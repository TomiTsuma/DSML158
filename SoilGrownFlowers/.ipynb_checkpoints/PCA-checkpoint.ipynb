# %%
import psycopg2
import pandas as pd
import numpy as np
import mariadb
import json
import os
import shutil
import subprocess
from pathlib import Path
import pyodbc
from sklearn.decomposition import PCA
from sklearn.preprocessing import StandardScaler
from scipy.spatial import distance
import pickle
import matplotlib.pyplot as plt
from sklearn.impute import SimpleImputer
import seaborn as sns

# %%
conn_lims = pyodbc.connect("Driver={SQL Server};"
                            "Server=192.168.5.18\CROPNUT;"
                            "Database=cropnuts;"
                            "uid=thomasTsuma;pwd=GR^KX$uRe9#JwLc6")

cursor = conn_lims.cursor()

# %%
analysisDetails = pd.read_csv("output/analysis_chemicals.csv")

# %%
analysisDetails.analysis_name = [ i.replace(":","") for i in analysisDetails.analysis_name ]

# %%
analysisDetails['chemical_name'] = [ i.replace("'","").replace("[","").replace("]","").split(",") for i in analysisDetails['chemical_name'] ]

# %%
analysisDetails = analysisDetails.set_index("analysis_name")

# %%
analysisDetails = analysisDetails.to_dict()['chemical_name']

# %%
sgf_df = pd.read_csv("output/sgf_analysis_cleaned.csv")

# %%
chemicals = pd.read_csv("chemicals.csv",index_col=0)

# %%
sgf_df = pd.merge(chemicals,sgf_df,on="chemical_name", how="inner")

# %%
df = pd.DataFrame({"sample_code":[]})

# %%
# for index,row in sgf_df.iterrows():
#     sample = row['sample_code']
#     if sample in df['sample_code'].values:
#         continue   
#     units = row['unit_name']
#     chemical = row['chemical_symbol']
#     result = row['result']
#     if units == "ppm":
#         sql = f"""
#         SELECT [dbo].[Calculate_Conversion] ({result}, '{chemical}') 
#         """
#         converted = cursor.execute(sql).fetchone()[0]
#         row['unit_name'] = "mmol/l"
#         row['result'] = converted
#         df = pd.concat([df, pd.DataFrame(row).T])
#     else:
#         df = pd.concat([df, pd.DataFrame(row).T])

# %%
sgf_df.analysis_name.value_counts().to_csv("output/analysis_value_counts.csv")

# %%
sgf_df.analysis_name = [ str(i).strip() for i in sgf_df.analysis_name]

# %%
sgf_df['analysis_name'] = [i.replace(":","") for i in sgf_df['analysis_name']]
sgf_df['result'] = [ float(str(i).replace("<","").replace(">","")) for i in sgf_df['result'] ]

# %%
sgf_df.sort_values('batch_date')
# Out:
#        chemical_symbol chemical_name  Unnamed: 0.2  Unnamed: 0.1  Unnamed: 0  \
# 567949      NO3N           nitrate_n         87090         30012       30012
# 176765      Mn             manganese         87139         30051       30051
# 176764      Mn             manganese         87093         30015       30015
# 308266      B                  boron         87095         30017       30017
# 308267      B                  boron         87137         30053       30053
# ...                ...           ...           ...           ...         ...
# 122280      Mg             magnesium         87078        405682      405682
# 670300      Si             silicon__         87069        406134      406134
# 227110      Cu                copper         87086        406129      406129
# 17444       K              potassium         87077        405683      405683
# 277457      B                  boron         87085        406128      406128
#
#                sample_code               batch_date           analysis_name  \
# 567949  CG044SGF0002        2010-11-26 00:00:00.000  12 Soil Volume Extract
# 176765  CG044SGF0004        2010-11-26 00:00:00.000  12 Soil Volume Extract
# 176764  CG044SGF0002        2010-11-26 00:00:00.000  12 Soil Volume Extract
# 308266  CG044SGF0002        2010-11-26 00:00:00.000  12 Soil Volume Extract
# 308267  CG044SGF0004        2010-11-26 00:00:00.000  12 Soil Volume Extract
# ...                    ...                      ...                     ...
# 122280        CT017SGF0380  2024-11-14 13:00:06.607  12 Soil Volume Extract
# 670300        CT017SGF0380  2024-11-14 13:00:06.607  12 Soil Volume Extract
# 227110        CT017SGF0380  2024-11-14 13:00:06.607  12 Soil Volume Extract
# 17444         CT017SGF0380  2024-11-14 13:00:06.607  12 Soil Volume Extract
# 277457        CT017SGF0380  2024-11-14 13:00:06.607  12 Soil Volume Extract
#
#         result unit_name
# 567949  31.300       ppm
# 176765   0.780       ppm
# 176764   0.069       ppm
# 308266   0.170       ppm
# 308267   0.069       ppm
# ...        ...       ...
# 122280   6.690       ppm
# 670300  13.300       ppm
# 227110   0.015       ppm
# 17444   48.400       ppm
# 277457   0.200       ppm
#
# [703101 rows x 10 columns]

# %%
new_samples_df = sgf_df.loc[sgf_df['batch_date'] > '2024-08-21'] 
sgf_df = sgf_df.loc[sgf_df['batch_date'] <= '2024-08-21']

# %%
new_samples_df.analysis_name.value_counts()
# Out:
# analysis_name
# 12 Soil Volume Extract                             12232
# Drip Water Analysis                                 6630
# Raw irrigation water analysis (for fertigation)      255
# Name: count, dtype: int64

# %%
sgf_df.analysis_name.value_counts()
# Out:
# analysis_name
# 12 Soil Volume Extract                             638896
# Drip Water Analysis                                 62189
# Raw irrigation water analysis (for fertigation)      3407
# Name: count, dtype: int64

# %%
sgf_df.analysis_name.value_counts().to_csv("output/modelling_analysis_value_counts.csv")
new_samples_df.analysis_name.value_counts().to_csv("output/test_analysis_value_counts.csv")

# %%
os.makedirs("output/analysis",exist_ok=True)
os.makedirs("output/chemical_null_count",exist_ok=True)

for analysis in np.unique(sgf_df['analysis_name']):
    print(analysis)
    df_ = sgf_df.loc[sgf_df['analysis_name']==analysis]
    print(df_.chemical_name.unique())
    
    df_ = pd.pivot_table(data=df_, values="result", index="sample_code", columns="chemical_name")
    df_ = df_[[ j.strip() for j in analysisDetails[analysis] if j.strip() in df_.columns]]
    df_ = df_.loc[:, ~df_.columns.duplicated()]
    os.makedirs(f"output/boxplots/{analysis}",exist_ok=True)
    for column in df_.columns:        
        plt.boxplot(df_[column])
        plt.savefig(f"output/boxplots/{analysis}/{column}.png")
        plt.clf()
        outlier_threshold = df_[column].quantile(0.99)
        # df_ = df_.loc[df_[column] <= outlier_threshold]

    if len(df_.columns) == 0:
        continue
    df_.describe().to_csv(f"output/chemical_null_count/{analysis}.csv")
    
    df_.to_csv(f"output/analysis/{analysis}.csv")
# Out:
# 12 Soil Volume Extract
# ['magnesium' 'calcium' 'ammonium' 'sulphur' 'sodium' 'potassium'
#  'nitrate_n' 'phosphorus' 'bicarbonate' 'zinc' 'molybdenum' 'boron'
#  'copper' 'manganese' 'iron' 'silicon__' 'chloride' 'chlorides' 'nitrates'
#  'electrical_conductivity']
# Drip Water Analysis
# ['nitrate_n' 'molybdenum' 'sulphur' 'manganese' 'magnesium' 'phosphorus'
#  'iron' 'potassium' 'copper' 'calcium' 'sodium' 'zinc' 'bicarbonate'
#  'boron' 'ammonium' 'silicon__' 'chloride' 'nitrates' 'chlorides']
# Raw irrigation water analysis (for fertigation)
# ['bicarbonate' 'sulphur' 'magnesium' 'copper' 'boron' 'nitrate_n' 'zinc'
#  'iron' 'chloride' 'potassium' 'calcium' 'molybdenum' 'manganese'
#  'ammonium' 'phosphorus' 'sodium' 'silicon__' 'nitrates'
#  'electrical_conductivity' 'ph']

# %%
os.makedirs("./output/analysis_imputed",exist_ok=True)
os.makedirs("./output/pca_plots",exist_ok=True)
os.makedirs("./output/pca_df",exist_ok=True)
os.makedirs("./output/analysis_scaled",exist_ok=True)

# %%
os.makedirs("./models/imputers",exist_ok=True)
os.makedirs("./models/scalers",exist_ok=True)
os.makedirs("./models/pca",exist_ok=True)

# %%
for analysis_file in os.listdir("output/analysis"):
    print(analysis_file)
    analysis_df = pd.read_csv(f"output/analysis/{analysis_file}",index_col=0)
    analysis_df = analysis_df.loc[analysis_df.index.isin(sgf_df.sample_code)]
    imp_mean = SimpleImputer(missing_values=np.nan, strategy='mean')
    # analysis_df = pd.DataFrame(imp_mean.fit_transform(analysis_df), columns=analysis_df.columns, index=analysis_df.index)
    analysis_df = pd.DataFrame(imp_mean.fit_transform(analysis_df), index=analysis_df.index)
    analysis_df.to_csv(f"./output/analysis_imputed/{analysis_file}")
    pickle.dump(imp_mean, open(f"models/imputers/{analysis_file.replace('csv','pkl')}","wb"))
    # if(len(analysis_df) == 0):
    #     continue
    if(len(analysis_df.columns) == 1):
        continue
    sc = StandardScaler()
    pca = PCA()
    analysis_scaled = sc.fit_transform(analysis_df)
    pca.fit(analysis_scaled)
    explained_variance_ratio = pca.explained_variance_ratio_
    cumulative_explained_variance = np.cumsum(explained_variance_ratio)
    plt.figure(figsize=(8, 5))
    plt.plot(range(1, len(cumulative_explained_variance) + 1), cumulative_explained_variance, marker='o', linestyle='--')
    plt.xlabel('Number of Principal Components')
    plt.ylabel('Cumulative Explained Variance')
    plt.title(f'Explained Variance vs Number of Components {analysis_file}')
    plt.grid(True)
    plt.savefig(f"./output/pca_plots/{analysis_file.replace('.csv','.png')}")
    n_components = np.argmax(cumulative_explained_variance >= 0.95) + 1
    print(f'Number of components explaining 95% variance: {n_components}')
    
    pca = PCA(n_components=n_components)
    pca_reduced_df = pca.fit_transform(analysis_scaled)
    analysis_scaled = pd.DataFrame(analysis_scaled,index=analysis_df.index)
    analysis_scaled.to_csv(f"output/analysis_scaled/{analysis_file}")
    np.save(f"output/pca_df/{analysis_file.replace('.csv','')}", pca_reduced_df)
    pickle.dump(sc, open(f"models/scalers/{analysis_file.replace('csv','pkl')}","wb"))
    pickle.dump(pca, open(f"models/pca/{analysis_file.replace('csv','pkl')}","wb"))
# Out:
# 12 Soil Volume Extract.csv
# Number of components explaining 95% variance: 14
# Drip Water Analysis.csv
# Number of components explaining 95% variance: 13
# Raw irrigation water analysis (for fertigation).csv
# Number of components explaining 95% variance: 8

# %%
os.makedirs("./output/mahalanobis_distance",exist_ok=True)

# %%
for analysis_file in os.listdir("output/pca_df"):
    print(analysis_file)
    pca_reduced_df = pd.DataFrame(np.load(f"output/pca_df/{analysis_file}"))
    if len(pca_reduced_df.columns) <= 2:
        continue
    mu = np.mean(pca_reduced_df, axis=0)
    sigma = np.cov(pca_reduced_df.T)
    pca_reduced_df['mahalanobis_distance'] = [distance.mahalanobis(pca_reduced_df.iloc[i], mu, np.linalg.inv(sigma)) for i in range(len(pca_reduced_df)) ]

    pd.DataFrame(pca_reduced_df).to_csv(f"output/mahalanobis_distance/{analysis_file.replace('.npy','')}.csv")
# Out:
# 12 Soil Volume Extract.npy
# Drip Water Analysis.npy
# Raw irrigation water analysis (for fertigation).npy

# %%
os.makedirs("output/mahanobis_distance_upper_quantile",exist_ok=True)
os.makedirs("output/mahalanobis_boxplots",exist_ok=True)

# %%
mahalanobis_threshold_dict = {}
for analysis_file in os.listdir("output/mahalanobis_distance"):
    print(analysis_file)
    analysis = analysis_file.replace(".csv","")
    mahalanobis_df = pd.read_csv(f"output/mahalanobis_distance/{analysis_file}",index_col=0)
    upper_quantile = (mahalanobis_df['mahalanobis_distance'].quantile(0.95))
    mahalanobis_threshold_dict[analysis_file.replace(".csv","")] = upper_quantile
    mahalanobis_df.loc[mahalanobis_df['mahalanobis_distance'] >= upper_quantile].to_csv(f"output/mahanobis_distance_upper_quantile/{analysis_file}")
    plt.boxplot(mahalanobis_df['mahalanobis_distance'])
    plt.axhline(y=upper_quantile, color='red', linestyle='--', label=f'Threshold at {upper_quantile}')
    plt.title(f"Mahalanobis Threshold = {round(upper_quantile,2)}")
    plt.savefig(f"output/mahalanobis_boxplots/{analysis}.png")
    plt.clf()
pickle.dump(mahalanobis_threshold_dict, open("mahalanobis_thresholds.dict","wb"))
# Out:
# 12 Soil Volume Extract.csv
# Drip Water Analysis.csv
# Raw irrigation water analysis (for fertigation).csv

# %%
pd.DataFrame({'analysis_name':(mahalanobis_threshold_dict.keys())}).to_csv("output/analysis_names_send_to_thomas_and_josephine.csv")

# %%
conn_lims = pyodbc.connect("Driver={SQL Server};"
                            "Server=192.168.5.18\CROPNUT;"
                            "Database=cropnuts;"
                            "uid=thomasTsuma;pwd=GR^KX$uRe9#JwLc6")

# %%
reverse_analysis_dict = pd.read_sql(f"""SELECT analysis_id, LTRIM(RTRIM(analysis_name)) as analysis_name FROM Analysis ORDER BY analysis_name""",con=conn_lims).set_index("analysis_name").to_dict()['analysis_id']
reverse_analysis_dict
# Out:
# C:\Users\tsuma.thomas\AppData\Local\Temp\ipykernel_11632\3771434913.py:1: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   reverse_analysis_dict = pd.read_sql(f"""SELECT analysis_id, LTRIM(RTRIM(analysis_name)) as analysis_name FROM Analysis ORDER BY analysis_name""",con=conn_lims).set_index("analysis_name").to_dict()['analysis_id']
# {'% Gypsum': 540,
#  '% Nitrogen (RSSP 2)': 647,
#  '% Organic Matter': 258,
#  '% Organic Matter (RSSP 2)': 646,
#  '% Soil Nitrogen': 18,
#  '%Assay': 27490,
#  '%N (RSSP 2)': 652,
#  '%OM (RSSP 2)': 651,
#  '%P,%S Analysis(Super Calcium)': 383,
#  '1:2 Soil Volume Extract': 294,
#  '1:2 soil volume extract': 25,
#  '1:2 Soil Volume Extract (Data Only)': 27339,
#  '1:2 Vol Extract for BLGG': 317,
#  '20:12:12 (N,P205,K20) Analysis': 840,
#  'Absorbance at 254nm': 26936,
#  'Acid Detergent Fibre': 27063,
#  'Acid Insoluble Ash': 27417,
#  'Acid Insoluble Matter': 27108,
#  'Acid titration': 26647,
#  'Acid Value': 26971,
#  'Advanced Biological Farming Soil Audit': 26521,
#  'Advanced Soil Health Analysis': 27181,
#  'Aerobic Mesophilic Count': 26649,
#  'Aflatoxin': 26794,
#  'Aflatoxin AFB1': 26938,
#  'Aflatoxin B1': 26939,
#  'Aflatoxin in feed': 767,
#  'Aflatoxin M1': 27469,
#  'Aflatoxin Total': 766,
#  'AfSIS Standard Leaf Analysis': 633,
#  'AFSIS Std Wet Chemistry Soil Analysis': 589,
#  'Aggregate Stability': 26727,
#  'Agrifi Soil Microbiome Analysis': 27293,
#  'Agrobacterium Detection': 636,
#  'Agrobacterium Test': 26634,
#  'Agroblen Analysis': 80,
#  'Agroleaf Analysis': 169,
#  'Alfalfa mosaic virus (AMV)  (ELISA)': 26820,
#  'Algae': 27114,
#  'Alkalinity': 26754,
#  'Alkalinity in Water': 184,
#  'Allergens LC-MS': 27065,
#  'Alternaria spp': 26775,
#  'Aluminium': 390,
#  'Aluminium analysis': 27131,
#  'Aluminium Analysis': 26782,
#  'Aluminium Ananalysys': 27132,
#  'Aluminium in Compost/Manure': 26731,
#  'Aluminium in Plant': 829,
#  'Aluminium in soil': 26722,
#  'Aluminium in Soil (Mehlich3)': 549,
#  'Aluminium Sulphate (Al,S) Analysis': 848,
#  'Aluminium Sulphate Analysis': 68,
#  'Amino acids with tryptophan': 27353,
#  'Ammonia': 27248,
#  'Ammonia in Soil': 644,
#  'Ammonia in Water': 312,
#  'Ammonia Sulphate Analysis': 65,
#  'Ammonim Sulphate (N,S) Analysis': 845,
#  'Ammonium Acetate Cu & Zn': 26758,
#  'Ammonium Analysis': 872,
#  'Ammonium Nitrate': 930,
#  'Ammonium Nitrate Analysis': 167,
#  'Ammonium Sulphate': 475,
#  'Ammonium Sulphate Analysis': 689,
#  'Animal Feed Mercury EAS 55 2019': 27023,
#  'Animal Feeds Analysis': 171,
#  'Animal Health Leaf Analysis': 15,
#  'Animal Health Leaf Analysis (Feed)': 83,
#  'Animal Health Soil Analysis': 31,
#  'Animal Health Soil Analysis (Feed)': 84,
#  'Anthracnose test': 27096,
#  'Anthraquinone analysis': 26966,
#  'Antibiotics Analysis': 26808,
#  'Antimony & Lithium': 27350,
#  'Aqua Regia (Ca, Mg, K & Na) Analysis': 27509,
#  'Aqua regia - Selected elements (ICP) Analysis': 26852,
#  'Aquasearch Full Chemical Analysis': 555,
#  'Aquasearch Overseas Full Chem Analysis': 705,
#  'Aquavita 1': 27426,
#  'Aquavita 2': 27427,
#  'Armillaria spp': 27487,
#  'Arsenic': 391,
#  'Arsenic Analysis': 27224,
#  'Arsenic in Plant': 694,
#  'Arsenic in Soil (Aqua regia)': 26629,
#  'Arsenic in Water': 762,
#  'Ash Analysis': 26838,
#  'Ash Content': 26530,
#  'Ash Content Analysis': 642,
#  'Ash content in sludge': 27232,
#  'Aspergillus': 265,
#  'Aspergillus spp': 27054,
#  'ASTM Rapid Sugar Test': 26807,
#  'ATA Ethiopia Soil Analysis': 779,
#  'Athi River Fertiliser': 345,
#  'Available Calcium Carbonate': 26964,
#  'Available Calcium Carbonate Eq': 26871,
#  'Available Calcium Hydroxide': 27197,
#  'Available Nitrogen Analysis': 873,
#  'Available Nitrogen in Soil': 27461,
#  'Available P': 552,
#  'Available Phosphorous': 27390,
#  'Available Potassium in Soil': 26666,
#  'Available Soil Nitrogen': 33,
#  'Avocado Fruit Pathology Screen': 26610,
#  'Bacillus cereus': 27506,
#  'bacillus cereus': 27099,
#  'Bacillus ssp': 27257,
#  'Bacteria Count': 27504,
#  'Bacterial sequencing': 27446,
#  'Bacterial test (9) in hydroponics': 27447,
#  'Barium': 392,
#  'Barium & Silicon & Strontium': 155,
#  'Barium Analysis': 27459,
#  'Barium in Water': 876,
#  'Base Titanium Water Analysis': 719,
#  'Basic Analysis Plus Micros': 10,
#  'Basic Animal Feed Analysis': 56,
#  'Basic Compost/Manure Analysis': 492,
#  'Basic Drinking Water Analysis (WHO)': 288,
#  'Basic Effluent Analysis (Burka)': 693,
#  'Basic Effluent Analysis Minus Micro': 639,
#  'Basic Effluent Water Analysis': 322,
#  'Basic Hybrid Plus': 27210,
#  'Basic Irrigation Water Analysis': 26660,
#  'Basic Leaf Analysis': 275,
#  'Basic Manure Analysis': 301,
#  'Basic Manure/Compost Analysis': 170,
#  'Basic Soil + Hp Analysis': 765,
#  'Basic Soil Analysis': 4,
#  'Basic Soil Analysis (Soil prepared by Agent)': 430,
#  'Basic Soil Analysis with Recommendations': 751,
#  'Basic Soil Analysis( Not in use)': 211,
#  'Basic Soil Chemistry Analysis': 27317,
#  'Basic Soil Chemistry Analysis (alkaline)': 27319,
#  'Basic Soil Health Analysis': 27179,
#  'Basic Soil Scan(NOT IN USE)': 752,
#  'Basic Water Analysis for Filtration': 377,
#  'BeCrop Microbiome Analysis': 27229,
#  'BeCrop® microbiome Analysis': 27364,
#  'Benzoic Acid': 27332,
#  'Bicarbonate Analysis': 26620,
#  'Bicarbonate in Water': 721,
#  'Bio-available Nutrients in Soil': 330,
#  'Bio-PCR Agrobacterium': 27228,
#  'Biochemical Oxygen Demand': 733,
#  'Biological & Chemical Oxygen Demand': 126,
#  'Biological Oxygen Demand': 26777,
#  'Biomass': 934,
#  'Biuret Analysis on Urea': 926,
#  'Biuret test': 27297,
#  'Black Tea Aluminium Analysis': 26721,
#  'Black Tea Contaminant Analysis': 26880,
#  'Black Tea Flouride Analysis': 26720,
#  'Black Tea Microbial': 27392,
#  'Black Tea Microbial Analysis': 26881,
#  'Borax (B) Analysis': 1002,
#  'Borax Analysis': 690,
#  'Boron Analysis': 27430,
#  'Boron Analysis - Hot water': 229,
#  'Boron in Plant': 562,
#  'Boron in Water': 763,
#  'Botrytis cinerea': 27352,
#  'Bray 1': 26708,
#  'Bray 1 & 2 in Soil': 222,
#  'Bray 1 in Soil': 26603,
#  'Bray 2 in Soil': 27230,
#  'Brix': 27269,
#  'Brix analysis': 27233,
#  'Brix Analysis': 27480,
#  'Brix test': 27102,
#  'Broad Spectrum Leaf Analysis': 13,
#  'Broad Spectrum Soil Analysis': 11,
#  'Broken Grains': 27093,
#  'Bromide': 27507,
#  'Bromide in Water': 891,
#  'BT Extended Water Quality Analysis': 743,
#  'BT NEMA Effluent into Environment': 27200,
#  'BTEX Analysis': 712,
#  'Bulk Density': 27027,
#  'Bulk Density Analysis': 585,
#  'Cadmium': 497,
#  'Cadmium Analysis': 27471,
#  'Cadmium analysis': 27137,
#  'Cadmium Analysis of Fish Extract (KEBS)': 574,
#  'Cadmium in Water': 26742,
#  'Cadnium': 393,
#  'Calcium': 29,
#  'Calcium & Magnesium Animal Food': 27282,
#  'Calcium & Phosphorous Animal Food': 26942,
#  'Calcium Ammonium Nitrate Analysis': 806,
#  'Calcium Analysis': 27405,
#  'Calcium analysis': 27130,
#  'Calcium Carbonate': 27305,
#  'Calcium Carbonate Analysis': 27376,
#  'Calcium Carbonate Equivalent': 27284,
#  'Calcium Chloride Analysis': 537,
#  'Calcium hypochlorite': 27154,
#  'Calcium in Plant': 559,
#  'Calcium in Water': 350,
#  'Calcium Nitrate Analysis': 798,
#  'Calcium Sulphate': 27460,
#  'Calcium Sulphate Analysis': 851,
#  'Calcium, Magnesium & Potassium': 27374,
#  'CAN Analysis': 621,
#  'CAN Analysis (KEBS)': 26643,
#  'Carbohydrates': 27416,
#  'Carbon (Total Organic)': 424,
#  'Carbon : Nitrogen Ratio': 26770,
#  'Carbon Analysis': 209,
#  'Carbon in Compost/Manure': 826,
#  'Carbon in Plant': 581,
#  'Carbon in Soil': 505,
#  'Carbon Plus': 27176,
#  'Carbon:Nitrogen Ratio': 27424,
#  'Carbonate Analysis': 27288,
#  'Carbonate analysis': 27106,
#  'Carbonates': 26960,
#  'Carbonates in Water': 272,
#  'CEC Analysis': 27371,
#  'Chelated Manganese analysis': 146,
#  'Chemical & Biochemical Oxygen Demand': 26953,
#  'Chemical & Biological Oxygen Demand': 26963,
#  'Chemical & Heavy Metals Water Analysis (FAO)': 26774,
#  'Chemical Analysis': 576,
#  'Chemical Oxygen Demand': 27378,
#  'Chemical screen (GC & LC-MS)': 27103,
#  'Chlorate & Perchlorate Analysis': 26670,
#  'Chlorate Analysis': 27501,
#  'Chloride': 103,
#  'Chloride (water soluble)': 27277,
#  'Chloride Analysis': 729,
#  'Chloride Analysis (Drain)': 295,
#  'Chloride in Plant': 26857,
#  'Chloride in plant': 27140,
#  'Chloride in Soil': 26559,
#  'Chloride in Water': 481,
#  'Chlorine (Fre Available)': 416,
#  'Chlorine (Residual)': 417,
#  'Chlorine analysis': 26984,
#  'Chlorine Test': 27491,
#  'Chlorophyll Analysis': 26516,
#  'Chlorpyrifos Analysis': 27402,
#  'Chlorpyrifos, chlorpyrifos-methyl': 27473,
#  'Chrome': 394,
#  'Chromium': 498,
#  'Chromium Analysis': 27225,
#  'Chromium analysis': 27194,
#  'Chromium in Plant': 26591,
#  'Chromium in water': 27111,
#  'Chromium-6': 27351,
#  'Chrrmium VI': 413,
#  'CIFOR-ICRAF Wet Chem Soil Analysis Option 2': 27126,
#  'CIFOR-ICRAF Wet Chem Soil Analysis Soil Option 1': 27125,
#  'CIFOR-ICRAF Wet Chemistry Soil Analysis Option 3': 27127,
#  'Clavibacter michiganensis subsp. michiganensis(ELISA)': 26874,
#  'Clostridium Perfringens': 26664,
#  'CMM Analysis': 26841,
#  'CO2 Respiration': 27449,
#  'Cobalt': 26572,
#  'Cobalt Analysis': 27017,
#  'Cobalt analysis': 27201,
#  'Cobalt in Soil': 26681,
#  'Colloidal Silica': 26755,
#  'Colloidal Silica in Water': 678,
#  'Colour': 26878,
#  'Complete Compost-Manure Pathology Screen': 917,
#  'Complete Compost/Manure Analysis': 494,
#  'Complete Compost/Manure Analysis +OM': 27302,
#  'Complete Feed Analysis (NIR, ICP)': 820,
#  'Complete Feed Analysis (Wetchem, ICP)': 26671,
#  'Complete Hybrid Soil plus': 27209,
#  'Complete Leaf Analysis': 231,
#  'Complete Leaf Analysis(NIR)': 26738,
#  'Complete Leaf Analysis+DM': 26771,
#  'Complete Leaf Analysis+DM+Al': 27090,
#  'Complete Media Pathology Screen': 26696,
#  'Complete Nutritional Analysis (Wetchem & ICP)': 26957,
#  'Complete Path Scan (Soil)': 949,
#  'Complete Plant Pathology Fungal Screening': 27425,
#  'Complete Plant Pathology Screen': 911,
#  'Complete Plant Sap Analysis': 26601,
#  'Complete Soil + Bio-available Nutrients Analysis': 26570,
#  'Complete Soil + Hp Analysis': 796,
#  'Complete Soil Analysis (CA)': 27112,
#  'Complete Soil Analysis (Calcareous)': 905,
#  'Complete Soil Analysis (data only)': 26597,
#  'Complete Soil Analysis (M3)': 568,
#  'Complete Soil Analysis (RSSP 2)': 645,
#  'Complete Soil Analysis (RSSP2)': 650,
#  'Complete Soil Analysis (soil prepared by agent)': 948,
#  'Complete Soil Analysis + Exch. Acidity': 764,
#  'Complete Soil Analysis - Co & Si (IFDC)': 808,
#  'Complete Soil Analysis with Recommendations': 221,
#  'Complete Soil Pathology Screen': 908,
#  'Complete Substrate Pathology Screen': 920,
#  'Complete Water Analysis': 26560,
#  'Complete Water Screen for Plant Pathogens': 914,
#  'Composition & Quality of Nuts': 26918,
#  'Compost 1:1.5 Water Extract': 493,
#  'Compost Liquid Extract': 534,
#  'Compost Liquid Extract  Analysis': 173,
#  'Compost Liquid Extracts Analysis': 533,
#  'Compost Pathology Test': 889,
#  'Compost Scan': 788,
#  'Compost-Manure Bacterial Pathogen Screen': 919,
#  'Compost-Manure Fungal Pathogen Screen': 918,
#  'Compost/Manure Pathology': 627,
#  'Copper': 396,
#  'Copper  Analysis': 119,
#  'Copper & Zinc Analysis': 26955,
#  'Copper Analysis': 26679,
#  'Copper in Plant': 563,
#  'Copper in Water': 723,
#  'Copper Sulphate Analysis': 490,
#  'Copper,Chromium and Arsenic Analysis': 945,
#  'CPF Soil Analysis': 26550,
#  'Cropnuts Spectral IR Pre-screening': 26687,
#  'Cropnuts Wet Chem IR Calibration Soil Analysis': 26684,
#  'Crude Fibre': 26988,
#  'Crude Protein': 813,
#  'Cucumber Mosaic Virus (CMV)  (ELISA)': 26811,
#  'Cyanide (Total)': 414,
#  'Cyanide A': 415,
#  'cylindrocarpon destructans': 27014,
#  'Daminozide Analysis': 27453,
#  'DAP (N, P2O5) Analysis': 774,
#  'DAP (N,P2O5) Analysis': 606,
#  'DAP Analysis': 843,
#  'DAP Analysis (KEBS)': 26583,
#  'Data Science Plant': 27499,
#  'Data Science Re-Analysis': 27156,
#  'Dayliff Drinking Water Analysis': 513,
#  'Dayliff Microbial Water Analysis': 514,
#  'Density': 27239,
#  'Di-Ammonium Phosphate Analysis': 66,
#  'Dialysis Water Chemical Parameters': 27033,
#  'Dialysis Water Microbial Parameters': 27034,
#  'Diary Cattle Heavy Metals KS62 2009': 27025,
#  'Dicalcium Phosphate (DCP) Analysis': 26668,
#  'dioxine +furanen+pcb ( dl +ndl )': 27150,
#  'Dissolved (reactive) Silica': 26756,
#  'Dissolved Chlorine': 27346,
#  'Dissolved Organic Carbon Analysis': 26858,
#  'Dissolved Oxygen': 336,
#  'Dissolved Phosphorus (citric acid)': 26894,
#  'Dissolved(reactive) Silica': 26576,
#  'Dithiocarbamate Compounds': 27050,
#  'DNA Extraction': 27021,
#  'DNA Multi Pathogen Screen (Roses, MDR)': 27380,
#  'DNAcheckTomato+Clavibacter': 26842,
#  'Dolmax Analysis': 105,
#  'Downy Mildew': 26587,
#  'Drain Water Analysis': 255,
#  'Drain Water Analysis (Data only)': 27337,
#  'Drain Water Analysis (SGS)': 41,
#  'Drain Water Analysis + Rx': 386,
#  'Drainage water analysis': 191,
#  'Dried Fruit Microbial': 27395,
#  'Drinking Water Analysis (Sino)': 27104,
#  'Drinking Water Standard Analysis(BATUK)': 27483,
#  'Drinking Water(B)': 27484,
#  'Drip Water Analysis': 27454,
#  'Drip Water Analysis (Data only)': 27335,
#  'Drip Water Analysis (SGF) + Rx': 427,
#  'Drip Water Analysis (SGS)': 40,
#  'Drip Water Analysis (soil, data only)': 27340,
#  'Drip Water Analysis + Rx': 385,
#  'Dry Matter Analysis': 953,
#  'Dry Matter content': 27019,
#  'Dry Matter in Compost/Manure': 941,
#  'E coli': 26879,
#  'E Coli': 26868,
#  'E coli & Total Coliforms': 263,
#  'E Coli & Total Coliforms': 289,
#  'E. coli': 27068,
#  'E. Coli Analysis': 674,
#  'E.Coli and Salmonella Analysis': 204,
#  'EAS 12:2018 Drinking Water Analysis (Cat2)': 27280,
#  'EAS 12:2018 Drinking Water Analysis (Cat3)': 27295,
#  'EAS 12:2018 Drinking Water Analysis (Cat4)': 27244,
#  'EAS 12:2018 Drinking Water Standard Analysis(SG)': 27359,
#  'EAS 12:2018 Drinking Water Standard Analysis(SG) - without Micro': 27498,
#  'EC': 928,
#  'EC [Salts] Analysis': 236,
#  'EC Analysis': 347,
#  'EC of Sample': 1011,
#  'Ecoli': 27186,
#  'Effluent Analysis (NEMA 3rd Schedule - Into Environment)': 26577,
#  'Effluent Analysis (NEMA 5th Schedule - Into Public Sewer': 26728,
#  'Effluent Analysis (ST)': 736,
#  'Effluent Analysis into Environment (Usafi raw water)': 26824,
#  'Effluent Analysis into Environment (Usafi treated water)': 26825,
#  'Electrical Conductivity': 27296,
#  'Electrical Conductivity in Water': 143,
#  'Element Config': 26588,
#  'ELISA BATCH PREPARATION (up to 45 samples)': 26562,
#  'Elisa Virology': 333,
#  'Enterobacteriaceae': 27088,
#  'Enterococcus': 27215,
#  'Enterococcus faecalis': 27489,
#  'Enterococcus faecium': 27268,
#  'Erwinia carotovora': 27216,
#  'Escherichia coli': 124,
#  'Estimated Available Water Holding Capacity': 27211,
#  'Ether Extract': 27051,
#  'Ethylene Acids': 27436,
#  'Ethylene Oxide': 27472,
#  'Exchangeable Acidity': 19,
#  'Exchangeable Acidity (Hp) in Soil': 183,
#  'Exchangeable Acidity Analysis': 528,
#  'Exchangeable Acidity Analysis(NM)': 175,
#  'Exchangeable Al (RSSP 2)': 654,
#  'Exchangeable Aluminium': 531,
#  'Exchangeable Aluminium (RSSP 2)': 648,
#  'Exchangeable Aluminium in Soil': 504,
#  'Exchangeable K (Ammonium Acetate)': 27148,
#  'Exchangeable K, Mg, Ca, Na (Ammonium Acetate)': 26789,
#  'Extended Water Chemisty Analysis': 462,
#  'Extractable Inorganic N (KCl Extract)': 675,
#  'Faecal coliforms': 26917,
#  'Faecal E.Coli': 284,
#  'Faecal Streptococci': 968,
#  'FarmLab Molo Soil Test': 541,
#  'Fat Acidity (mgKOH)': 27097,
#  'Fat content': 26992,
#  'Fat Content': 26896,
#  'Fats, Oil & Grease': 422,
#  'Fatty Acids Profile': 27432,
#  'Feacal Coliforms (MPN)': 677,
#  'Feacal Coliforms (MPN) & Feacal E Coli Test': 26621,
#  'Feacal Coliforms (MPN) and E.Coli': 897,
#  'Feed Scan': 759,
#  'Feriline -6% Analysis': 629,
#  'Feriline-6% (Fe) Analysis': 1001,
#  'Ferrilene Analysis': 100,
#  "Fertiliser Screen (excludes HM's)": 929,
#  "Fertiliser Screen (incl HM's)": 26994,
#  'Fertilizer Analysis (3 Elements)': 473,
#  'Fertilizer Analysis (Full Fertilizer Scan HMs)': 1020,
#  'Fertilizer Analysis 6 Elements': 480,
#  'Fertilizer Analysis(1 Element)': 471,
#  'Fertilizer Heavy Metals': 892,
#  'Fertilizer Screen': 1032,
#  'Fibre Analysis': 27193,
#  'Flouride Analysis': 947,
#  'Flouride in soil': 26719,
#  'Flourine': 418,
#  'Fluoride Analysis': 27287,
#  'Fluoride Analysis (Drain)': 250,
#  'Fluoride Analysis (Media)': 26515,
#  'Fluoride in Plant': 26625,
#  'Fluoride in Water': 248,
#  'Fodder and Silage Analysis': 57,
#  'Food Grade Salt': 26934,
#  'Fortified edible fats and oils (EAS 769: 2019)': 27242,
#  'Fortified edible fats and oils contaminants (EAS 769: 2019)': 27243,
#  'Fosetyl-aluminum + phosphonic acid': 27466,
#  'Free Chlorine': 26630,
#  'Free Chlorine Analysis': 582,
#  'Free Fatty Acid (FFA)': 27292,
#  'Free Lime in Soil': 539,
#  'Free Moisture Analysis': 26659,
#  'Fruit Juice Micro': 27394,
#  'Fruit Nitrogen/ Calcium Analysis': 27494,
#  'Full Nutritional Analysis Forage (Wetchem)': 26952,
#  'Full soil screen HF': 27508,
#  'Fumonisin total': 27414,
#  'Fungal Bacteria Ratio': 27331,
#  'Fungal Bacterial ratio in Liquid compost': 27502,
#  'Fungi bacterial ratio in manure': 27433,
#  'Fusarium Isolation': 112,
#  'Fusarium Oxysporum': 26542,
#  'Glyphosate': 26999,
#  'Glyphosate Residue testing': 26851,
#  'Glyphosate Residue Testing': 26602,
#  'Glyphosate, Glufosinate and AMPA': 27365,
#  'Gold': 397,
#  'Gold Analysis': 27212,
#  'Gold analysis (extracted solution by ICP)': 26589,
#  'Grain Nutrient Analysis': 27321,
#  'Grain Physical Test': 26986,
#  'Grain Physical Test- Rice': 27299,
#  'Granulatory Analysis': 485,
#  'Gypsum Analysis': 686,
#  'Hand Swabs': 535,
#  'Handling Fee Per Batch': 26600,
#  'Haney Soil Test': 27492,
#  'Hardness': 26810,
#  'Hardness Analysis': 314,
#  'Heavy Metal Analysis': 731,
#  'Heavy Metal Analysis (Soil)': 198,
#  'Heavy Metals': 943,
#  'Heavy Metals  (KS 2290:2018)': 27309,
#  'Heavy Metals (Dry Food)': 26657,
#  'Heavy Metals Analysis': 296,
#  'Heavy Metals Analysis (Food Safety)': 27237,
#  'Heavy Metals Analysis (Fresh Foods)': 27000,
#  'Heavy Metals Analysis (P)': 151,
#  'Heavy Metals Compost/Manure Analysis': 153,
#  'Heavy Metals in 1:1.5 Substrate': 590,
#  'Heavy Metals in Compost/Manure': 26699,
#  'Heavy Metals in Fertilizer': 893,
#  'Heavy Metals in Fertilizer (inc Hg)': 27092,
#  'Heavy Metals in food (with mercury)': 26652,
#  'Heavy metals in Hydroponics': 26864,
#  'Heavy Metals in Lime': 26661,
#  'Heavy Metals in Plant': 588,
#  'Heavy Metals in Sample': 1018,
#  'Heavy Metals in Soil (Aqua regia)': 297,
#  'Heavy Metals in Water': 26685,
#  'Hot Brew Microbial-125': 27398,
#  'Hot Brew Microbial-25': 27397,
#  'Hybrid Soil Analysis': 27085,
#  'Hydroponics Analysis': 27343,
#  'Hydroponics Pathology': 147,
#  'ICRAF Std Wetchem Soil Analysis': 567,
#  'Impatiens Necrotic Spot Virus (INSV)': 27101,
#  'Inorganic carbon': 27412,
#  'Inorganic Carbon Analysis': 27255,
#  'Insect ID & Control Recommendations': 26575,
#  'Insoluble Matter': 27463,
#  'Iodate Analysis': 128,
#  'Iodine': 26855,
#  'iodine': 27441,
#  'Iodine Analysis': 662,
#  'Iodine in Water': 660,
#  'Iodine Value': 27005,
#  'Iridium': 398,
#  'Iron': 399,
#  'Iron  Analysis': 487,
#  'Iron Analysis': 688,
#  'Iron Chelate': 107,
#  'Iron Filings in Food': 26940,
#  'Iron in food': 26975,
#  'Iron in Plant': 564,
#  'Iron in Water': 311,
#  'Irrigation Water Analysis (FAO)': 27008,
#  'Jar Test': 26561,
#  'KALRO Soil Analysis': 27485,
#  'KALRO Soil Analysis(Comprehensive)': 27475,
#  'KARIKI CMV Poty ToMV TMV': 27151,
#  'KARIKI TSWV CMV Poty ToMV TMV': 27152,
#  'KEBS Drinking Basic Min Monitoring': 26956,
#  'KEBS Drinking Water Microbiology': 26724,
#  'KEBS Drinking Water Min Monitoring Microbiology': 27031,
#  'KEBS Drinking Water Minimum Monitoring': 26873,
#  'KEBS Drinking Water Standard Analysis': 26860,
#  'KOH Analysis': 27263,
#  'KS 2290:2018 Microbial': 27136,
#  'KS EAS768:2019 Milled Flour Microbial Analysis': 26899,
#  'KS EAS768:2019 Milled Maize Contaminants': 26887,
#  'KS Fertiliser Standards Heavy Metal Analysis': 26882,
#  'KS Fertiliser Standards Selenium': 26733,
#  'KS Potable Water Microbiology': 26893,
#  'KTDA Complete Leaf Analysis': 26612,
#  'KTDA Soil Analysis': 26613,
#  'Lactic Acid Bacteria': 27082,
#  'Lake Naivasha Monitoring': 335,
#  'LDPSA (Dry mode)': 27124,
#  'LDPSA (Wet mode)': 27123,
#  'Lead': 495,
#  'Lead Analysis': 27500,
#  'Lead analysis': 27138,
#  'Lead Analysis of Fish Extract (KEBS)': 575,
#  'Lead in Water': 933,
#  'Leaf Scan': 756,
#  'Legionella': 26656,
#  'Lignin In Feed': 27452,
#  'Lime Analysis': 199,
#  'Lime Analysis % Ca': 244,
#  'Lime Analysis % Mg': 243,
#  'Lime pH': 26582,
#  'Lime Quality Assessment': 26474,
#  'Lime Requirement': 238,
#  'Lime Screen': 26595,
#  "Lime Screen (excludes HM's)": 26594,
#  'Liquid Compost Pathology': 716,
#  'Liquid Organic Plant Supplement (KS 2290)': 27135,
#  'Listeria Analysis': 369,
#  'Listeria monocytogenes': 26929,
#  'Listeria monocytogens': 503,
#  'Listeria spp': 26973,
#  'Listeria Spp': 27002,
#  'Lite Drinking Water Analysis': 27324,
#  'Lithium Analysis': 635,
#  'Livestock Drinking Water': 26847,
#  'Macadamia Micro &Myco': 27401,
#  'Macadamia Physical parameters': 26915,
#  'Magnesium': 35,
#  'Magnesium Analysis': 27052,
#  'Magnesium in Plant': 561,
#  'Magnesium in Water': 663,
#  'Magnesium Nitrate Analysis': 63,
#  'Magnesium Oxide': 27143,
#  'Magnesium Sulphate': 472,
#  'Magnesium Sulphate Analysis': 799,
#  'Maize chlorotic mottle virus (MCMV) (ELISA)': 27083,
#  'Maize micro and mycotoxins': 27396,
#  'MAJI_Scan (Not In Use)': 755,
#  'Manganese': 401,
#  'Manganese Analysis': 27439,
#  'Manganese Analysis (Soil)': 310,
#  'Manganese in Plant': 565,
#  'Manganese in Water': 429,
#  'Manganese Sulphate': 894,
#  'Manganese Sulphate  Analysis': 742,
#  'Manganese Sulphate Analysis': 60,
#  'Manure / Compost Analysis': 14,
#  'MAP  Analysis (KEBS)': 26642,
#  'MAP Analysis': 615,
#  'Mavuno (N,P2O5,K,S,B,Zn) Analysis': 698,
#  'Mavuno Planting Fertilizer Analysis': 140,
#  'Mazao Bora Analysis': 507,
#  'Media Pathology': 600,
#  'Media Pathology Test': 887,
#  'Mehlich 3 extract analysis': 27278,
#  'Mercury': 402,
#  'Mercury & Lead Analysis': 741,
#  'Mercury Analysis': 27368,
#  'Mercury analysis': 26967,
#  'Mercury in Plant': 605,
#  'Mercury in sugar': 26718,
#  'Mg': 106,
#  'Micrel  Fe 11%DTPA Analysis': 625,
#  'Micrel Fe 11% DTPA (Fe) Analysis': 1003,
#  'Microbial Analysis': 27362,
#  'Microbial Analysis (Food)': 26995,
#  'Microbial Analysis (Milk Products)': 26996,
#  'Microbial Analysis Tea EAS 28:2019': 27022,
#  'Microbial Limits for Organic Fertiliser (KS EAS)': 26862,
#  'Microbial Respiration (CO2)': 875,
#  'Microfeed Analysis': 78,
#  'Microscopic Examination': 26663,
#  'Milk Solids Non Fat': 27360,
#  'Milled Flour Microbial Analysis': 26867,
#  'Mineral Carbon': 27026,
#  'Mineral Elements Analysis': 26944,
#  'Mineral Elements in Feed': 761,
#  'Mineral Elements in Forage': 26904,
#  'Mineral Lick': 27444,
#  'Mineral Lick Analysis': 26574,
#  'Mineral Oil Aromatic Hydrocarbons': 27474,
#  'Minjingu Mazao Analysis': 93,
#  'MIR Soil Scan': 26981,
#  'MKP (Mono Potassium Phosphate) Analysis': 844,
#  'MKP (Mono Potassium Phosphate) Analysis (KEBS)': 26644,
#  'MKP Analysis': 628,
#  'MLND (ELISA)': 26658,
#  'Modified Morgan': 26519,
#  'Moisture': 795,
#  'Moisture Analysis': 26910,
#  'Moisture Content': 27013,
#  'Moisture content': 26580,
#  'Moisture Content %': 26906,
#  'Moisture in Sample': 1022,
#  'Moisture in sluge': 27234,
#  'Molybdate Analysis': 118,
#  'Molybdenum': 26571,
#  'Molybdenum Analysis': 27283,
#  'Molybdenum in Plant': 233,
#  'Monilinia spp': 27488,
#  'Mono Ammonium Phosphate(MAP)': 478,
#  'Mono Potassium Phosphate': 871,
#  'Mono Potassium Phosphate( MKP)': 479,
#  'Mono-Ammonium Phosphate': 73,
#  'Mono-Potassium Phosphate Analysis': 67,
#  'Monocalcium Phosphate (MCP) Analysis': 27240,
#  'MOP (K) Analyais': 708,
#  'MOP (K) Analysis  (KEBS)': 26645,
#  'MOP Analysis': 375,
#  'Morgan Extract': 359,
#  'Morgan P': 26564,
#  'Most Probable Number': 123,
#  'Mould Analysis': 26697,
#  'Multi-element & HM Fert Analysis': 587,
#  'Multiphos': 27162,
#  'Munsell soil colour': 26683,
#  'Mycorrhiza': 27279,
#  'N Fertilizer Analysis ( %N)': 586,
#  'N,P,K,Mg Fertilizer Analysis': 612,
#  'NEMA 10th Recreational Water Quality': 26950,
#  'NEMA 1st & 2nd  Domestic Water Quality': 468,
#  'NEMA 4th Steam Electric Power Gen Industry': 27158,
#  'NEMA 5th Basic Effluent into Public Sewer': 470,
#  'NEMA 5th Effluent into Public Sewer': 679,
#  'NEMA 6th & 4th Tea/Coffee Industry': 26715,
#  'NEMA 6th Treated Effluent into Environment': 26567,
#  'NEMA 8th Wastewater for Irrigation': 26951,
#  'NEMA 9th Irrigation Water Quality': 469,
#  'NEMA Basic Effluent into Environment': 388,
#  'NEMA Basic Effluent into Environment (High halide)': 26695,
#  'NEMA Basic Effluent into Environment-without micros': 26779,
#  'NEMA Comp Effluent into Environment': 389,
#  'NEMA Comp Effluent into Environment (CES 328)': 27271,
#  'NEMA Comp Effluent into Environment -without Micros': 26662,
#  'NEMA Drinking Water Analysis': 291,
#  'NEMA Efluent Water Analysis': 292,
#  'NEMA Irrigation Water Analysis': 290,
#  'Nematode': 381,
#  'Nematode Analysis (Compost)': 631,
#  'Nematode analysis (Media)': 596,
#  'Nematode Analysis (Plant Tissue)': 597,
#  'Nematode Analysis (Soil)': 594,
#  'Nematode Analysis (Water)': 595,
#  'Nematode Analysis in Plant (Tobacco)': 27408,
#  'Nematode Analysis in Soil (Tobacco)': 27406,
#  'Nematode Scan': 757,
#  'Nematodes in Compost': 884,
#  'Nematodes in Compost/Manure': 702,
#  'Nematodes in Media': 142,
#  'Nematodes in Plant': 881,
#  'Nematodes in Plant Tissue': 114,
#  'Nematodes in Soil': 880,
#  'Nematodes in Water': 102,
#  'NETAFIM Water Analysis': 657,
#  'Neutral Detergent Fibre': 26543,
#  'Neutral Detergent Fibre (NDF)': 27064,
#  'New Formulation Analysis': 316,
#  'Nickel': 496,
#  'Nickel Analysis': 27428,
#  'Nickel analysis': 26969,
#  'NIR scanning (spectra only)': 26735,
#  'NIR Soil Scan': 26982,
#  'Nitrate and Ammonium (KCl) in Soil': 26604,
#  'Nitrates': 27070,
#  'Nitrates Analysis': 27481,
#  'Nitrates in Plant': 611,
#  'Nitrates in Soil': 643,
#  'Nitrates in soil': 27159,
#  'Nitrates in Water': 313,
#  'Nitric Acid': 26598,
#  'Nitrite Analysis': 206,
#  'Nitrite Analysis (Water)': 186,
#  'Nitrite in Water': 309,
#  'Nitrites Analysis': 27482,
#  'Nitrites in soil': 27160,
#  'Nitrogen Analysis': 506,
#  'Nitrogen in Plant': 557,
#  'Nitrogen Phosphorus Potassium ( 25:5:5)': 137,
#  'NPK (%N, %P, %K) Analysis': 584,
#  'NPK (12:52:05)': 620,
#  'NPK (17:17:17)': 617,
#  'NPK (19:19:19)': 618,
#  'NPK (20:10:10)': 619,
#  'NPK (N, P2O5, K2O) Analysis': 787,
#  'NPK (N,P205,K20) Analysis': 778,
#  'NPK + S + Ca + Mg Analysis': 852,
#  'NPK + S Analysis': 853,
#  'NPK Analysis': 27495,
#  'NPK Analysis (KEBS)': 27328,
#  'NPK Blend (N, P2O5, K2O, Urea) Analysis': 924,
#  'NPK Compound (N, P2O5, K2O) Analysis': 839,
#  'NPK in Feed': 27413,
#  'NPK in food': 27387,
#  'NPK(14:14:20)': 655,
#  'Nutrichem Combi Analysis': 61,
#  'Nutrient Mapping in Soil': 92,
#  'Nutritional Analysis (Wetchem)': 26900,
#  'Nutritional Analysis Feed (Wetchem)': 26901,
#  'Nutritional Analysis Forage (Wetchem)': 26903,
#  'Nutritional Analysis Milled Flour (Wetchem)': 26965,
#  'Nutritional Value (EU)': 26709,
#  'OAF Wet Chemistry Soil Analysis': 26606,
#  'Ochratoxin A': 27470,
#  'Ochratoxin Screening': 26688,
#  'Odour': 27468,
#  'Oil': 26725,
#  'Oil & Grease': 326,
#  'Oil and Grease': 125,
#  'Oil in Seed': 26651,
#  'Oil Seed Analysis': 26897,
#  'Olsen P in Soil': 697,
#  'OM Fractionation': 676,
#  'Organic Carbon': 27505,
#  'Organic Carbon & Total N (Wetchem)': 27213,
#  'Organic Carbon analysis': 27165,
#  'Organic Matter': 367,
#  'Organic Matter % (OM)': 230,
#  'Organic Matter (%) in Soil': 219,
#  'Organic Matter Analysis': 950,
#  'Organic Nitrogen': 27175,
#  'Ortho-Phosphate Analysis': 26609,
#  'Oxalate Extractable Al, Fe & P': 26757,
#  'P-Sorption': 548,
#  'Papaya Mosaic Virus (ELISA)': 26618,
#  'Paramagnetism(PCM)': 26518,
#  'paraquat+diquat': 26833,
#  'Particle Size': 27182,
#  'Particle Size (0.3-2mm)': 26853,
#  'Particle Size (0.5-0.6mm)': 27301,
#  'Particle Size (1-4mm)': 27438,
#  'Particle Size (2-4mm)': 925,
#  'Particle Size (2-5mm)': 27290,
#  'Particle Size (8 sieves)': 27109,
#  'Particle size <0.075mm': 26747,
#  'Particle size <0.15mm': 26743,
#  'Particle Size <0.18mm': 27421,
#  'Particle size <0.3mm': 26854,
#  'Particle size <2.0 mm': 27227,
#  'Particle size 0.075mm-0.18mm': 26746,
#  'Particle size 0.3 mm - 0.15 mm': 26744,
#  'Particle size 0.3mm-2.00mm': 27294,
#  'Particle Size 1mm - 0.3 mm': 26745,
#  'Particle size 2.0 mm - 4.0 mm': 27222,
#  'Particle Size Analysis': 177,
#  'Particle Size Analysis (RSSP 2)': 649,
#  'Particle Size Analysis(Hydrometer Method)': 569,
#  'Particle Size Distribution': 27315,
#  'Particle Size of Sample': 1031,
#  'Path Scan': 758,
#  'Pathology Analysis (Media)': 547,
#  'Pathology Analysis (Plant)': 85,
#  'Pathology Analysis (Soil)': 545,
#  'Pathology Analysis (Water)': 546,
#  'Pathology testing without Ralstonia': 26886,
#  'Patulin': 26624,
#  'Peanuts Mycotoxins': 27400,
#  'Pectobacterium & Dickeya': 27249,
#  'Pek Acid (P2O5,K) Analysis': 747,
#  'Pek Acid Analysis': 630,
#  'Peroxide value': 27437,
#  'Peroxide Value': 26914,
#  'Pesticide Residue (GC & LC-MS)': 962,
#  'Pesticide Residue Analysis (GC & LC-MS)': 27493,
#  'Pesticide Residue Analysis (SGS)': 88,
#  'Pesticide Residue Analysis (Soil)': 196,
#  'Pesticide Residue Analysis (Water)': 87,
#  'Pesticide Residue Analysis GC-MS Analysis': 520,
#  'Pesticide Residue GC-MS + LC-MS': 521,
#  'Pesticide Residue GC-MS + LC-MS (Water)': 577,
#  'Pesticide Residue GC-MS Analysis (Plant)': 152,
#  'Pesticide Residue in feed (GC & LC-MS)': 27041,
#  'Pesticide Residue in food (GC & LC-MS)': 27190,
#  'Pesticide Residue in water (GC & LC-MS)': 26836,
#  'Pesticide Residue LC-MS Analysis (Plant)': 432,
#  'pH': 27077,
#  'pH & EC': 632,
#  'pH & Electrical Conductivity Analysis': 380,
#  'pH (1%)': 969,
#  'pH Analysis': 27016,
#  'pH in Food': 27057,
#  'pH in Water': 149,
#  'pH of Sample': 1010,
#  'pH, EC & Sodium Analysis': 342,
#  'pH, EC & Sodium Analysis (drain)': 384,
#  'pH, EC & Sodium Analysis (Substrate)': 282,
#  'Phenols': 419,
#  'Phenols Analysis': 715,
#  'Phosethyl-aluminum + phosphonic acid': 26717,
#  'Phosphate Analysis': 684,
#  'Phosphates in Water': 722,
#  'Phosphoric Acid (H3PO4) Analysis': 857,
#  'Phosphorus': 26581,
#  'Phosphorus (Bray1-Sensor)': 26716,
#  'Phosphorus (Mehlich1)': 27178,
#  'Phosphorus Analysis': 192,
#  'Phosphorus in Plant': 558,
#  'Phosphorus in Water': 327,
#  'Phosphorus Sorption Index (PSI)': 626,
#  'Physical Specs': 26856,
#  'Physical Test': 27087,
#  'Phytophthora': 109,
#  'Phytophthora (ELISA)': 26608,
#  'Pig Food Heavy Metals EAS 55 2019': 27024,
#  'PK Analysis': 27286,
#  'Plant Bacterial Pathogen Screen': 913,
#  'Plant Carbohydrates': 27322,
#  'Plant Elemental Extraction': 556,
#  'Plant Fungal Bacteria Ratio': 27377,
#  'Plant Fungal Pathogen Screen': 912,
#  'Plant N, P, K': 515,
#  'Plant N, P, K, Ca,S & Mg': 516,
#  'Plant N, P, K, Ca,S, Mg + Micros': 517,
#  'Plant Pathology': 599,
#  'Plant Pathology Analysis': 116,
#  'Plant Pathology Test': 886,
#  'Plant Pesticide Residue Analysis (SGS)': 86,
#  'Plant preparation (Milling)': 26734,
#  'Plastisizers': 27164,
#  'Polycyclic aromatic hydrocarbons (PAHs)': 27048,
#  'Polyfeed 17:17:17 Analysis': 77,
#  'Polyfeed 19:19:19 Analysis': 76,
#  'Polysulphate': 27147,
#  'Post Harvest Water Analysis': 902,
#  'Post Harvest Water Analysis without micros': 26714,
#  'Potassium Analysis': 448,
#  'Potassium analysis': 404,
#  'Potassium Chloride Analysis': 361,
#  'Potassium in Plant': 560,
#  'Potassium in Water': 349,
#  'Potassium Nitrate': 476,
#  'Potassium Nitrate Analysis': 846,
#  'Potassium Sulphate': 477,
#  'Potassium Sulphate  Analysis': 7,
#  'Potassium Sulphate Analysis': 624,
#  'Potassium Sulphate Nitrite': 286,
#  'Potato Cyst (PCN) in Soil': 26638,
#  'Potato Cyst (PCN) in Water': 26636,
#  'Potato Cyst (PCN) on Tubers': 26637,
#  'Potato Seed LAMP Assay Bacterial Wilt (Rs)': 26920,
#  'Potato virus X (PVX) (ELISA)': 26821,
#  'Potato virus Y (PVY) (ELISA)': 26788,
#  'Potential acidity': 27177,
#  'Potphos Analysis': 300,
#  'Potphos/Elphos Analysis': 299,
#  'Potyvirus Group Test (ELISA)': 26822,
#  'Pratylenchus': 27046,
#  'Premix Analysis': 133,
#  'Protein analysis': 27133,
#  'Proximate Analysis (NIR & Wetchem)': 26623,
#  'Proximate Analysis Milled Flour (NIR)': 26888,
#  'Proximate Analysis on Dry Feed (NIR)': 760,
#  'Proximate analysis on flour': 26890,
#  'PSA (RSSP 2)': 653,
#  'Pseudomonas Aeruginosa': 27072,
#  'Pseudomonas aeruginosa': 27409,
#  'Pure Pesticide': 26972,
#  'Purity Check % Weight': 26908,
#  'Pyrrolizidine alkaloids': 27251,
#  'Pythium': 110,
#  'Pythium Screening': 27291,
#  'QAC Analysis': 26669,
#  'Quaternary Ammonium compounds (DDAC/BAC)': 26912,
#  'Ralstonia (ELISA)': 26611,
#  'Ralstonia LAMP Assay Seed Potatoes': 26885,
#  'Ralstonia solanacearum': 26529,
#  'Raw (Domestic) Water Analysis': 27183,
#  'Raw irrigation water analysis (for fertigation)': 26823,
#  'Raw Water Analysis': 658,
#  'Reactive Carbon': 811,
#  'Reactive Silica Analysis': 185,
#  'Reagent Water Analysis': 26686,
#  'Recycle Water Analysis': 890,
#  'Relative Density': 27386,
#  'Residue after Evaporation': 26935,
#  'Reverse Osmosis Water Use': 324,
#  'Rhizobia': 274,
#  'Rhizoctonia': 108,
#  'Rhodium': 405,
#  'Rhodococcus fascians': 27128,
#  'Rice Aflatoxins': 27393,
#  'Rock Phospate Analysis': 373,
#  'Rock Phosphate Analysis': 659,
#  'Root Knot nematodes (Meloidogyne)': 27045,
#  'Rosasol Even 20.20.20. Analysis': 163,
#  'Rosasol P 10.50.10 Analysis': 162,
#  'Routine Soil Analysis - Sugar Sector (data only)': 27313,
#  'Routine Soil Chemistry Analysis': 27316,
#  'Routine Soil Chemistry Analysis (Alkaline)': 27318,
#  'Routine Soil Chemistry Analysis_2': 27511,
#  'Routine Top Soil Analysis (Sugarcane)': 27189,
#  'Ruthenium': 406,
#  'Sadcmet Water PT Anions Analysis': 640,
#  'Sadcmet Water PT Cations Analysis': 641,
#  'Salmonella': 27119,
#  'Salmonella & E Coli Test': 26553,
#  'Salmonella and E.Coli': 27274,
#  'Salmonella and E.coli (Compost/Manure)': 145,
#  'Salmonella and E.Coli (Water)': 144,
#  'Salmonella sp': 242,
#  'Salmonella spp': 27458,
#  'Salmonella ssp': 26707,
#  'Salt Crystal Mineral Analysis': 208,
#  'Sample digestion': 26776,
#  'Sample preparation (Crushing)': 26677,
#  'Saponification value': 27006,
#  'Saturated Fat': 27300,
#  'Saturated Soil Paste Extract': 939,
#  'Seed Fungal Pathogen Screen': 26907,
#  'Seed germination': 26889,
#  'Seed Germination Tests': 26884,
#  'Seed Layer test': 26909,
#  'Seed Testing Human Pathogens': 27047,
#  'Seed viability testing': 27403,
#  'Selected elements (ICP) Analysis': 26732,
#  'Selected ICP Elements': 27372,
#  'Selenium': 407,
#  'Selenium Analysis': 27060,
#  'Selenium in Dry Feed': 26905,
#  'Selenium in Plant': 566,
#  'Selenium in Water': 935,
#  'Settleable Solids': 420,
#  'Shigella spp': 27363,
#  'Silicon Analysis': 730,
#  'Silicon Analysis in Compost/Manure': 896,
#  'Silicon in Plant': 830,
#  'Silicon in Water': 428,
#  'Silver': 408,
#  'Silver analysis': 195,
#  'Silver Analysis': 701,
#  'Silver in Plant': 923,
#  'Silver in Water': 27120,
#  'Single parameter GC': 26978,
#  'Single parameter LC': 26979,
#  'Single Super Phosphate (SSP) Analysis': 26665,
#  'Sludge Content': 26993,
#  'Soap Analysis': 372,
#  'Soap Content': 26974,
#  ...}

# %%
for analysis in reverse_analysis_dict.copy().keys():
    if ":" in analysis:
        reverse_analysis_dict[analysis.replace(":","")] = reverse_analysis_dict[analysis]

# %%
new_samples = pd.read_sql(f"SELECT sample_code, batch_date, result, unit_name, chemical_name, analysis_name FROM SampleResults WHERE sample_code IN {tuple(new_samples_df.sample_code.values)}", con=conn_lims)
# Out:
# C:\Users\tsuma.thomas\AppData\Local\Temp\ipykernel_11632\1881003016.py:1: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   new_samples = pd.read_sql(f"SELECT sample_code, batch_date, result, unit_name, chemical_name, analysis_name FROM SampleResults WHERE sample_code IN {tuple(new_samples_df.sample_code.values)}", con=conn_lims)

# %%
new_samples = new_samples.dropna(subset=['chemical_name','result','analysis_name'])
new_samples['analysis_name'] = [ str(i).replace(":","").split(",") for i in new_samples.analysis_name ]
new_samples = new_samples.explode("analysis_name")

# %%
new_samples['result'] = [ str(i).replace("<","").replace(">","").strip() for i in new_samples['result'] ]

# %%
new_samples.loc[(new_samples['result'] == "ND"), "result" ] = 0

# %%
new_samples = new_samples.loc[~(new_samples['result'] == "Detected") ]

# %%
new_samples['unit_name'] = [ str(i).strip() for i in new_samples['unit_name'].values ]

# %%
new_samples['chemical_name'] = [ str(i).lower().replace(" ","_").replace("(","").replace(")","").replace(".","").strip() for i in new_samples['chemical_name'].values ]

# %%
new_samples['result'] = new_samples['result'].astype(float)

# %%
test = []
for sample in new_samples.sample_code.unique():
    res = {}
    tmp_ = new_samples.loc[new_samples.sample_code == sample]
    res['sample_code'] = sample
    print([ i for i in tmp_.analysis_name.unique() ])
    res['analysis_id'] = [ reverse_analysis_dict[i] for i in tmp_.analysis_name.unique() if i in reverse_analysis_dict.keys() ]
    for index,row in tmp_.iterrows():
        if row['result'] >= 0 :
            res[row['chemical_name']] = {'result': row['result'], 'units': str(row['unit_name'])}
        else:
            res[row['chemical_name']] = {'result': 0, 'units': row['unit_name']}
    test.append(res)
# Out:
# ['12 Soil Volume Extract']
# ['12 Soil Volume Extract']
# ['12 Soil Volume Extract']
# ['12 Soil Volume Extract']
# ['12 Soil Volume Extract']
# ['12 Soil Volume Extract']
# ['12 Soil Volume Extract']
# ['12 Soil Volume Extract']
# ['12 Soil Volume Extract']
# ['12 Soil Volume Extract']
# ['Drip Water Analysis']
# ['Drip Water Analysis']
# ['12 Soil Volume Extract']
# ['12 Soil Volume Extract']
# ['12 Soil Volume Extract']
# ['12 Soil Volume Extract']
# ['Drip Water Analysis']
# ['12 Soil Volume Extract']
# ['12 Soil Volume Extract']
# ['12 Soil Volume Extract']
# ['12 Soil Volume Extract']
# ['12 Soil Volume Extract']
# ['12 Soil Volume Extract']
# ['12 Soil Volume Extract']
# ['12 Soil Volume Extract']
# ['Drip Water Analysis']
# ['Drip Water Analysis']
# ['12 Soil Volume Extract']
# ['12 Soil Volume Extract']
# ['Drip Water Analysis']
# ['12 Soil Volume Extract']
# ['12 Soil Volume Extract']
# ['12 Soil Volume Extract']
# ['12 Soil Volume Extract']
# ['Drip Water Analysis']
# ['12 Soil Volume Extract']
# ['Drip Water Analysis']
# ['12 Soil Volume Extract']
# ['12 Soil Volume Extract']
# ['12 Soil Volume Extract']
# ['12 Soil Volume Extract']
# ['Drip Water Analysis']
# ['Drip Water Analysis']
# ['Drip Water Analysis']
# ['Drip Water Analysis']
# ['12 Soil Volume Extract']
# ['12 Soil Volume Extract']
# ['12 Soil Volume Extract']
# ['12 Soil Volume Extract']
# ['12 Soil Volume Extract']
# ['12 Soil Volume Extract']
# ['12 Soil Volume Extract']
# ['12 Soil Volume Extract']
# ['12 Soil Volume Extract']
# ['12 Soil Volume Extract']
# ['12 Soil Volume Extract']
# ['12 Soil Volume Extract']
# ['12 Soil Volume Extract']
# ['12 Soil Volume Extract']
# ['12 Soil Volume Extract']
# ['12 Soil Volume Extract']
# ['12 Soil Volume Extract']
# ['12 Soil Volume Extract']
# ['12 Soil Volume Extract']
# ['12 Soil Volume Extract']
# ['12 Soil Volume Extract']
# ['12 Soil Volume Extract']
# ['12 Soil Volume Extract']
# ['Raw irrigation water analysis (for fertigation)']
# ['12 Soil Volume Extract']
# ['12 Soil Volume Extract']
# ['12 Soil Volume Extract']
# ['12 Soil Volume Extract']
# ['12 Soil Volume Extract']
# ['12 Soil Volume Extract']
# ['12 Soil Volume Extract']
# ['Drip Water Analysis']
# ['Drip Water Analysis']
# ['12 Soil Volume Extract']
# ['12 Soil Volume Extract']
# ['12 Soil Volume Extract']
# ['Drip Water Analysis']
# ['Drip Water Analysis']
# ['Drip Water Analysis']
# ['12 Soil Volume Extract']
# ['12 Soil Volume Extract']
# ['Drip Water Analysis']
# ['Drip Water Analysis']
# ['Drip Water Analysis']
# ['12 Soil Volume Extract']
# ['12 Soil Volume Extract']
# ['12 Soil Volume Extract']
# ['12 Soil Volume Extract']
# ['Drip Water Analysis']
# ['Drip Water Analysis']
# ['Drip Water Analysis']
# ['Drip Water Analysis']
# ['12 Soil Volume Extract']
# ['12 Soil Volume Extract']
# ['Drip Water Analysis']
# ['12 Soil Volume Extract']
# ['Drip Water Analysis']
# ['12 Soil Volume Extract']
# ['Drip Water Analysis']
# ['Drip Water Analysis']
# ['Drip Water Analysis']
# ['Drip Water Analysis']
# ['12 Soil Volume Extract']
# ['Raw irrigation water analysis (for fertigation)']
# ['12 Soil Volume Extract']
# ['12 Soil Volume Extract']
# ['12 Soil Volume Extract']
# ['12 Soil Volume Extract']
# ['12 Soil Volume Extract']
# ['12 Soil Volume Extract']
# ['12 Soil Volume Extract']
# ['12 Soil Volume Extract']
# ['12 Soil Volume Extract']
# ['12 Soil Volume Extract']
# ['12 Soil Volume Extract']
# ['12 Soil Volume Extract']
# ['Drip Water Analysis']
# ['Drip Water Analysis']
# ['12 Soil Volume Extract']
# ['12 Soil Volume Extract']
# ['12 Soil Volume Extract']
# ['12 Soil Volume Extract']
# ['12 Soil Volume Extract']
# ['12 Soil Volume Extract']
# ['12 Soil Volume Extract']
# ['12 Soil Volume Extract']
# ['12 Soil Volume Extract']
# ['12 Soil Volume Extract']
# ['Drip Water Analysis']
# ['12 Soil Volume Extract']
# ['Drip Water Analysis']
# ['Drip Water Analysis']
# ['Drip Water Analysis']
# ['12 Soil Volume Extract']
# ['12 Soil Volume Extract']
# ['12 Soil Volume Extract']
# ['Drip Water Analysis']
# ['Drip Water Analysis']
# ['Drip Water Analysis']
# ['Raw irrigation water analysis (for fertigation)']
# ['12 Soil Volume Extract']
# ['12 Soil Volume Extract']
# ['12 Soil Volume Extract']
# ['12 Soil Volume Extract']
# ['12 Soil Volume Extract']
# ['12 Soil Volume Extract']
# ['12 Soil Volume Extract']
# ['12 Soil Volume Extract']
# ['12 Soil Volume Extract']
# ['12 Soil Volume Extract']
# ['12 Soil Volume Extract']
# ['12 Soil Volume Extract']
# ['12 Soil Volume Extract']
# ['12 Soil Volume Extract']
# ['12 Soil Volume Extract']
# ['12 Soil Volume Extract']
# ['12 Soil Volume Extract']
# ['Raw irrigation water analysis (for fertigation)']
# ['12 Soil Volume Extract']
# ['12 Soil Volume Extract']
# ['12 Soil Volume Extract']
# ['12 Soil Volume Extract']
# ['12 Soil Volume Extract']
# ['12 Soil Volume Extract']
# ['12 Soil Volume Extract']
# ['12 Soil Volume Extract']
# ['12 Soil Volume Extract']
# ['12 Soil Volume Extract']
# ['12 Soil Volume Extract']
# ['12 Soil Volume Extract']
# ['12 Soil Volume Extract']
# ['12 Soil Volume Extract']
# ['Drip Water Analysis']
# ['12 Soil Volume Extract']
# ['12 Soil Volume Extract']
# ['12 Soil Volume Extract']
# ['12 Soil Volume Extract']
# ['12 Soil Volume Extract']
# ['12 Soil Volume Extract']
# ['12 Soil Volume Extract']
# ['12 Soil Volume Extract']
# ['12 Soil Volume Extract']
# ['12 Soil Volume Extract']
# ['Drip Water Analysis']
# ['12 Soil Volume Extract']
# ['12 Soil Volume Extract']
# ['12 Soil Volume Extract']
# ['12 Soil Volume Extract']
# ['12 Soil Volume Extract']
# ['12 Soil Volume Extract']
# ['12 Soil Volume Extract']
# ['12 Soil Volume Extract']
# ['12 Soil Volume Extract']
# ['12 Soil Volume Extract']
# ['12 Soil Volume Extract']
# ['12 Soil Volume Extract']
# ['12 Soil Volume Extract']
# ['12 Soil Volume Extract']
# ['12 Soil Volume Extract']
# ['12 Soil Volume Extract']
# ['12 Soil Volume Extract']
# ['Raw irrigation water analysis (for fertigation)']
# ['12 Soil Volume Extract']
# ['Drip Water Analysis']
# ['Drip Water Analysis']
# ['Drip Water Analysis']
# ['Drip Water Analysis']
# ['Drip Water Analysis']
# ['Drip Water Analysis']
# ['12 Soil Volume Extract']
# ['12 Soil Volume Extract']
# ['Raw irrigation water analysis (for fertigation)']
# ['12 Soil Volume Extract']
# ['12 Soil Volume Extract']
# ['12 Soil Volume Extract']
# ['12 Soil Volume Extract']
# ['12 Soil Volume Extract']
# ['12 Soil Volume Extract']
# ['12 Soil Volume Extract']
# ['12 Soil Volume Extract']
# ['12 Soil Volume Extract']
# ['12 Soil Volume Extract']
# ['12 Soil Volume Extract']
# ['12 Soil Volume Extract']
# ['12 Soil Volume Extract']
# ['12 Soil Volume Extract']
# ['12 Soil Volume Extract']
# ['12 Soil Volume Extract']
# ['12 Soil Volume Extract']
# ['12 Soil Volume Extract']
# ['12 Soil Volume Extract']
# ['12 Soil Volume Extract']
# ['Raw irrigation water analysis (for fertigation)']
# ['12 Soil Volume Extract']
# ['12 Soil Volume Extract']
# ['Drip Water Analysis']
# ['Drip Water Analysis']
# ['Drip Water Analysis']
# ['12 Soil Volume Extract']
# ['Drip Water Analysis']
# ['Drip Water Analysis']
# ['Drip Water Analysis']
# ['Drip Water Analysis']
# ['Drip Water Analysis']
# ['Drip Water Analysis']
# ['Drip Water Analysis']
# ['Drip Water Analysis']
# ['Drip Water Analysis']
# ['Drip Water Analysis']
# ['Raw irrigation water analysis (for fertigation)']
# ['12 Soil Volume Extract']
# ['12 Soil Volume Extract']
# ['12 Soil Volume Extract']
# ['12 Soil Volume Extract']
# ['Drip Water Analysis']
# ['Drip Water Analysis']
# ['12 Soil Volume Extract']
# ['12 Soil Volume Extract']
# ['12 Soil Volume Extract']
# ['Drip Water Analysis']
# ['12 Soil Volume Extract']
# ['12 Soil Volume Extract']
# ['12 Soil Volume Extract']
# ['Drip Water Analysis']
# ['12 Soil Volume Extract']
# ['12 Soil Volume Extract']
# ['12 Soil Volume Extract']
# ['12 Soil Volume Extract']
# ['12 Soil Volume Extract']
# ['12 Soil Volume Extract']
# ['Raw irrigation water analysis (for fertigation)']
# ['12 Soil Volume Extract']
# ['12 Soil Volume Extract']
# ['12 Soil Volume Extract']
# ['12 Soil Volume Extract']
# ['Drip Water Analysis']
# ['Drip Water Analysis']
# ['Drip Water Analysis']
# ['Drip Water Analysis']
# ['Drip Water Analysis']
# ['Drip Water Analysis']
# ['Drip Water Analysis']
# ['Drip Water Analysis']
# ['Drip Water Analysis']
# ['Drip Water Analysis']
# ['Raw irrigation water analysis (for fertigation)']
# ['Drip Water Analysis']
# ['Drip Water Analysis']
# ['12 Soil Volume Extract']
# ['12 Soil Volume Extract']
# ['12 Soil Volume Extract']
# ['Drip Water Analysis']
# ['Drip Water Analysis']
# ['12 Soil Volume Extract']
# ['12 Soil Volume Extract']
# ['Drip Water Analysis']
# ['12 Soil Volume Extract']
# ['Drip Water Analysis']
# ['Drip Water Analysis']
# ['12 Soil Volume Extract']
# ['Drip Water Analysis']
# ['Drip Water Analysis']
# ['Drip Water Analysis']
# ['12 Soil Volume Extract']
# ['12 Soil Volume Extract']
# ['Drip Water Analysis']
# ['Drip Water Analysis']
# ['12 Soil Volume Extract']
# ['12 Soil Volume Extract']
# ['12 Soil Volume Extract']
# ['12 Soil Volume Extract']
# ['12 Soil Volume Extract']
# ['Drip Water Analysis']
# ['Drip Water Analysis']
# ['Drip Water Analysis']
# ['Raw irrigation water analysis (for fertigation)']
# ['12 Soil Volume Extract']
# ['12 Soil Volume Extract']
# ['12 Soil Volume Extract']
# ['Drip Water Analysis']
# ['12 Soil Volume Extract']
# ['Drip Water Analysis']
# ['Drip Water Analysis']
# ['12 Soil Volume Extract']
# ['Drip Water Analysis']
# ['12 Soil Volume Extract']
# ['Drip Water Analysis']
# ['12 Soil Volume Extract']
# ['12 Soil Volume Extract']
# ['Drip Water Analysis']
# ['Drip Water Analysis']
# ['Drip Water Analysis']
# ['12 Soil Volume Extract']
# ['Drip Water Analysis']
# ['12 Soil Volume Extract']
# ['Drip Water Analysis']
# ['12 Soil Volume Extract']
# ['Drip Water Analysis']
# ['12 Soil Volume Extract']
# ['12 Soil Volume Extract']
# ['Drip Water Analysis']
# ['Drip Water Analysis']
# ['12 Soil Volume Extract']
# ['Drip Water Analysis']
# ['Drip Water Analysis']
# ['Drip Water Analysis']
# ['12 Soil Volume Extract']
# ['Drip Water Analysis']
# ['Drip Water Analysis']
# ['Drip Water Analysis']
# ['Raw irrigation water analysis (for fertigation)']
# ['12 Soil Volume Extract']
# ['Drip Water Analysis']
# ['Drip Water Analysis']
# ['Raw irrigation water analysis (for fertigation)']
# ['12 Soil Volume Extract']
# ['12 Soil Volume Extract']
# ['12 Soil Volume Extract']
# ['12 Soil Volume Extract']
# ['12 Soil Volume Extract']
# ['12 Soil Volume Extract']
# ['12 Soil Volume Extract']
# ['12 Soil Volume Extract']
# ['12 Soil Volume Extract']
# ['12 Soil Volume Extract']
# ['12 Soil Volume Extract']
# ['12 Soil Volume Extract']
# ['12 Soil Volume Extract']
# ['12 Soil Volume Extract']
# ['12 Soil Volume Extract']
# ['12 Soil Volume Extract']
# ['12 Soil Volume Extract']
# ['12 Soil Volume Extract']
# ['12 Soil Volume Extract']
# ['12 Soil Volume Extract']
# ['12 Soil Volume Extract']
# ['12 Soil Volume Extract']
# ['12 Soil Volume Extract']
# ['12 Soil Volume Extract']
# ['12 Soil Volume Extract']
# ['12 Soil Volume Extract']
# ['12 Soil Volume Extract']
# ['12 Soil Volume Extract']
# ['12 Soil Volume Extract']
# ['12 Soil Volume Extract']
# ['12 Soil Volume Extract']
# ['12 Soil Volume Extract']
# ['12 Soil Volume Extract']
# ['12 Soil Volume Extract']
# ['12 Soil Volume Extract']
# ['12 Soil Volume Extract']
# ['12 Soil Volume Extract']
# ['12 Soil Volume Extract']
# ['12 Soil Volume Extract']
# ['12 Soil Volume Extract']
# ['12 Soil Volume Extract']
# ['12 Soil Volume Extract']
# ['12 Soil Volume Extract']
# ['12 Soil Volume Extract']
# ['12 Soil Volume Extract']
# ['12 Soil Volume Extract']
# ['12 Soil Volume Extract']
# ['12 Soil Volume Extract']
# ['Drip Water Analysis']
# ['12 Soil Volume Extract']
# ['Drip Water Analysis']
# ['Drip Water Analysis']
# ['Drip Water Analysis']
# ['Drip Water Analysis']
# ['Drip Water Analysis']
# ['Drip Water Analysis']
# ['Drip Water Analysis']
# ['Drip Water Analysis']
# ['Drip Water Analysis']
# ['Drip Water Analysis']
# ['Drip Water Analysis']
# ['Drip Water Analysis']
# ['Drip Water Analysis']
# ['Drip Water Analysis']
# ['Drip Water Analysis']
# ['Drip Water Analysis']
# ['Raw irrigation water analysis (for fertigation)']
# ['Raw irrigation water analysis (for fertigation)']
# ['12 Soil Volume Extract']
# ['12 Soil Volume Extract']
# ['Drip Water Analysis']
# ['Drip Water Analysis']
# ['12 Soil Volume Extract']
# ['12 Soil Volume Extract']
# ['12 Soil Volume Extract']
# ['12 Soil Volume Extract']
# ['12 Soil Volume Extract']
# ['Drip Water Analysis']
# ['Drip Water Analysis']
# ['12 Soil Volume Extract']
# ['Drip Water Analysis']
# ['Drip Water Analysis']
# ['12 Soil Volume Extract']
# ['12 Soil Volume Extract']
# ['Drip Water Analysis']
# ['12 Soil Volume Extract']
# ['Drip Water Analysis']
# ['Drip Water Analysis']
# ['Drip Water Analysis']
# ['Drip Water Analysis']
# ['Drip Water Analysis']
# ['12 Soil Volume Extract']
# ['12 Soil Volume Extract']
# ['12 Soil Volume Extract']
# ['12 Soil Volume Extract']
# ['12 Soil Volume Extract']
# ['Raw irrigation water analysis (for fertigation)']
# ['12 Soil Volume Extract']
# ['12 Soil Volume Extract']
# ['12 Soil Volume Extract']
# ['12 Soil Volume Extract']
# ['12 Soil Volume Extract']
# ['12 Soil Volume Extract']
# ['12 Soil Volume Extract']
# ['12 Soil Volume Extract']
# ['12 Soil Volume Extract']
# ['12 Soil Volume Extract']
# ['12 Soil Volume Extract']
# ['12 Soil Volume Extract']
# ['12 Soil Volume Extract']
# ['12 Soil Volume Extract']
# ['12 Soil Volume Extract']
# ['12 Soil Volume Extract']
# ['12 Soil Volume Extract']
# ['12 Soil Volume Extract']
# ['12 Soil Volume Extract']
# ['12 Soil Volume Extract']
# ['12 Soil Volume Extract']
# ['12 Soil Volume Extract']
# ['12 Soil Volume Extract']
# ['Drip Water Analysis']
# ['12 Soil Volume Extract']
# ['12 Soil Volume Extract']
# ['12 Soil Volume Extract']
# ['Drip Water Analysis']
# ['12 Soil Volume Extract']
# ['12 Soil Volume Extract']
# ['12 Soil Volume Extract']
# ['12 Soil Volume Extract']
# ['12 Soil Volume Extract']
# ['Drip Water Analysis']
# ['Drip Water Analysis']
# ['Drip Water Analysis']
# ['Drip Water Analysis']
# ['12 Soil Volume Extract']
# ['12 Soil Volume Extract']
# ['Drip Water Analysis']
# ['12 Soil Volume Extract']
# ['12 Soil Volume Extract']
# ['Drip Water Analysis']
# ['Drip Water Analysis']
# ['12 Soil Volume Extract']
# ['Drip Water Analysis']
# ['Drip Water Analysis']
# ['12 Soil Volume Extract']
# ['12 Soil Volume Extract']
# ['Drip Water Analysis']
# ['Drip Water Analysis']
# ['Drip Water Analysis']
# ['12 Soil Volume Extract']
# ['12 Soil Volume Extract']
# ['Drip Water Analysis']
# ['12 Soil Volume Extract']
# ['Drip Water Analysis']
# ['12 Soil Volume Extract']
# ['Drip Water Analysis']
# ['Drip Water Analysis']
# ['12 Soil Volume Extract']
# ['Drip Water Analysis']
# ['12 Soil Volume Extract']
# ['Drip Water Analysis']
# ['12 Soil Volume Extract']
# ['Drip Water Analysis']
# ['12 Soil Volume Extract']
# ['Drip Water Analysis']
# ['Drip Water Analysis']
# ['12 Soil Volume Extract']
# ['12 Soil Volume Extract']
# ['12 Soil Volume Extract']
# ['12 Soil Volume Extract']
# ['12 Soil Volume Extract']
# ['Drip Water Analysis']
# ['Drip Water Analysis']
# ['12 Soil Volume Extract']
# ['12 Soil Volume Extract']
# ['12 Soil Volume Extract']
# ['12 Soil Volume Extract']
# ['Drip Water Analysis']
# ['Drip Water Analysis']
# ['12 Soil Volume Extract']
# ['12 Soil Volume Extract']
# ['12 Soil Volume Extract']
# ['Raw irrigation water analysis (for fertigation)']
# ['Raw irrigation water analysis (for fertigation)']
# ['12 Soil Volume Extract']
# ['12 Soil Volume Extract']
# ['12 Soil Volume Extract']
# ['12 Soil Volume Extract']
# ['12 Soil Volume Extract']
# ['12 Soil Volume Extract']
# ['12 Soil Volume Extract']
# ['12 Soil Volume Extract']
# ['12 Soil Volume Extract']
# ['12 Soil Volume Extract']
# ['12 Soil Volume Extract']
# ['12 Soil Volume Extract']
# ['12 Soil Volume Extract']
# ['12 Soil Volume Extract']
# ['12 Soil Volume Extract']
# ['12 Soil Volume Extract']
# ['12 Soil Volume Extract']
# ['12 Soil Volume Extract']
# ['12 Soil Volume Extract']
# ['12 Soil Volume Extract']
# ['12 Soil Volume Extract']
# ['Drip Water Analysis']
# ['Raw irrigation water analysis (for fertigation)']
# ['12 Soil Volume Extract']
# ['12 Soil Volume Extract']
# ['12 Soil Volume Extract']
# ['12 Soil Volume Extract']
# ['12 Soil Volume Extract']
# ['12 Soil Volume Extract']
# ['12 Soil Volume Extract']
# ['12 Soil Volume Extract']
# ['12 Soil Volume Extract']
# ['12 Soil Volume Extract']
# ['12 Soil Volume Extract']
# ['12 Soil Volume Extract']
# ['12 Soil Volume Extract']
# ['12 Soil Volume Extract']
# ['12 Soil Volume Extract']
# ['12 Soil Volume Extract']
# ['12 Soil Volume Extract']
# ['12 Soil Volume Extract']
# ['12 Soil Volume Extract']
# ['12 Soil Volume Extract']
# ['12 Soil Volume Extract']
# ['12 Soil Volume Extract']
# ['12 Soil Volume Extract']
# ['Drip Water Analysis']
# ['Drip Water Analysis']
# ['Drip Water Analysis']
# ['Raw irrigation water analysis (for fertigation)']
# ['12 Soil Volume Extract']
# ['12 Soil Volume Extract']
# ['12 Soil Volume Extract']
# ['12 Soil Volume Extract']
# ['12 Soil Volume Extract']
# ['12 Soil Volume Extract']
# ['Drip Water Analysis']
# ['Drip Water Analysis']
# ['Drip Water Analysis']
# ['Drip Water Analysis']
# ['Drip Water Analysis']
# ['Drip Water Analysis']
# ['Drip Water Analysis']
# ['Drip Water Analysis']
# ['Drip Water Analysis']
# ['Drip Water Analysis']
# ['Raw irrigation water analysis (for fertigation)']
# ['12 Soil Volume Extract']
# ['12 Soil Volume Extract']
# ['12 Soil Volume Extract']
# ['12 Soil Volume Extract']
# ['12 Soil Volume Extract']
# ['12 Soil Volume Extract']
# ['12 Soil Volume Extract']
# ['12 Soil Volume Extract']
# ['12 Soil Volume Extract']
# ['12 Soil Volume Extract']
# ['12 Soil Volume Extract']
# ['12 Soil Volume Extract']
# ['12 Soil Volume Extract']
# ['12 Soil Volume Extract']
# ['12 Soil Volume Extract']
# ['12 Soil Volume Extract']
# ['12 Soil Volume Extract']
# ['Drip Water Analysis']
# ['Drip Water Analysis']
# ['Drip Water Analysis']
# ['Drip Water Analysis']
# ['Drip Water Analysis']
# ['Drip Water Analysis']
# ['Drip Water Analysis']
# ['Drip Water Analysis']
# ['Drip Water Analysis']
# ['Drip Water Analysis']
# ['Drip Water Analysis']
# ['Drip Water Analysis']
# ['Drip Water Analysis']
# ['Drip Water Analysis']
# ['Drip Water Analysis']
# ['Raw irrigation water analysis (for fertigation)']
# ['12 Soil Volume Extract']
# ['12 Soil Volume Extract']
# ['12 Soil Volume Extract']

# %%
test
# Out:
# [{'sample_code': 'CS032SGF0390',
#   'analysis_id': [294],
#   'bicarbonate': {'result': 21.5, 'units': 'ppm'},
#   'silicon__': {'result': 13.8, 'units': 'ppm'},
#   'ph': {'result': 6.55, 'units': 'None'},
#   'electrical_conductivity': {'result': 0.55, 'units': 'mS/cm'},
#   'ammonium': {'result': 6.4, 'units': 'ppm'},
#   'calcium': {'result': 26.1, 'units': 'ppm'},
#   'magnesium': {'result': 6.83, 'units': 'ppm'},
#   'potassium': {'result': 51.1, 'units': 'ppm'},
#   'phosphorus': {'result': 5.59, 'units': 'ppm'},
#   'nitrate_n': {'result': 6.71, 'units': 'ppm'},
#   'nitrates': {'result': 29.7, 'units': 'ppm'},
#   'sulphur': {'result': 53.6, 'units': 'ppm'},
#   'iron': {'result': 0.25, 'units': 'ppm'},
#   'manganese': {'result': 0.05, 'units': 'ppm'},
#   'zinc': {'result': 0.027, 'units': 'ppm'},
#   'boron': {'result': 0.22, 'units': 'ppm'},
#   'copper': {'result': 0.028, 'units': 'ppm'},
#   'molybdenum': {'result': 0.12, 'units': 'ppm'},
#   'sodium': {'result': 26.5, 'units': 'ppm'},
#   'chloride': {'result': 15.2, 'units': 'ppm'}},
#  {'sample_code': 'CS032SGF0391',
#   'analysis_id': [294],
#   'ph': {'result': 6.63, 'units': 'None'},
#   'electrical_conductivity': {'result': 0.44, 'units': 'mS/cm'},
#   'ammonium': {'result': 6.32, 'units': 'ppm'},
#   'calcium': {'result': 19.3, 'units': 'ppm'},
#   'magnesium': {'result': 5.47, 'units': 'ppm'},
#   'potassium': {'result': 46.8, 'units': 'ppm'},
#   'phosphorus': {'result': 7.15, 'units': 'ppm'},
#   'nitrate_n': {'result': 9.38, 'units': 'ppm'},
#   'copper': {'result': 0.033, 'units': 'ppm'},
#   'molybdenum': {'result': 0.073, 'units': 'ppm'},
#   'sodium': {'result': 23.6, 'units': 'ppm'},
#   'nitrates': {'result': 41.5, 'units': 'ppm'},
#   'sulphur': {'result': 36.2, 'units': 'ppm'},
#   'iron': {'result': 0.33, 'units': 'ppm'},
#   'manganese': {'result': 0.032, 'units': 'ppm'},
#   'zinc': {'result': 0.022, 'units': 'ppm'},
#   'boron': {'result': 0.21, 'units': 'ppm'},
#   'chloride': {'result': 15.2, 'units': 'ppm'},
#   'bicarbonate': {'result': 32.1, 'units': 'ppm'},
#   'silicon__': {'result': 12.9, 'units': 'ppm'}},
#  {'sample_code': 'CB047SGF0228',
#   'analysis_id': [294],
#   'nitrate_n': {'result': 17.8, 'units': 'ppm'},
#   'nitrates': {'result': 78.8, 'units': 'ppm'},
#   'sulphur': {'result': 19.7, 'units': 'ppm'},
#   'iron': {'result': 0.37, 'units': 'ppm'},
#   'manganese': {'result': 0.35, 'units': 'ppm'},
#   'zinc': {'result': 0.043, 'units': 'ppm'},
#   'boron': {'result': 0.2, 'units': 'ppm'},
#   'copper': {'result': 0.01, 'units': 'ppm'},
#   'molybdenum': {'result': 0.021, 'units': 'ppm'},
#   'sodium': {'result': 28.0, 'units': 'ppm'},
#   'chloride': {'result': 17.2, 'units': 'ppm'},
#   'bicarbonate': {'result': 9.58, 'units': 'ppm'},
#   'silicon__': {'result': 19.7, 'units': 'ppm'},
#   'ph': {'result': 4.77, 'units': 'None'},
#   'electrical_conductivity': {'result': 0.42, 'units': 'mS/cm'},
#   'ammonium': {'result': 5.43, 'units': 'ppm'},
#   'calcium': {'result': 16.6, 'units': 'ppm'},
#   'magnesium': {'result': 3.91, 'units': 'ppm'},
#   'potassium': {'result': 40.8, 'units': 'ppm'},
#   'phosphorus': {'result': 15.5, 'units': 'ppm'}},
#  {'sample_code': 'CB047SGF0226',
#   'analysis_id': [294],
#   'molybdenum': {'result': 0.053, 'units': 'ppm'},
#   'sodium': {'result': 44.7, 'units': 'ppm'},
#   'chloride': {'result': 16.5, 'units': 'ppm'},
#   'bicarbonate': {'result': 12.4, 'units': 'ppm'},
#   'silicon__': {'result': 22.1, 'units': 'ppm'},
#   'sulphur': {'result': 59.1, 'units': 'ppm'},
#   'iron': {'result': 0.21, 'units': 'ppm'},
#   'manganese': {'result': 0.049, 'units': 'ppm'},
#   'zinc': {'result': 0.028, 'units': 'ppm'},
#   'boron': {'result': 0.17, 'units': 'ppm'},
#   'copper': {'result': 0.016, 'units': 'ppm'},
#   'ph': {'result': 5.68, 'units': 'None'},
#   'electrical_conductivity': {'result': 0.69, 'units': 'mS/cm'},
#   'ammonium': {'result': 6.39, 'units': 'ppm'},
#   'calcium': {'result': 37.6, 'units': 'ppm'},
#   'magnesium': {'result': 9.7, 'units': 'ppm'},
#   'potassium': {'result': 59.8, 'units': 'ppm'},
#   'phosphorus': {'result': 16.4, 'units': 'ppm'},
#   'nitrate_n': {'result': 22.6, 'units': 'ppm'},
#   'nitrates': {'result': 100.0, 'units': 'ppm'}},
#  {'sample_code': 'CN013SGF0150',
#   'analysis_id': [294],
#   'iron': {'result': 3.05, 'units': 'µmol/l'},
#   'manganese': {'result': 0.2, 'units': 'µmol/l'},
#   'zinc': {'result': 1.68, 'units': 'µmol/l'},
#   'boron': {'result': 10.2, 'units': 'µmol/l'},
#   'copper': {'result': 0.77, 'units': 'µmol/l'},
#   'molybdenum': {'result': 1.46, 'units': 'µmol/l'},
#   'sodium': {'result': 1.26, 'units': 'mmol/l'},
#   'chloride': {'result': 0.46, 'units': 'mmol/l'},
#   'bicarbonate': {'result': 0.23, 'units': 'mmol/l'},
#   'silicon__': {'result': 352.0, 'units': 'µmol/l'},
#   'nitrate_n': {'result': 0.76, 'units': 'mmol/l'},
#   'nitrates': {'result': 0.94, 'units': 'mmol/l'},
#   'sulphur': {'result': 1.27, 'units': 'mmol/l'},
#   'ph': {'result': 6.73, 'units': 'None'},
#   'electrical_conductivity': {'result': 0.47, 'units': 'mS/cm'},
#   'ammonium': {'result': 0.17, 'units': 'mmol/l'},
#   'calcium': {'result': 0.48, 'units': 'mmol/l'},
#   'magnesium': {'result': 0.26, 'units': 'mmol/l'},
#   'potassium': {'result': 1.95, 'units': 'mmol/l'},
#   'phosphorus': {'result': 0.57, 'units': 'mmol/l'}},
#  {'sample_code': 'CT017SGF0356',
#   'analysis_id': [294],
#   'ph': {'result': 6.92, 'units': 'None'},
#   'electrical_conductivity': {'result': 0.58, 'units': 'mS/cm'},
#   'ammonium': {'result': 1.73, 'units': 'ppm'},
#   'calcium': {'result': 49.8, 'units': 'ppm'},
#   'magnesium': {'result': 16.5, 'units': 'ppm'},
#   'potassium': {'result': 85.7, 'units': 'ppm'},
#   'phosphorus': {'result': 10.6, 'units': 'ppm'},
#   'nitrate_n': {'result': 15.4, 'units': 'ppm'},
#   'nitrates': {'result': 68.2, 'units': 'ppm'},
#   'sulphur': {'result': 92.9, 'units': 'ppm'},
#   'iron': {'result': 0.16, 'units': 'ppm'},
#   'manganese': {'result': 0.026, 'units': 'ppm'},
#   'zinc': {'result': 0.01, 'units': 'ppm'},
#   'boron': {'result': 0.32, 'units': 'ppm'},
#   'copper': {'result': 0.019, 'units': 'ppm'},
#   'molybdenum': {'result': 0.046, 'units': 'ppm'},
#   'sodium': {'result': 26.3, 'units': 'ppm'},
#   'chloride': {'result': 7.45, 'units': 'ppm'},
#   'bicarbonate': {'result': 20.2, 'units': 'ppm'},
#   'silicon__': {'result': 26.9, 'units': 'ppm'}},
#  {'sample_code': 'CT017SGF0357',
#   'analysis_id': [294],
#   'ph': {'result': 6.6, 'units': 'None'},
#   'electrical_conductivity': {'result': 0.44, 'units': 'mS/cm'},
#   'ammonium': {'result': 2.83, 'units': 'ppm'},
#   'calcium': {'result': 28.2, 'units': 'ppm'},
#   'magnesium': {'result': 10.3, 'units': 'ppm'},
#   'potassium': {'result': 60.4, 'units': 'ppm'},
#   'phosphorus': {'result': 11.9, 'units': 'ppm'},
#   'nitrate_n': {'result': 15.5, 'units': 'ppm'},
#   'nitrates': {'result': 68.6, 'units': 'ppm'},
#   'sulphur': {'result': 56.2, 'units': 'ppm'},
#   'iron': {'result': 0.56, 'units': 'ppm'},
#   'manganese': {'result': 0.01, 'units': 'ppm'},
#   'zinc': {'result': 0.01, 'units': 'ppm'},
#   'boron': {'result': 0.26, 'units': 'ppm'},
#   'copper': {'result': 0.028, 'units': 'ppm'},
#   'molybdenum': {'result': 0.018, 'units': 'ppm'},
#   'sodium': {'result': 25.2, 'units': 'ppm'},
#   'chloride': {'result': 5.82, 'units': 'ppm'},
#   'bicarbonate': {'result': 15.2, 'units': 'ppm'},
#   'silicon__': {'result': 30.6, 'units': 'ppm'}},
#  {'sample_code': 'CH006SGF1042      ',
#   'analysis_id': [294],
#   'ph': {'result': 5.79, 'units': 'None'},
#   'electrical_conductivity': {'result': 0.47, 'units': 'mS/cm'},
#   'ammonium': {'result': 0.2, 'units': 'mmol/l'},
#   'calcium': {'result': 0.69, 'units': 'mmol/l'},
#   'magnesium': {'result': 0.33, 'units': 'mmol/l'},
#   'potassium': {'result': 1.24, 'units': 'mmol/l'},
#   'phosphorus': {'result': 0.009, 'units': 'mmol/l'},
#   'nitrate_n': {'result': 2.86, 'units': 'mmol/l'},
#   'nitrates': {'result': 3.5, 'units': 'mmol/l'},
#   'sulphur': {'result': 0.27, 'units': 'mmol/l'},
#   'iron': {'result': 1.34, 'units': 'µmol/l'},
#   'manganese': {'result': 0.42, 'units': 'µmol/l'},
#   'zinc': {'result': 0.15, 'units': 'µmol/l'},
#   'boron': {'result': 0.93, 'units': 'µmol/l'},
#   'copper': {'result': 0.24, 'units': 'µmol/l'},
#   'molybdenum': {'result': 0.1, 'units': 'µmol/l'},
#   'sodium': {'result': 0.83, 'units': 'mmol/l'},
#   'chloride': {'result': 0.35, 'units': 'mmol/l'},
#   'bicarbonate': {'result': 0.11, 'units': 'mmol/l'},
#   'silicon__': {'result': 427.0, 'units': 'µmol/l'}},
#  {'sample_code': 'CK064SGF0122',
#   'analysis_id': [294],
#   'electrical_conductivity': {'result': 2.1, 'units': 'mS/cm'},
#   'ammonium': {'result': 6.23, 'units': 'ppm'},
#   'calcium': {'result': 112.0, 'units': 'ppm'},
#   'magnesium': {'result': 25.8, 'units': 'ppm'},
#   'potassium': {'result': 141.0, 'units': 'ppm'},
#   'phosphorus': {'result': 10.5, 'units': 'ppm'},
#   'nitrate_n': {'result': 111.0, 'units': 'ppm'},
#   'nitrates': {'result': 491.0, 'units': 'ppm'},
#   'sulphur': {'result': 197.0, 'units': 'ppm'},
#   'iron': {'result': 0.067, 'units': 'ppm'},
#   'manganese': {'result': 0.019, 'units': 'ppm'},
#   'zinc': {'result': 0.034, 'units': 'ppm'},
#   'boron': {'result': 0.3, 'units': 'ppm'},
#   'copper': {'result': 0.04, 'units': 'ppm'},
#   'molybdenum': {'result': 0.2, 'units': 'ppm'},
#   'ph': {'result': 6.49, 'units': 'None'},
#   'sodium': {'result': 175.0, 'units': 'ppm'},
#   'chloride': {'result': 26.5, 'units': 'ppm'},
#   'bicarbonate': {'result': 21.3, 'units': 'ppm'},
#   'silicon__': {'result': 20.5, 'units': 'ppm'}},
#  {'sample_code': 'CH006SGF1041      ',
#   'analysis_id': [294],
#   'ph': {'result': 6.2, 'units': 'None'},
#   'electrical_conductivity': {'result': 0.43, 'units': 'mS/cm'},
#   'ammonium': {'result': 0.18, 'units': 'mmol/l'},
#   'calcium': {'result': 0.57, 'units': 'mmol/l'},
#   'magnesium': {'result': 0.25, 'units': 'mmol/l'},
#   'potassium': {'result': 1.21, 'units': 'mmol/l'},
#   'phosphorus': {'result': 0.013, 'units': 'mmol/l'},
#   'nitrate_n': {'result': 1.99, 'units': 'mmol/l'},
#   'nitrates': {'result': 2.44, 'units': 'mmol/l'},
#   'sulphur': {'result': 0.46, 'units': 'mmol/l'},
#   'iron': {'result': 21.0, 'units': 'µmol/l'},
#   'manganese': {'result': 0.53, 'units': 'µmol/l'},
#   'zinc': {'result': 0.15, 'units': 'µmol/l'},
#   'boron': {'result': 13.9, 'units': 'µmol/l'},
#   'copper': {'result': 0.31, 'units': 'µmol/l'},
#   'molybdenum': {'result': 0.2, 'units': 'µmol/l'},
#   'sodium': {'result': 0.5, 'units': 'mmol/l'},
#   'chloride': {'result': 0.34, 'units': 'mmol/l'},
#   'bicarbonate': {'result': 0.12, 'units': 'mmol/l'},
#   'silicon__': {'result': 598.0, 'units': 'µmol/l'}},
#  {'sample_code': 'CM173SGF3262      ',
#   'analysis_id': [27454],
#   'manganese': {'result': 36.4, 'units': 'µmol/l'},
#   'zinc': {'result': 17.1, 'units': 'µmol/l'},
#   'boron': {'result': 32.4, 'units': 'µmol/l'},
#   'copper': {'result': 12.4, 'units': 'µmol/l'},
#   'molybdenum': {'result': 0.4, 'units': 'µmol/l'},
#   'sodium': {'result': 2.92, 'units': 'mmol/l'},
#   'chloride': {'result': 0.46, 'units': 'mmol/l'},
#   'silicon__': {'result': 730.0, 'units': 'µmol/l'},
#   'bicarbonate': {'result': 0.64, 'units': 'mmol/l'},
#   'ph': {'result': 5.84, 'units': 'None'},
#   'electrical_conductivity': {'result': 1.75, 'units': 'mS/cm'},
#   'ammonium': {'result': 0.54, 'units': 'mmol/l'},
#   'calcium': {'result': 3.47, 'units': 'mmol/l'},
#   'magnesium': {'result': 1.67, 'units': 'mmol/l'},
#   'potassium': {'result': 3.66, 'units': 'mmol/l'},
#   'phosphorus': {'result': 0.59, 'units': 'mmol/l'},
#   'nitrate_n': {'result': 9.67, 'units': 'mmol/l'},
#   'nitrates': {'result': 11.9, 'units': 'mmol/l'},
#   'sulphur': {'result': 2.67, 'units': 'mmol/l'},
#   'iron': {'result': 15.6, 'units': 'µmol/l'}},
#  {'sample_code': 'CM173SGF3263      ',
#   'analysis_id': [27454],
#   'ph': {'result': 5.62, 'units': 'None'},
#   'electrical_conductivity': {'result': 1.67, 'units': 'mS/cm'},
#   'ammonium': {'result': 0.34, 'units': 'mmol/l'},
#   'calcium': {'result': 2.49, 'units': 'mmol/l'},
#   'magnesium': {'result': 2.55, 'units': 'mmol/l'},
#   'potassium': {'result': 2.25, 'units': 'mmol/l'},
#   'phosphorus': {'result': 0.6, 'units': 'mmol/l'},
#   'nitrate_n': {'result': 9.67, 'units': 'mmol/l'},
#   'nitrates': {'result': 11.9, 'units': 'mmol/l'},
#   'sulphur': {'result': 1.73, 'units': 'mmol/l'},
#   'iron': {'result': 21.1, 'units': 'µmol/l'},
#   'manganese': {'result': 21.7, 'units': 'µmol/l'},
#   'zinc': {'result': 9.79, 'units': 'µmol/l'},
#   'boron': {'result': 23.1, 'units': 'µmol/l'},
#   'copper': {'result': 7.09, 'units': 'µmol/l'},
#   'molybdenum': {'result': 0.32, 'units': 'µmol/l'},
#   'sodium': {'result': 2.65, 'units': 'mmol/l'},
#   'chloride': {'result': 0.43, 'units': 'mmol/l'},
#   'silicon__': {'result': 712.0, 'units': 'µmol/l'},
#   'bicarbonate': {'result': 0.6, 'units': 'mmol/l'}},
#  {'sample_code': 'CT017SGF0370',
#   'analysis_id': [294],
#   'electrical_conductivity': {'result': 0.52, 'units': 'mS/cm'},
#   'ammonium': {'result': 3.76, 'units': 'ppm'},
#   'calcium': {'result': 28.5, 'units': 'ppm'},
#   'magnesium': {'result': 15.6, 'units': 'ppm'},
#   'potassium': {'result': 49.8, 'units': 'ppm'},
#   'phosphorus': {'result': 0.65, 'units': 'ppm'},
#   'nitrate_n': {'result': 6.94, 'units': 'ppm'},
#   'nitrates': {'result': 30.7, 'units': 'ppm'},
#   'sulphur': {'result': 79.1, 'units': 'ppm'},
#   'iron': {'result': 0.22, 'units': 'ppm'},
#   'manganese': {'result': 0.01, 'units': 'ppm'},
#   'zinc': {'result': 0.01, 'units': 'ppm'},
#   'boron': {'result': 0.099, 'units': 'ppm'},
#   'copper': {'result': 0.016, 'units': 'ppm'},
#   'molybdenum': {'result': 0.052, 'units': 'ppm'},
#   'sodium': {'result': 27.6, 'units': 'ppm'},
#   'chloride': {'result': 14.8, 'units': 'ppm'},
#   'bicarbonate': {'result': 35.5, 'units': 'ppm'},
#   'silicon__': {'result': 17.9, 'units': 'ppm'},
#   'ph': {'result': 7.17, 'units': 'None'}},
#  {'sample_code': 'CT017SGF0369',
#   'analysis_id': [294],
#   'ph': {'result': 6.54, 'units': 'None'},
#   'electrical_conductivity': {'result': 0.79, 'units': 'mS/cm'},
#   'ammonium': {'result': 6.65, 'units': 'ppm'},
#   'calcium': {'result': 74.0, 'units': 'ppm'},
#   'magnesium': {'result': 21.0, 'units': 'ppm'},
#   'potassium': {'result': 80.3, 'units': 'ppm'},
#   'phosphorus': {'result': 4.02, 'units': 'ppm'},
#   'nitrate_n': {'result': 2.38, 'units': 'ppm'},
#   'nitrates': {'result': 10.5, 'units': 'ppm'},
#   'sulphur': {'result': 167.0, 'units': 'ppm'},
#   'iron': {'result': 0.2, 'units': 'ppm'},
#   'manganese': {'result': 0.15, 'units': 'ppm'},
#   'zinc': {'result': 0.049, 'units': 'ppm'},
#   'boron': {'result': 0.068, 'units': 'ppm'},
#   'copper': {'result': 0.083, 'units': 'ppm'},
#   'molybdenum': {'result': 0.027, 'units': 'ppm'},
#   'sodium': {'result': 26.0, 'units': 'ppm'},
#   'chloride': {'result': 15.9, 'units': 'ppm'},
#   'bicarbonate': {'result': 37.0, 'units': 'ppm'},
#   'silicon__': {'result': 20.9, 'units': 'ppm'}},
#  {'sample_code': 'CT017SGF0364',
#   'analysis_id': [294],
#   'ph': {'result': 6.04, 'units': 'None'},
#   'electrical_conductivity': {'result': 0.74, 'units': 'mS/cm'},
#   'ammonium': {'result': 5.17, 'units': 'ppm'},
#   'calcium': {'result': 69.4, 'units': 'ppm'},
#   'magnesium': {'result': 24.3, 'units': 'ppm'},
#   'potassium': {'result': 74.7, 'units': 'ppm'},
#   'phosphorus': {'result': 6.51, 'units': 'ppm'},
#   'nitrate_n': {'result': 7.28, 'units': 'ppm'},
#   'nitrates': {'result': 32.2, 'units': 'ppm'},
#   'sulphur': {'result': 162.0, 'units': 'ppm'},
#   'iron': {'result': 0.8, 'units': 'ppm'},
#   'manganese': {'result': 0.019, 'units': 'ppm'},
#   'zinc': {'result': 0.044, 'units': 'ppm'},
#   'boron': {'result': 0.29, 'units': 'ppm'},
#   'copper': {'result': 0.047, 'units': 'ppm'},
#   'molybdenum': {'result': 0.019, 'units': 'ppm'},
#   'sodium': {'result': 33.2, 'units': 'ppm'},
#   'chloride': {'result': 9.23, 'units': 'ppm'},
#   'bicarbonate': {'result': 16.3, 'units': 'ppm'},
#   'silicon__': {'result': 27.4, 'units': 'ppm'}},
#  {'sample_code': 'CT017SGF0365',
#   'analysis_id': [294],
#   'ph': {'result': 6.0, 'units': 'None'},
#   'manganese': {'result': 0.011, 'units': 'ppm'},
#   'electrical_conductivity': {'result': 0.69, 'units': 'mS/cm'},
#   'ammonium': {'result': 2.97, 'units': 'ppm'},
#   'calcium': {'result': 71.4, 'units': 'ppm'},
#   'magnesium': {'result': 23.7, 'units': 'ppm'},
#   'potassium': {'result': 70.6, 'units': 'ppm'},
#   'phosphorus': {'result': 9.21, 'units': 'ppm'},
#   'nitrate_n': {'result': 11.6, 'units': 'ppm'},
#   'nitrates': {'result': 51.4, 'units': 'ppm'},
#   'sulphur': {'result': 146.0, 'units': 'ppm'},
#   'iron': {'result': 0.89, 'units': 'ppm'},
#   'zinc': {'result': 0.01, 'units': 'ppm'},
#   'boron': {'result': 0.25, 'units': 'ppm'},
#   'copper': {'result': 0.034, 'units': 'ppm'},
#   'molybdenum': {'result': 0.022, 'units': 'ppm'},
#   'sodium': {'result': 25.4, 'units': 'ppm'},
#   'chloride': {'result': 6.06, 'units': 'ppm'},
#   'bicarbonate': {'result': 17.0, 'units': 'ppm'},
#   'silicon__': {'result': 27.3, 'units': 'ppm'}},
#  {'sample_code': 'CO037SGF0023',
#   'analysis_id': [27454],
#   'ph': {'result': 6.14, 'units': 'None'},
#   'electrical_conductivity': {'result': 1.64, 'units': 'mS/cm'},
#   'ammonium': {'result': 0.55, 'units': 'mmol/l'},
#   'calcium': {'result': 3.27, 'units': 'mmol/l'},
#   'magnesium': {'result': 1.96, 'units': 'mmol/l'},
#   'potassium': {'result': 4.78, 'units': 'mmol/l'},
#   'phosphorus': {'result': 1.29, 'units': 'mmol/l'},
#   'nitrate_n': {'result': 8.62, 'units': 'mmol/l'},
#   'nitrates': {'result': 10.6, 'units': 'mmol/l'},
#   'sulphur': {'result': 2.12, 'units': 'mmol/l'},
#   'iron': {'result': 64.5, 'units': 'µmol/l'},
#   'manganese': {'result': 8.56, 'units': 'µmol/l'},
#   'zinc': {'result': 3.67, 'units': 'µmol/l'},
#   'boron': {'result': 42.6, 'units': 'µmol/l'},
#   'copper': {'result': 4.57, 'units': 'µmol/l'},
#   'molybdenum': {'result': 1.77, 'units': 'µmol/l'},
#   'sodium': {'result': 0.98, 'units': 'mmol/l'},
#   'chloride': {'result': 0.16, 'units': 'mmol/l'},
#   'silicon__': {'result': 58.7, 'units': 'µmol/l'},
#   'bicarbonate': {'result': 0.86, 'units': 'mmol/l'}},
#  {'sample_code': 'CT017SGF0366',
#   'analysis_id': [294],
#   'ph': {'result': 6.6, 'units': 'None'},
#   'electrical_conductivity': {'result': 1.25, 'units': 'mS/cm'},
#   'ammonium': {'result': 3.98, 'units': 'ppm'},
#   'calcium': {'result': 117.0, 'units': 'ppm'},
#   'magnesium': {'result': 40.2, 'units': 'ppm'},
#   'potassium': {'result': 97.0, 'units': 'ppm'},
#   'phosphorus': {'result': 7.74, 'units': 'ppm'},
#   'nitrate_n': {'result': 6.84, 'units': 'ppm'},
#   'nitrates': {'result': 30.3, 'units': 'ppm'},
#   'sulphur': {'result': 271.0, 'units': 'ppm'},
#   'iron': {'result': 0.29, 'units': 'ppm'},
#   'manganese': {'result': 0.01, 'units': 'ppm'},
#   'zinc': {'result': 0.01, 'units': 'ppm'},
#   'boron': {'result': 0.27, 'units': 'ppm'},
#   'copper': {'result': 0.021, 'units': 'ppm'},
#   'molybdenum': {'result': 0.029, 'units': 'ppm'},
#   'sodium': {'result': 63.3, 'units': 'ppm'},
#   'chloride': {'result': 8.19, 'units': 'ppm'},
#   'bicarbonate': {'result': 41.9, 'units': 'ppm'},
#   'silicon__': {'result': 24.4, 'units': 'ppm'}},
#  {'sample_code': 'CH231SGF0001',
#   'analysis_id': [294],
#   'ph': {'result': 5.38, 'units': 'None'},
#   'electrical_conductivity': {'result': 0.39, 'units': 'mS/cm'},
#   'ammonium': {'result': 6.47, 'units': 'ppm'},
#   'calcium': {'result': 27.0, 'units': 'ppm'},
#   'magnesium': {'result': 8.24, 'units': 'ppm'},
#   'potassium': {'result': 34.0, 'units': 'ppm'},
#   'phosphorus': {'result': 2.37, 'units': 'ppm'},
#   'nitrate_n': {'result': 27.3, 'units': 'ppm'},
#   'nitrates': {'result': 121.0, 'units': 'ppm'},
#   'sulphur': {'result': 40.7, 'units': 'ppm'},
#   'iron': {'result': 0.088, 'units': 'ppm'},
#   'manganese': {'result': 0.022, 'units': 'ppm'},
#   'zinc': {'result': 1.08, 'units': 'ppm'},
#   'boron': {'result': 0.039, 'units': 'ppm'},
#   'copper': {'result': 0.01, 'units': 'ppm'},
#   'molybdenum': {'result': 0.029, 'units': 'ppm'},
#   'sodium': {'result': 10.6, 'units': 'ppm'},
#   'chloride': {'result': 17.3, 'units': 'ppm'},
#   'bicarbonate': {'result': 12.1, 'units': 'ppm'},
#   'silicon__': {'result': 7.77, 'units': 'ppm'}},
#  {'sample_code': 'CH231SGF0002',
#   'analysis_id': [294],
#   'ph': {'result': 5.78, 'units': 'None'},
#   'electrical_conductivity': {'result': 1.88, 'units': 'mS/cm'},
#   'ammonium': {'result': 4.37, 'units': 'ppm'},
#   'calcium': {'result': 188.0, 'units': 'ppm'},
#   'magnesium': {'result': 49.0, 'units': 'ppm'},
#   'potassium': {'result': 144.0, 'units': 'ppm'},
#   'phosphorus': {'result': 5.42, 'units': 'ppm'},
#   'nitrate_n': {'result': 141.0, 'units': 'ppm'},
#   'nitrates': {'result': 624.0, 'units': 'ppm'},
#   'sulphur': {'result': 239.0, 'units': 'ppm'},
#   'iron': {'result': 0.01, 'units': 'ppm'},
#   'manganese': {'result': 0.014, 'units': 'ppm'},
#   'zinc': {'result': 0.046, 'units': 'ppm'},
#   'boron': {'result': 0.15, 'units': 'ppm'},
#   'copper': {'result': 0.01, 'units': 'ppm'},
#   'molybdenum': {'result': 0.086, 'units': 'ppm'},
#   'sodium': {'result': 53.1, 'units': 'ppm'},
#   'chloride': {'result': 38.1, 'units': 'ppm'},
#   'bicarbonate': {'result': 24.8, 'units': 'ppm'},
#   'silicon__': {'result': 4.82, 'units': 'ppm'}},
#  {'sample_code': 'CT017SGF0359',
#   'analysis_id': [294],
#   'ph': {'result': 6.4, 'units': 'None'},
#   'electrical_conductivity': {'result': 0.55, 'units': 'mS/cm'},
#   'ammonium': {'result': 2.82, 'units': 'ppm'},
#   'calcium': {'result': 38.0, 'units': 'ppm'},
#   'magnesium': {'result': 14.3, 'units': 'ppm'},
#   'potassium': {'result': 40.5, 'units': 'ppm'},
#   'phosphorus': {'result': 8.27, 'units': 'ppm'},
#   'nitrate_n': {'result': 3.44, 'units': 'ppm'},
#   'nitrates': {'result': 15.2, 'units': 'ppm'},
#   'sulphur': {'result': 104.0, 'units': 'ppm'},
#   'iron': {'result': 0.14, 'units': 'ppm'},
#   'manganese': {'result': 0.01, 'units': 'ppm'},
#   'zinc': {'result': 0.01, 'units': 'ppm'},
#   'boron': {'result': 0.24, 'units': 'ppm'},
#   'copper': {'result': 0.021, 'units': 'ppm'},
#   'molybdenum': {'result': 0.01, 'units': 'ppm'},
#   'sodium': {'result': 47.8, 'units': 'ppm'},
#   'chloride': {'result': 16.7, 'units': 'ppm'},
#   'bicarbonate': {'result': 16.3, 'units': 'ppm'},
#   'silicon__': {'result': 25.9, 'units': 'ppm'}},
#  {'sample_code': 'CT017SGF0360',
#   'analysis_id': [294],
#   'ph': {'result': 6.31, 'units': 'None'},
#   'electrical_conductivity': {'result': 0.55, 'units': 'mS/cm'},
#   'ammonium': {'result': 2.46, 'units': 'ppm'},
#   'calcium': {'result': 45.1, 'units': 'ppm'},
#   'magnesium': {'result': 14.4, 'units': 'ppm'},
#   'potassium': {'result': 35.8, 'units': 'ppm'},
#   'phosphorus': {'result': 4.75, 'units': 'ppm'},
#   'nitrate_n': {'result': 6.66, 'units': 'ppm'},
#   'nitrates': {'result': 29.5, 'units': 'ppm'},
#   'sulphur': {'result': 94.5, 'units': 'ppm'},
#   'iron': {'result': 0.21, 'units': 'ppm'},
#   'manganese': {'result': 0.01, 'units': 'ppm'},
#   'zinc': {'result': 0.01, 'units': 'ppm'},
#   'boron': {'result': 0.3, 'units': 'ppm'},
#   'copper': {'result': 0.018, 'units': 'ppm'},
#   'molybdenum': {'result': 0.018, 'units': 'ppm'},
#   'sodium': {'result': 53.9, 'units': 'ppm'},
#   'chloride': {'result': 24.1, 'units': 'ppm'},
#   'bicarbonate': {'result': 15.2, 'units': 'ppm'},
#   'silicon__': {'result': 26.4, 'units': 'ppm'}},
#  {'sample_code': 'CT017SGF0362',
#   'analysis_id': [294],
#   'molybdenum': {'result': 0.01, 'units': 'ppm'},
#   'sodium': {'result': 32.1, 'units': 'ppm'},
#   'chloride': {'result': 17.7, 'units': 'ppm'},
#   'bicarbonate': {'result': 13.3, 'units': 'ppm'},
#   'silicon__': {'result': 22.4, 'units': 'ppm'},
#   'potassium': {'result': 67.6, 'units': 'ppm'},
#   'phosphorus': {'result': 5.94, 'units': 'ppm'},
#   'nitrate_n': {'result': 6.19, 'units': 'ppm'},
#   'nitrates': {'result': 27.4, 'units': 'ppm'},
#   'sulphur': {'result': 121.0, 'units': 'ppm'},
#   'iron': {'result': 0.31, 'units': 'ppm'},
#   'manganese': {'result': 0.021, 'units': 'ppm'},
#   'zinc': {'result': 0.01, 'units': 'ppm'},
#   'boron': {'result': 0.25, 'units': 'ppm'},
#   'copper': {'result': 0.018, 'units': 'ppm'},
#   'ph': {'result': 5.7, 'units': 'None'},
#   'electrical_conductivity': {'result': 0.61, 'units': 'mS/cm'},
#   'ammonium': {'result': 4.21, 'units': 'ppm'},
#   'calcium': {'result': 68.6, 'units': 'ppm'},
#   'magnesium': {'result': 13.6, 'units': 'ppm'}},
#  {'sample_code': 'CT017SGF0361',
#   'analysis_id': [294],
#   'molybdenum': {'result': 0.013, 'units': 'ppm'},
#   'sodium': {'result': 25.3, 'units': 'ppm'},
#   'chloride': {'result': 16.0, 'units': 'ppm'},
#   'bicarbonate': {'result': 13.2, 'units': 'ppm'},
#   'silicon__': {'result': 27.2, 'units': 'ppm'},
#   'ph': {'result': 5.98, 'units': 'None'},
#   'electrical_conductivity': {'result': 0.55, 'units': 'mS/cm'},
#   'ammonium': {'result': 2.93, 'units': 'ppm'},
#   'calcium': {'result': 40.7, 'units': 'ppm'},
#   'magnesium': {'result': 13.8, 'units': 'ppm'},
#   'potassium': {'result': 56.9, 'units': 'ppm'},
#   'phosphorus': {'result': 6.93, 'units': 'ppm'},
#   'nitrate_n': {'result': 6.82, 'units': 'ppm'},
#   'nitrates': {'result': 30.2, 'units': 'ppm'},
#   'sulphur': {'result': 95.1, 'units': 'ppm'},
#   'iron': {'result': 0.23, 'units': 'ppm'},
#   'manganese': {'result': 0.01, 'units': 'ppm'},
#   'zinc': {'result': 0.01, 'units': 'ppm'},
#   'boron': {'result': 0.28, 'units': 'ppm'},
#   'copper': {'result': 0.013, 'units': 'ppm'}},
#  {'sample_code': 'CT017SGF0354',
#   'analysis_id': [294],
#   'ph': {'result': 7.15, 'units': 'None'},
#   'electrical_conductivity': {'result': 0.49, 'units': 'mS/cm'},
#   'ammonium': {'result': 1.86, 'units': 'ppm'},
#   'boron': {'result': 0.26, 'units': 'ppm'},
#   'copper': {'result': 0.023, 'units': 'ppm'},
#   'molybdenum': {'result': 0.051, 'units': 'ppm'},
#   'sodium': {'result': 18.8, 'units': 'ppm'},
#   'chloride': {'result': 12.3, 'units': 'ppm'},
#   'bicarbonate': {'result': 23.3, 'units': 'ppm'},
#   'silicon__': {'result': 27.8, 'units': 'ppm'},
#   'calcium': {'result': 46.8, 'units': 'ppm'},
#   'magnesium': {'result': 12.7, 'units': 'ppm'},
#   'potassium': {'result': 64.8, 'units': 'ppm'},
#   'phosphorus': {'result': 12.3, 'units': 'ppm'},
#   'nitrate_n': {'result': 18.3, 'units': 'ppm'},
#   'nitrates': {'result': 81.0, 'units': 'ppm'},
#   'sulphur': {'result': 51.6, 'units': 'ppm'},
#   'iron': {'result': 0.12, 'units': 'ppm'},
#   'manganese': {'result': 0.01, 'units': 'ppm'},
#   'zinc': {'result': 0.01, 'units': 'ppm'}},
#  {'sample_code': 'CM173SGF3302      ',
#   'analysis_id': [27454],
#   'ph': {'result': 5.53, 'units': 'None'},
#   'electrical_conductivity': {'result': 1.84, 'units': 'mS/cm'},
#   'ammonium': {'result': 0.55, 'units': 'mmol/l'},
#   'calcium': {'result': 3.44, 'units': 'mmol/l'},
#   'magnesium': {'result': 2.52, 'units': 'mmol/l'},
#   'potassium': {'result': 2.84, 'units': 'mmol/l'},
#   'phosphorus': {'result': 0.75, 'units': 'mmol/l'},
#   'nitrate_n': {'result': 10.4, 'units': 'mmol/l'},
#   'nitrates': {'result': 12.7, 'units': 'mmol/l'},
#   'sulphur': {'result': 1.83, 'units': 'mmol/l'},
#   'iron': {'result': 29.4, 'units': 'µmol/l'},
#   'manganese': {'result': 27.9, 'units': 'µmol/l'},
#   'zinc': {'result': 13.1, 'units': 'µmol/l'},
#   'boron': {'result': 24.1, 'units': 'µmol/l'},
#   'copper': {'result': 7.4, 'units': 'µmol/l'},
#   'molybdenum': {'result': 0.1, 'units': 'µmol/l'},
#   'sodium': {'result': 2.34, 'units': 'mmol/l'},
#   'chloride': {'result': 0.74, 'units': 'mmol/l'},
#   'silicon__': {'result': 648.0, 'units': 'µmol/l'},
#   'bicarbonate': {'result': 0.51, 'units': 'mmol/l'}},
#  {'sample_code': 'CM173SGF3304      ',
#   'analysis_id': [27454],
#   'ph': {'result': 5.58, 'units': 'None'},
#   'molybdenum': {'result': 0.1, 'units': 'µmol/l'},
#   'sodium': {'result': 2.4, 'units': 'mmol/l'},
#   'chloride': {'result': 0.84, 'units': 'mmol/l'},
#   'silicon__': {'result': 644.0, 'units': 'µmol/l'},
#   'bicarbonate': {'result': 0.66, 'units': 'mmol/l'},
#   'electrical_conductivity': {'result': 1.78, 'units': 'mS/cm'},
#   'ammonium': {'result': 0.53, 'units': 'mmol/l'},
#   'calcium': {'result': 3.89, 'units': 'mmol/l'},
#   'magnesium': {'result': 1.84, 'units': 'mmol/l'},
#   'potassium': {'result': 2.56, 'units': 'mmol/l'},
#   'phosphorus': {'result': 0.77, 'units': 'mmol/l'},
#   'nitrate_n': {'result': 9.67, 'units': 'mmol/l'},
#   'nitrates': {'result': 11.9, 'units': 'mmol/l'},
#   'sulphur': {'result': 2.31, 'units': 'mmol/l'},
#   'iron': {'result': 45.7, 'units': 'µmol/l'},
#   'manganese': {'result': 41.2, 'units': 'µmol/l'},
#   'zinc': {'result': 22.3, 'units': 'µmol/l'},
#   'boron': {'result': 36.1, 'units': 'µmol/l'},
#   'copper': {'result': 12.1, 'units': 'µmol/l'}},
#  {'sample_code': 'CB033SGF0327',
#   'analysis_id': [294],
#   'iron': {'result': 28.1, 'units': 'ppm'},
#   'manganese': {'result': 4.11, 'units': 'ppm'},
#   'zinc': {'result': 1.8, 'units': 'ppm'},
#   'boron': {'result': 5.33, 'units': 'ppm'},
#   'copper': {'result': 0.88, 'units': 'ppm'},
#   'molybdenum': {'result': 0.011, 'units': 'ppm'},
#   'sodium': {'result': 53.3, 'units': 'ppm'},
#   'chloride': {'result': 34.8, 'units': 'ppm'},
#   'bicarbonate': {'result': 27.8, 'units': 'ppm'},
#   'silicon__': {'result': 16.7, 'units': 'ppm'},
#   'ph': {'result': 4.73, 'units': 'None'},
#   'electrical_conductivity': {'result': 2.18, 'units': 'mS/cm'},
#   'ammonium': {'result': 13.4, 'units': 'ppm'},
#   'calcium': {'result': 206.0, 'units': 'ppm'},
#   'magnesium': {'result': 54.5, 'units': 'ppm'},
#   'potassium': {'result': 135.0, 'units': 'ppm'},
#   'phosphorus': {'result': 16.4, 'units': 'ppm'},
#   'nitrate_n': {'result': 162.0, 'units': 'ppm'},
#   'nitrates': {'result': 717.0, 'units': 'ppm'},
#   'sulphur': {'result': 116.0, 'units': 'ppm'}},
#  {'sample_code': 'CB033SGF0328',
#   'analysis_id': [294],
#   'ph': {'result': 6.9, 'units': 'None'},
#   'electrical_conductivity': {'result': 0.53, 'units': 'mS/cm'},
#   'ammonium': {'result': 6.89, 'units': 'ppm'},
#   'calcium': {'result': 27.5, 'units': 'ppm'},
#   'magnesium': {'result': 7.68, 'units': 'ppm'},
#   'potassium': {'result': 54.8, 'units': 'ppm'},
#   'phosphorus': {'result': 11.4, 'units': 'ppm'},
#   'nitrate_n': {'result': 14.3, 'units': 'ppm'},
#   'nitrates': {'result': 63.3, 'units': 'ppm'},
#   'sulphur': {'result': 30.0, 'units': 'ppm'},
#   'iron': {'result': 2.34, 'units': 'ppm'},
#   'manganese': {'result': 0.012, 'units': 'ppm'},
#   'zinc': {'result': 2.51, 'units': 'ppm'},
#   'boron': {'result': 0.96, 'units': 'ppm'},
#   'copper': {'result': 1.2, 'units': 'ppm'},
#   'molybdenum': {'result': 0.12, 'units': 'ppm'},
#   'sodium': {'result': 16.8, 'units': 'ppm'},
#   'chloride': {'result': 17.6, 'units': 'ppm'},
#   'bicarbonate': {'result': 33.4, 'units': 'ppm'},
#   'silicon__': {'result': 14.1, 'units': 'ppm'}},
#  {'sample_code': 'CV010SGF0232',
#   'analysis_id': [27454],
#   'ph': {'result': 6.15, 'units': 'None'},
#   'electrical_conductivity': {'result': 1.22, 'units': 'mS/cm'},
#   'ammonium': {'result': 0.42, 'units': 'mmol/l'},
#   'calcium': {'result': 2.48, 'units': 'mmol/l'},
#   'magnesium': {'result': 1.19, 'units': 'mmol/l'},
#   'potassium': {'result': 2.69, 'units': 'mmol/l'},
#   'phosphorus': {'result': 0.46, 'units': 'mmol/l'},
#   'nitrate_n': {'result': 4.53, 'units': 'mmol/l'},
#   'nitrates': {'result': 5.55, 'units': 'mmol/l'},
#   'sulphur': {'result': 2.41, 'units': 'mmol/l'},
#   'iron': {'result': 34.9, 'units': 'µmol/l'},
#   'manganese': {'result': 7.83, 'units': 'µmol/l'},
#   'zinc': {'result': 3.52, 'units': 'µmol/l'},
#   'boron': {'result': 19.4, 'units': 'µmol/l'},
#   'copper': {'result': 1.46, 'units': 'µmol/l'},
#   'molybdenum': {'result': 0.6, 'units': 'µmol/l'},
#   'sodium': {'result': 1.22, 'units': 'mmol/l'},
#   'chloride': {'result': 1.1, 'units': 'mmol/l'},
#   'silicon__': {'result': 43.4, 'units': 'µmol/l'},
#   'bicarbonate': {'result': 0.47, 'units': 'mmol/l'}},
#  {'sample_code': 'CB033SGF0329',
#   'analysis_id': [294],
#   'ph': {'result': 5.36, 'units': 'None'},
#   'electrical_conductivity': {'result': 2.02, 'units': 'mS/cm'},
#   'ammonium': {'result': 7.81, 'units': 'ppm'},
#   'calcium': {'result': 263.0, 'units': 'ppm'},
#   'magnesium': {'result': 54.7, 'units': 'ppm'},
#   'potassium': {'result': 137.0, 'units': 'ppm'},
#   'phosphorus': {'result': 7.14, 'units': 'ppm'},
#   'nitrate_n': {'result': 221.0, 'units': 'ppm'},
#   'nitrates': {'result': 978.0, 'units': 'ppm'},
#   'sulphur': {'result': 81.6, 'units': 'ppm'},
#   'iron': {'result': 10.2, 'units': 'ppm'},
#   'manganese': {'result': 1.38, 'units': 'ppm'},
#   'zinc': {'result': 1.1, 'units': 'ppm'},
#   'boron': {'result': 1.92, 'units': 'ppm'},
#   'copper': {'result': 0.84, 'units': 'ppm'},
#   'molybdenum': {'result': 0.013, 'units': 'ppm'},
#   'sodium': {'result': 44.9, 'units': 'ppm'},
#   'chloride': {'result': 32.3, 'units': 'ppm'},
#   'silicon__': {'result': 17.4, 'units': 'ppm'},
#   'bicarbonate': {'result': 22.9, 'units': 'ppm'}},
#  {'sample_code': 'CA035SGF0154',
#   'analysis_id': [294],
#   'ph': {'result': 6.43, 'units': 'None'},
#   'electrical_conductivity': {'result': 1.26, 'units': 'mS/cm'},
#   'ammonium': {'result': 7.09, 'units': 'ppm'},
#   'calcium': {'result': 99.4, 'units': 'ppm'},
#   'magnesium': {'result': 26.5, 'units': 'ppm'},
#   'potassium': {'result': 132.0, 'units': 'ppm'},
#   'phosphorus': {'result': 4.59, 'units': 'ppm'},
#   'nitrate_n': {'result': 124.0, 'units': 'ppm'},
#   'nitrates': {'result': 549.0, 'units': 'ppm'},
#   'sulphur': {'result': 50.3, 'units': 'ppm'},
#   'iron': {'result': 0.45, 'units': 'ppm'},
#   'manganese': {'result': 0.014, 'units': 'ppm'},
#   'zinc': {'result': 0.8, 'units': 'ppm'},
#   'boron': {'result': 0.2, 'units': 'ppm'},
#   'copper': {'result': 0.016, 'units': 'ppm'},
#   'molybdenum': {'result': 0.022, 'units': 'ppm'},
#   'sodium': {'result': 40.4, 'units': 'ppm'},
#   'chloride': {'result': 21.2, 'units': 'ppm'},
#   'bicarbonate': {'result': 13.5, 'units': 'ppm'},
#   'silicon__': {'result': 11.7, 'units': 'ppm'}},
#  {'sample_code': 'CB357SGF0007',
#   'analysis_id': [294],
#   'iron': {'result': 0.01, 'units': 'ppm'},
#   'manganese': {'result': 0.01, 'units': 'ppm'},
#   'zinc': {'result': 0.01, 'units': 'ppm'},
#   'boron': {'result': 0.079, 'units': 'ppm'},
#   'copper': {'result': 0.01, 'units': 'ppm'},
#   'molybdenum': {'result': 0.01, 'units': 'ppm'},
#   'sodium': {'result': 0.05, 'units': 'ppm'},
#   'chloride': {'result': 7.46, 'units': 'ppm'},
#   'bicarbonate': {'result': 8.6, 'units': 'ppm'},
#   'silicon__': {'result': 4.21, 'units': 'ppm'},
#   'ph': {'result': 5.88, 'units': 'None'},
#   'electrical_conductivity': {'result': 0.2, 'units': 'mS/cm'},
#   'ammonium': {'result': 3.62, 'units': 'ppm'},
#   'calcium': {'result': 19.7, 'units': 'ppm'},
#   'magnesium': {'result': 2.9, 'units': 'ppm'},
#   'potassium': {'result': 7.07, 'units': 'ppm'},
#   'phosphorus': {'result': 0.19, 'units': 'ppm'},
#   'nitrate_n': {'result': 15.7, 'units': 'ppm'},
#   'nitrates': {'result': 69.5, 'units': 'ppm'},
#   'sulphur': {'result': 3.66, 'units': 'ppm'}},
#  {'sample_code': 'CB357SGF0008',
#   'analysis_id': [294],
#   'ph': {'result': 4.62, 'units': 'None'},
#   'electrical_conductivity': {'result': 0.34, 'units': 'mS/cm'},
#   'ammonium': {'result': 4.07, 'units': 'ppm'},
#   'calcium': {'result': 36.9, 'units': 'ppm'},
#   'magnesium': {'result': 9.26, 'units': 'ppm'},
#   'potassium': {'result': 6.62, 'units': 'ppm'},
#   'phosphorus': {'result': 0.05, 'units': 'ppm'},
#   'nitrate_n': {'result': 37.5, 'units': 'ppm'},
#   'nitrates': {'result': 166.0, 'units': 'ppm'},
#   'sulphur': {'result': 3.34, 'units': 'ppm'},
#   'iron': {'result': 0.01, 'units': 'ppm'},
#   'manganese': {'result': 0.38, 'units': 'ppm'},
#   'zinc': {'result': 0.093, 'units': 'ppm'},
#   'boron': {'result': 0.096, 'units': 'ppm'},
#   'copper': {'result': 0.012, 'units': 'ppm'},
#   'molybdenum': {'result': 0.01, 'units': 'ppm'},
#   'sodium': {'result': 0.05, 'units': 'ppm'},
#   'chloride': {'result': 5.86, 'units': 'ppm'},
#   'bicarbonate': {'result': 5.9, 'units': 'ppm'},
#   'silicon__': {'result': 3.7, 'units': 'ppm'}},
#  {'sample_code': 'CV010SGF0233',
#   'analysis_id': [27454],
#   'ph': {'result': 6.2, 'units': 'None'},
#   'electrical_conductivity': {'result': 1.22, 'units': 'mS/cm'},
#   'ammonium': {'result': 0.41, 'units': 'mmol/l'},
#   'calcium': {'result': 2.59, 'units': 'mmol/l'},
#   'magnesium': {'result': 1.23, 'units': 'mmol/l'},
#   'potassium': {'result': 2.76, 'units': 'mmol/l'},
#   'phosphorus': {'result': 0.47, 'units': 'mmol/l'},
#   'nitrate_n': {'result': 4.6, 'units': 'mmol/l'},
#   'nitrates': {'result': 5.65, 'units': 'mmol/l'},
#   'sulphur': {'result': 2.49, 'units': 'mmol/l'},
#   'iron': {'result': 33.7, 'units': 'µmol/l'},
#   'manganese': {'result': 6.38, 'units': 'µmol/l'},
#   'zinc': {'result': 3.67, 'units': 'µmol/l'},
#   'boron': {'result': 19.4, 'units': 'µmol/l'},
#   'copper': {'result': 1.73, 'units': 'µmol/l'},
#   'molybdenum': {'result': 0.76, 'units': 'µmol/l'},
#   'sodium': {'result': 1.26, 'units': 'mmol/l'},
#   'chloride': {'result': 1.13, 'units': 'mmol/l'},
#   'silicon__': {'result': 32.4, 'units': 'µmol/l'},
#   'bicarbonate': {'result': 0.47, 'units': 'mmol/l'}},
#  {'sample_code': 'CB033SGF0330',
#   'analysis_id': [294],
#   'ph': {'result': 6.93, 'units': 'None'},
#   'electrical_conductivity': {'result': 0.42, 'units': 'mS/cm'},
#   'ammonium': {'result': 7.76, 'units': 'ppm'},
#   'calcium': {'result': 24.3, 'units': 'ppm'},
#   'magnesium': {'result': 6.04, 'units': 'ppm'},
#   'potassium': {'result': 47.4, 'units': 'ppm'},
#   'phosphorus': {'result': 13.6, 'units': 'ppm'},
#   'nitrate_n': {'result': 11.5, 'units': 'ppm'},
#   'nitrates': {'result': 50.9, 'units': 'ppm'},
#   'sulphur': {'result': 21.8, 'units': 'ppm'},
#   'iron': {'result': 4.39, 'units': 'ppm'},
#   'manganese': {'result': 0.03, 'units': 'ppm'},
#   'zinc': {'result': 4.56, 'units': 'ppm'},
#   'boron': {'result': 1.31, 'units': 'ppm'},
#   'copper': {'result': 1.87, 'units': 'ppm'},
#   'molybdenum': {'result': 0.13, 'units': 'ppm'},
#   'sodium': {'result': 16.8, 'units': 'ppm'},
#   'chloride': {'result': 20.0, 'units': 'ppm'},
#   'bicarbonate': {'result': 39.9, 'units': 'ppm'},
#   'silicon__': {'result': 13.1, 'units': 'ppm'}},
#  {'sample_code': 'CV010SGF0234',
#   'analysis_id': [27454],
#   'ph': {'result': 6.23, 'units': 'None'},
#   'electrical_conductivity': {'result': 1.35, 'units': 'mS/cm'},
#   'ammonium': {'result': 0.56, 'units': 'mmol/l'},
#   'calcium': {'result': 2.79, 'units': 'mmol/l'},
#   'magnesium': {'result': 1.53, 'units': 'mmol/l'},
#   'potassium': {'result': 2.94, 'units': 'mmol/l'},
#   'phosphorus': {'result': 0.51, 'units': 'mmol/l'},
#   'nitrate_n': {'result': 4.69, 'units': 'mmol/l'},
#   'nitrates': {'result': 5.74, 'units': 'mmol/l'},
#   'sulphur': {'result': 2.89, 'units': 'mmol/l'},
#   'iron': {'result': 40.0, 'units': 'µmol/l'},
#   'manganese': {'result': 8.93, 'units': 'µmol/l'},
#   'zinc': {'result': 5.5, 'units': 'µmol/l'},
#   'boron': {'result': 24.1, 'units': 'µmol/l'},
#   'copper': {'result': 2.68, 'units': 'µmol/l'},
#   'molybdenum': {'result': 1.15, 'units': 'µmol/l'},
#   'sodium': {'result': 1.28, 'units': 'mmol/l'},
#   'chloride': {'result': 1.3, 'units': 'mmol/l'},
#   'silicon__': {'result': 40.9, 'units': 'µmol/l'},
#   'bicarbonate': {'result': 0.7, 'units': 'mmol/l'}},
#  {'sample_code': 'CB006SGF0239',
#   'analysis_id': [294],
#   'silicon__': {'result': 34.1, 'units': 'ppm'},
#   'iron': {'result': 8.13, 'units': 'ppm'},
#   'ph': {'result': 6.42, 'units': 'None'},
#   'electrical_conductivity': {'result': 0.21, 'units': 'mS/cm'},
#   'ammonium': {'result': 7.36, 'units': 'ppm'},
#   'calcium': {'result': 12.0, 'units': 'ppm'},
#   'magnesium': {'result': 2.63, 'units': 'ppm'},
#   'potassium': {'result': 29.9, 'units': 'ppm'},
#   'phosphorus': {'result': 6.68, 'units': 'ppm'},
#   'nitrate_n': {'result': 9.71, 'units': 'ppm'},
#   'nitrates': {'result': 43.0, 'units': 'ppm'},
#   'sulphur': {'result': 7.92, 'units': 'ppm'},
#   'manganese': {'result': 0.14, 'units': 'ppm'},
#   'zinc': {'result': 0.07, 'units': 'ppm'},
#   'boron': {'result': 0.064, 'units': 'ppm'},
#   'copper': {'result': 0.01, 'units': 'ppm'},
#   'molybdenum': {'result': 0.01, 'units': 'ppm'},
#   'sodium': {'result': 6.02, 'units': 'ppm'},
#   'chloride': {'result': 53.0, 'units': 'ppm'},
#   'bicarbonate': {'result': 11.8, 'units': 'ppm'}},
#  {'sample_code': 'CB006SGF0240',
#   'analysis_id': [294],
#   'manganese': {'result': 0.029, 'units': 'ppm'},
#   'zinc': {'result': 0.014, 'units': 'ppm'},
#   'boron': {'result': 0.091, 'units': 'ppm'},
#   'copper': {'result': 0.015, 'units': 'ppm'},
#   'molybdenum': {'result': 0.076, 'units': 'ppm'},
#   'sodium': {'result': 8.92, 'units': 'ppm'},
#   'chloride': {'result': 35.6, 'units': 'ppm'},
#   'bicarbonate': {'result': 16.2, 'units': 'ppm'},
#   'silicon__': {'result': 15.8, 'units': 'ppm'},
#   'ph': {'result': 6.44, 'units': 'None'},
#   'electrical_conductivity': {'result': 0.41, 'units': 'mS/cm'},
#   'ammonium': {'result': 5.98, 'units': 'ppm'},
#   'calcium': {'result': 22.1, 'units': 'ppm'},
#   'magnesium': {'result': 6.8, 'units': 'ppm'},
#   'potassium': {'result': 43.2, 'units': 'ppm'},
#   'phosphorus': {'result': 6.27, 'units': 'ppm'},
#   'nitrate_n': {'result': 21.0, 'units': 'ppm'},
#   'nitrates': {'result': 93.0, 'units': 'ppm'},
#   'sulphur': {'result': 8.4, 'units': 'ppm'},
#   'iron': {'result': 0.31, 'units': 'ppm'}},
#  {'sample_code': 'CB006SGF0241',
#   'analysis_id': [294],
#   'ph': {'result': 6.12, 'units': 'None'},
#   'electrical_conductivity': {'result': 0.42, 'units': 'mS/cm'},
#   'ammonium': {'result': 5.88, 'units': 'ppm'},
#   'calcium': {'result': 23.9, 'units': 'ppm'},
#   'manganese': {'result': 0.055, 'units': 'ppm'},
#   'zinc': {'result': 0.029, 'units': 'ppm'},
#   'boron': {'result': 0.05, 'units': 'ppm'},
#   'copper': {'result': 0.028, 'units': 'ppm'},
#   'molybdenum': {'result': 0.016, 'units': 'ppm'},
#   'sodium': {'result': 13.1, 'units': 'ppm'},
#   'chloride': {'result': 19.1, 'units': 'ppm'},
#   'bicarbonate': {'result': 12.7, 'units': 'ppm'},
#   'silicon__': {'result': 17.9, 'units': 'ppm'},
#   'magnesium': {'result': 6.46, 'units': 'ppm'},
#   'potassium': {'result': 48.3, 'units': 'ppm'},
#   'phosphorus': {'result': 0.89, 'units': 'ppm'},
#   'nitrate_n': {'result': 16.4, 'units': 'ppm'},
#   'nitrates': {'result': 72.6, 'units': 'ppm'},
#   'sulphur': {'result': 28.7, 'units': 'ppm'},
#   'iron': {'result': 0.33, 'units': 'ppm'}},
#  {'sample_code': 'CT017SGF0378',
#   'analysis_id': [294],
#   'ph': {'result': 5.52, 'units': 'None'},
#   'electrical_conductivity': {'result': 0.93, 'units': 'mS/cm'},
#   'ammonium': {'result': 3.75, 'units': 'ppm'},
#   'calcium': {'result': 78.7, 'units': 'ppm'},
#   'magnesium': {'result': 18.0, 'units': 'ppm'},
#   'potassium': {'result': 51.2, 'units': 'ppm'},
#   'phosphorus': {'result': 1.21, 'units': 'ppm'},
#   'nitrate_n': {'result': 53.4, 'units': 'ppm'},
#   'nitrates': {'result': 236.0, 'units': 'ppm'},
#   'sulphur': {'result': 101.0, 'units': 'ppm'},
#   'iron': {'result': 0.83, 'units': 'ppm'},
#   'manganese': {'result': 0.069, 'units': 'ppm'},
#   'zinc': {'result': 0.016, 'units': 'ppm'},
#   'boron': {'result': 0.025, 'units': 'ppm'},
#   'copper': {'result': 0.017, 'units': 'ppm'},
#   'molybdenum': {'result': 0.01, 'units': 'ppm'},
#   'sodium': {'result': 37.7, 'units': 'ppm'},
#   'chloride': {'result': 4.79, 'units': 'ppm'},
#   'bicarbonate': {'result': 13.5, 'units': 'ppm'},
#   'silicon__': {'result': 17.3, 'units': 'ppm'}},
#  {'sample_code': 'CV010SGF0235',
#   'analysis_id': [27454],
#   'ph': {'result': 6.3, 'units': 'None'},
#   'electrical_conductivity': {'result': 1.23, 'units': 'mS/cm'},
#   'ammonium': {'result': 0.53, 'units': 'mmol/l'},
#   'calcium': {'result': 2.16, 'units': 'mmol/l'},
#   'magnesium': {'result': 1.39, 'units': 'mmol/l'},
#   'potassium': {'result': 2.94, 'units': 'mmol/l'},
#   'phosphorus': {'result': 0.55, 'units': 'mmol/l'},
#   'nitrate_n': {'result': 3.52, 'units': 'mmol/l'},
#   'nitrates': {'result': 4.32, 'units': 'mmol/l'},
#   'sulphur': {'result': 2.89, 'units': 'mmol/l'},
#   'iron': {'result': 31.5, 'units': 'µmol/l'},
#   'manganese': {'result': 6.92, 'units': 'µmol/l'},
#   'zinc': {'result': 4.28, 'units': 'µmol/l'},
#   'boron': {'result': 20.4, 'units': 'µmol/l'},
#   'copper': {'result': 2.36, 'units': 'µmol/l'},
#   'molybdenum': {'result': 0.88, 'units': 'µmol/l'},
#   'sodium': {'result': 1.33, 'units': 'mmol/l'},
#   'chloride': {'result': 1.11, 'units': 'mmol/l'},
#   'silicon__': {'result': 49.8, 'units': 'µmol/l'},
#   'bicarbonate': {'result': 0.75, 'units': 'mmol/l'}},
#  {'sample_code': 'CV010SGF0236',
#   'analysis_id': [27454],
#   'nitrate_n': {'result': 4.81, 'units': 'mmol/l'},
#   'nitrates': {'result': 5.89, 'units': 'mmol/l'},
#   'sulphur': {'result': 2.85, 'units': 'mmol/l'},
#   'iron': {'result': 33.9, 'units': 'µmol/l'},
#   'manganese': {'result': 7.29, 'units': 'µmol/l'},
#   'zinc': {'result': 3.67, 'units': 'µmol/l'},
#   'ph': {'result': 6.38, 'units': 'None'},
#   'electrical_conductivity': {'result': 1.38, 'units': 'mS/cm'},
#   'ammonium': {'result': 0.39, 'units': 'mmol/l'},
#   'calcium': {'result': 2.92, 'units': 'mmol/l'},
#   'magnesium': {'result': 1.51, 'units': 'mmol/l'},
#   'potassium': {'result': 2.97, 'units': 'mmol/l'},
#   'phosphorus': {'result': 0.54, 'units': 'mmol/l'},
#   'boron': {'result': 21.3, 'units': 'µmol/l'},
#   'copper': {'result': 2.99, 'units': 'µmol/l'},
#   'molybdenum': {'result': 0.86, 'units': 'µmol/l'},
#   'sodium': {'result': 1.23, 'units': 'mmol/l'},
#   'chloride': {'result': 1.25, 'units': 'mmol/l'},
#   'silicon__': {'result': 30.6, 'units': 'µmol/l'},
#   'bicarbonate': {'result': 0.71, 'units': 'mmol/l'}},
#  {'sample_code': 'CV010SGF0237',
#   'analysis_id': [27454],
#   'ph': {'result': 6.42, 'units': 'None'},
#   'electrical_conductivity': {'result': 1.4, 'units': 'mS/cm'},
#   'ammonium': {'result': 0.44, 'units': 'mmol/l'},
#   'calcium': {'result': 2.79, 'units': 'mmol/l'},
#   'magnesium': {'result': 1.55, 'units': 'mmol/l'},
#   'potassium': {'result': 3.27, 'units': 'mmol/l'},
#   'phosphorus': {'result': 0.5, 'units': 'mmol/l'},
#   'nitrate_n': {'result': 4.5, 'units': 'mmol/l'},
#   'nitrates': {'result': 5.52, 'units': 'mmol/l'},
#   'sulphur': {'result': 3.15, 'units': 'mmol/l'},
#   'iron': {'result': 29.4, 'units': 'µmol/l'},
#   'manganese': {'result': 7.83, 'units': 'µmol/l'},
#   'zinc': {'result': 6.42, 'units': 'µmol/l'},
#   'boron': {'result': 22.2, 'units': 'µmol/l'},
#   'copper': {'result': 5.2, 'units': 'µmol/l'},
#   'molybdenum': {'result': 0.55, 'units': 'µmol/l'},
#   'sodium': {'result': 1.24, 'units': 'mmol/l'},
#   'chloride': {'result': 1.15, 'units': 'mmol/l'},
#   'silicon__': {'result': 29.9, 'units': 'µmol/l'},
#   'bicarbonate': {'result': 0.86, 'units': 'mmol/l'}},
#  {'sample_code': 'CV010SGF0238',
#   'analysis_id': [27454],
#   'ph': {'result': 6.51, 'units': 'None'},
#   'electrical_conductivity': {'result': 1.4, 'units': 'mS/cm'},
#   'ammonium': {'result': 0.46, 'units': 'mmol/l'},
#   'calcium': {'result': 2.74, 'units': 'mmol/l'},
#   'magnesium': {'result': 1.56, 'units': 'mmol/l'},
#   'potassium': {'result': 3.35, 'units': 'mmol/l'},
#   'phosphorus': {'result': 0.5, 'units': 'mmol/l'},
#   'nitrate_n': {'result': 4.53, 'units': 'mmol/l'},
#   'nitrates': {'result': 5.55, 'units': 'mmol/l'},
#   'sulphur': {'result': 3.21, 'units': 'mmol/l'},
#   'iron': {'result': 27.6, 'units': 'µmol/l'},
#   'manganese': {'result': 7.65, 'units': 'µmol/l'},
#   'zinc': {'result': 6.88, 'units': 'µmol/l'},
#   'boron': {'result': 22.2, 'units': 'µmol/l'},
#   'copper': {'result': 5.51, 'units': 'µmol/l'},
#   'molybdenum': {'result': 0.75, 'units': 'µmol/l'},
#   'sodium': {'result': 1.24, 'units': 'mmol/l'},
#   'chloride': {'result': 1.15, 'units': 'mmol/l'},
#   'silicon__': {'result': 28.1, 'units': 'µmol/l'},
#   'bicarbonate': {'result': 0.78, 'units': 'mmol/l'}},
#  {'sample_code': 'CT017SGF0377',
#   'analysis_id': [294],
#   'chloride': {'result': 5.12, 'units': 'ppm'},
#   'bicarbonate': {'result': 17.0, 'units': 'ppm'},
#   'silicon__': {'result': 12.6, 'units': 'ppm'},
#   'ph': {'result': 5.84, 'units': 'None'},
#   'electrical_conductivity': {'result': 0.66, 'units': 'mS/cm'},
#   'ammonium': {'result': 5.27, 'units': 'ppm'},
#   'calcium': {'result': 65.1, 'units': 'ppm'},
#   'magnesium': {'result': 11.9, 'units': 'ppm'},
#   'potassium': {'result': 48.5, 'units': 'ppm'},
#   'phosphorus': {'result': 1.18, 'units': 'ppm'},
#   'nitrate_n': {'result': 5.08, 'units': 'ppm'},
#   'nitrates': {'result': 22.5, 'units': 'ppm'},
#   'sulphur': {'result': 119.0, 'units': 'ppm'},
#   'iron': {'result': 0.63, 'units': 'ppm'},
#   'manganese': {'result': 0.035, 'units': 'ppm'},
#   'zinc': {'result': 0.01, 'units': 'ppm'},
#   'boron': {'result': 0.15, 'units': 'ppm'},
#   'copper': {'result': 0.011, 'units': 'ppm'},
# ...
#   'ammonium': {'result': 0.01, 'units': 'mmol/l'},
#   'calcium': {'result': 3.67, 'units': 'mmol/l'},
#   'magnesium': {'result': 1.59, 'units': 'mmol/l'},
#   'potassium': {'result': 3.25, 'units': 'mmol/l'},
#   'phosphorus': {'result': 0.6, 'units': 'mmol/l'},
#   'nitrate_n': {'result': 9.55, 'units': 'mmol/l'},
#   'nitrates': {'result': 11.7, 'units': 'mmol/l'},
#   'sulphur': {'result': 2.28, 'units': 'mmol/l'},
#   'iron': {'result': 45.2, 'units': 'µmol/l'},
#   'manganese': {'result': 36.2, 'units': 'µmol/l'},
#   'zinc': {'result': 15.6, 'units': 'µmol/l'},
#   'boron': {'result': 34.3, 'units': 'µmol/l'},
#   'copper': {'result': 8.5, 'units': 'µmol/l'},
#   'molybdenum': {'result': 0.39, 'units': 'µmol/l'},
#   'sodium': {'result': 2.76, 'units': 'mmol/l'},
#   'chloride': {'result': 0.5, 'units': 'mmol/l'},
#   'silicon__': {'result': 694.0, 'units': 'µmol/l'},
#   'bicarbonate': {'result': 0.65, 'units': 'mmol/l'}},
#  {'sample_code': 'CM173SGF3289      ',
#   'analysis_id': [27454],
#   'ph': {'result': 5.59, 'units': 'None'},
#   'electrical_conductivity': {'result': 1.87, 'units': 'mS/cm'},
#   'ammonium': {'result': 0.45, 'units': 'mmol/l'},
#   'calcium': {'result': 3.59, 'units': 'mmol/l'},
#   'magnesium': {'result': 1.7, 'units': 'mmol/l'},
#   'potassium': {'result': 3.32, 'units': 'mmol/l'},
#   'phosphorus': {'result': 0.65, 'units': 'mmol/l'},
#   'nitrate_n': {'result': 10.2, 'units': 'mmol/l'},
#   'nitrates': {'result': 12.5, 'units': 'mmol/l'},
#   'sulphur': {'result': 2.03, 'units': 'mmol/l'},
#   'iron': {'result': 41.0, 'units': 'µmol/l'},
#   'manganese': {'result': 34.1, 'units': 'µmol/l'},
#   'zinc': {'result': 15.6, 'units': 'µmol/l'},
#   'boron': {'result': 35.2, 'units': 'µmol/l'},
#   'copper': {'result': 9.29, 'units': 'µmol/l'},
#   'molybdenum': {'result': 0.48, 'units': 'µmol/l'},
#   'sodium': {'result': 2.77, 'units': 'mmol/l'},
#   'chloride': {'result': 0.55, 'units': 'mmol/l'},
#   'silicon__': {'result': 705.0, 'units': 'µmol/l'},
#   'bicarbonate': {'result': 0.61, 'units': 'mmol/l'}},
#  {'sample_code': 'CM173SGF3290      ',
#   'analysis_id': [27454],
#   'ph': {'result': 5.8, 'units': 'None'},
#   'electrical_conductivity': {'result': 1.84, 'units': 'mS/cm'},
#   'ammonium': {'result': 0.39, 'units': 'mmol/l'},
#   'calcium': {'result': 3.04, 'units': 'mmol/l'},
#   'magnesium': {'result': 1.88, 'units': 'mmol/l'},
#   'potassium': {'result': 3.48, 'units': 'mmol/l'},
#   'phosphorus': {'result': 0.58, 'units': 'mmol/l'},
#   'nitrate_n': {'result': 10.2, 'units': 'mmol/l'},
#   'nitrates': {'result': 12.5, 'units': 'mmol/l'},
#   'sulphur': {'result': 1.78, 'units': 'mmol/l'},
#   'iron': {'result': 32.3, 'units': 'µmol/l'},
#   'manganese': {'result': 28.2, 'units': 'µmol/l'},
#   'zinc': {'result': 12.5, 'units': 'µmol/l'},
#   'boron': {'result': 27.8, 'units': 'µmol/l'},
#   'copper': {'result': 6.46, 'units': 'µmol/l'},
#   'molybdenum': {'result': 0.53, 'units': 'µmol/l'},
#   'sodium': {'result': 2.65, 'units': 'mmol/l'},
#   'chloride': {'result': 0.47, 'units': 'mmol/l'},
#   'silicon__': {'result': 690.0, 'units': 'µmol/l'},
#   'bicarbonate': {'result': 0.67, 'units': 'mmol/l'}},
#  {'sample_code': 'CM173SGF3291      ',
#   'analysis_id': [27454],
#   'ph': {'result': 5.37, 'units': 'None'},
#   'electrical_conductivity': {'result': 1.9, 'units': 'mS/cm'},
#   'ammonium': {'result': 0.56, 'units': 'mmol/l'},
#   'calcium': {'result': 3.54, 'units': 'mmol/l'},
#   'magnesium': {'result': 1.76, 'units': 'mmol/l'},
#   'potassium': {'result': 3.48, 'units': 'mmol/l'},
#   'phosphorus': {'result': 0.64, 'units': 'mmol/l'},
#   'nitrate_n': {'result': 9.9, 'units': 'mmol/l'},
#   'nitrates': {'result': 12.1, 'units': 'mmol/l'},
#   'sulphur': {'result': 2.21, 'units': 'mmol/l'},
#   'iron': {'result': 37.6, 'units': 'µmol/l'},
#   'manganese': {'result': 32.2, 'units': 'µmol/l'},
#   'zinc': {'result': 14.8, 'units': 'µmol/l'},
#   'boron': {'result': 34.3, 'units': 'µmol/l'},
#   'copper': {'result': 9.29, 'units': 'µmol/l'},
#   'molybdenum': {'result': 0.33, 'units': 'µmol/l'},
#   'sodium': {'result': 2.72, 'units': 'mmol/l'},
#   'chloride': {'result': 0.56, 'units': 'mmol/l'},
#   'silicon__': {'result': 687.0, 'units': 'µmol/l'},
#   'bicarbonate': {'result': 0.54, 'units': 'mmol/l'}},
#  {'sample_code': 'CM173SGF3292      ',
#   'analysis_id': [27454],
#   'ph': {'result': 5.83, 'units': 'None'},
#   'electrical_conductivity': {'result': 1.88, 'units': 'mS/cm'},
#   'ammonium': {'result': 0.48, 'units': 'mmol/l'},
#   'calcium': {'result': 3.49, 'units': 'mmol/l'},
#   'magnesium': {'result': 1.82, 'units': 'mmol/l'},
#   'potassium': {'result': 3.25, 'units': 'mmol/l'},
#   'phosphorus': {'result': 0.65, 'units': 'mmol/l'},
#   'nitrate_n': {'result': 6.47, 'units': 'mmol/l'},
#   'nitrates': {'result': 7.92, 'units': 'mmol/l'},
#   'sulphur': {'result': 1.63, 'units': 'mmol/l'},
#   'iron': {'result': 40.3, 'units': 'µmol/l'},
#   'manganese': {'result': 35.0, 'units': 'µmol/l'},
#   'zinc': {'result': 15.3, 'units': 'µmol/l'},
#   'boron': {'result': 33.3, 'units': 'µmol/l'},
#   'copper': {'result': 8.5, 'units': 'µmol/l'},
#   'molybdenum': {'result': 0.39, 'units': 'µmol/l'},
#   'sodium': {'result': 2.8, 'units': 'mmol/l'},
#   'chloride': {'result': 0.51, 'units': 'mmol/l'},
#   'silicon__': {'result': 708.0, 'units': 'µmol/l'},
#   'bicarbonate': {'result': 0.62, 'units': 'mmol/l'}},
#  {'sample_code': 'CM173SGF3293      ',
#   'analysis_id': [27454],
#   'ph': {'result': 5.55, 'units': 'None'},
#   'electrical_conductivity': {'result': 1.87, 'units': 'mS/cm'},
#   'ammonium': {'result': 0.55, 'units': 'mmol/l'},
#   'calcium': {'result': 3.59, 'units': 'mmol/l'},
#   'magnesium': {'result': 1.75, 'units': 'mmol/l'},
#   'potassium': {'result': 3.32, 'units': 'mmol/l'},
#   'phosphorus': {'result': 0.65, 'units': 'mmol/l'},
#   'nitrate_n': {'result': 10.7, 'units': 'mmol/l'},
#   'nitrates': {'result': 13.1, 'units': 'mmol/l'},
#   'sulphur': {'result': 1.56, 'units': 'mmol/l'},
#   'iron': {'result': 40.0, 'units': 'µmol/l'},
#   'manganese': {'result': 34.1, 'units': 'µmol/l'},
#   'zinc': {'result': 15.6, 'units': 'µmol/l'},
#   'boron': {'result': 36.1, 'units': 'µmol/l'},
#   'copper': {'result': 10.1, 'units': 'µmol/l'},
#   'molybdenum': {'result': 0.58, 'units': 'µmol/l'},
#   'sodium': {'result': 2.83, 'units': 'mmol/l'},
#   'chloride': {'result': 0.54, 'units': 'mmol/l'},
#   'silicon__': {'result': 708.0, 'units': 'µmol/l'},
#   'bicarbonate': {'result': 0.59, 'units': 'mmol/l'}},
#  {'sample_code': 'CM173SGF3294      ',
#   'analysis_id': [27454],
#   'ph': {'result': 5.58, 'units': 'None'},
#   'electrical_conductivity': {'result': 1.88, 'units': 'mS/cm'},
#   'ammonium': {'result': 0.58, 'units': 'mmol/l'},
#   'calcium': {'result': 3.67, 'units': 'mmol/l'},
#   'magnesium': {'result': 1.69, 'units': 'mmol/l'},
#   'potassium': {'result': 3.45, 'units': 'mmol/l'},
#   'phosphorus': {'result': 0.66, 'units': 'mmol/l'},
#   'nitrate_n': {'result': 10.1, 'units': 'mmol/l'},
#   'nitrates': {'result': 12.4, 'units': 'mmol/l'},
#   'sulphur': {'result': 2.09, 'units': 'mmol/l'},
#   'iron': {'result': 40.3, 'units': 'µmol/l'},
#   'manganese': {'result': 35.0, 'units': 'µmol/l'},
#   'zinc': {'result': 15.9, 'units': 'µmol/l'},
#   'boron': {'result': 36.1, 'units': 'µmol/l'},
#   'copper': {'result': 9.61, 'units': 'µmol/l'},
#   'molybdenum': {'result': 0.43, 'units': 'µmol/l'},
#   'sodium': {'result': 2.86, 'units': 'mmol/l'},
#   'chloride': {'result': 0.57, 'units': 'mmol/l'},
#   'silicon__': {'result': 712.0, 'units': 'µmol/l'},
#   'bicarbonate': {'result': 0.65, 'units': 'mmol/l'}},
#  {'sample_code': 'CM173SGF3295      ',
#   'analysis_id': [27454],
#   'ph': {'result': 5.87, 'units': 'None'},
#   'electrical_conductivity': {'result': 1.86, 'units': 'mS/cm'},
#   'ammonium': {'result': 0.6, 'units': 'mmol/l'},
#   'calcium': {'result': 3.69, 'units': 'mmol/l'},
#   'magnesium': {'result': 1.76, 'units': 'mmol/l'},
#   'potassium': {'result': 3.07, 'units': 'mmol/l'},
#   'phosphorus': {'result': 0.65, 'units': 'mmol/l'},
#   'nitrate_n': {'result': 9.96, 'units': 'mmol/l'},
#   'nitrates': {'result': 12.2, 'units': 'mmol/l'},
#   'sulphur': {'result': 1.62, 'units': 'mmol/l'},
#   'iron': {'result': 36.6, 'units': 'µmol/l'},
#   'manganese': {'result': 32.1, 'units': 'µmol/l'},
#   'zinc': {'result': 14.7, 'units': 'µmol/l'},
#   'boron': {'result': 33.3, 'units': 'µmol/l'},
#   'copper': {'result': 8.5, 'units': 'µmol/l'},
#   'molybdenum': {'result': 0.47, 'units': 'µmol/l'},
#   'sodium': {'result': 2.81, 'units': 'mmol/l'},
#   'chloride': {'result': 0.52, 'units': 'mmol/l'},
#   'silicon__': {'result': 708.0, 'units': 'µmol/l'},
#   'bicarbonate': {'result': 0.56, 'units': 'mmol/l'}},
#  {'sample_code': 'CM173SGF3296      ',
#   'analysis_id': [27454],
#   'ph': {'result': 5.73, 'units': 'None'},
#   'electrical_conductivity': {'result': 1.89, 'units': 'mS/cm'},
#   'ammonium': {'result': 0.6, 'units': 'mmol/l'},
#   'calcium': {'result': 3.69, 'units': 'mmol/l'},
#   'magnesium': {'result': 1.77, 'units': 'mmol/l'},
#   'potassium': {'result': 3.12, 'units': 'mmol/l'},
#   'phosphorus': {'result': 0.66, 'units': 'mmol/l'},
#   'nitrate_n': {'result': 10.1, 'units': 'mmol/l'},
#   'nitrates': {'result': 12.4, 'units': 'mmol/l'},
#   'sulphur': {'result': 1.62, 'units': 'mmol/l'},
#   'iron': {'result': 39.1, 'units': 'µmol/l'},
#   'manganese': {'result': 33.5, 'units': 'µmol/l'},
#   'zinc': {'result': 15.4, 'units': 'µmol/l'},
#   'boron': {'result': 34.3, 'units': 'µmol/l'},
#   'copper': {'result': 8.98, 'units': 'µmol/l'},
#   'molybdenum': {'result': 0.45, 'units': 'µmol/l'},
#   'sodium': {'result': 2.79, 'units': 'mmol/l'},
#   'chloride': {'result': 0.5, 'units': 'mmol/l'},
#   'silicon__': {'result': 701.0, 'units': 'µmol/l'},
#   'bicarbonate': {'result': 0.57, 'units': 'mmol/l'}},
#  {'sample_code': 'CM173SGF3297      ',
#   'analysis_id': [27454],
#   'ph': {'result': 5.85, 'units': 'None'},
#   'electrical_conductivity': {'result': 1.86, 'units': 'mS/cm'},
#   'ammonium': {'result': 0.59, 'units': 'mmol/l'},
#   'calcium': {'result': 3.77, 'units': 'mmol/l'},
#   'magnesium': {'result': 1.73, 'units': 'mmol/l'},
#   'potassium': {'result': 2.92, 'units': 'mmol/l'},
#   'phosphorus': {'result': 0.64, 'units': 'mmol/l'},
#   'nitrate_n': {'result': 10.7, 'units': 'mmol/l'},
#   'nitrates': {'result': 13.1, 'units': 'mmol/l'},
#   'sulphur': {'result': 1.6, 'units': 'mmol/l'},
#   'iron': {'result': 36.2, 'units': 'µmol/l'},
#   'manganese': {'result': 31.7, 'units': 'µmol/l'},
#   'zinc': {'result': 14.7, 'units': 'µmol/l'},
#   'boron': {'result': 34.3, 'units': 'µmol/l'},
#   'copper': {'result': 8.82, 'units': 'µmol/l'},
#   'molybdenum': {'result': 0.51, 'units': 'µmol/l'},
#   'sodium': {'result': 2.8, 'units': 'mmol/l'},
#   'chloride': {'result': 0.55, 'units': 'mmol/l'},
#   'silicon__': {'result': 708.0, 'units': 'µmol/l'},
#   'bicarbonate': {'result': 0.7, 'units': 'mmol/l'}},
#  {'sample_code': 'CM173SGF3298      ',
#   'analysis_id': [27454],
#   'ph': {'result': 5.7, 'units': 'None'},
#   'electrical_conductivity': {'result': 1.86, 'units': 'mS/cm'},
#   'ammonium': {'result': 0.58, 'units': 'mmol/l'},
#   'calcium': {'result': 3.79, 'units': 'mmol/l'},
#   'magnesium': {'result': 1.67, 'units': 'mmol/l'},
#   'potassium': {'result': 2.79, 'units': 'mmol/l'},
#   'phosphorus': {'result': 0.64, 'units': 'mmol/l'},
#   'nitrate_n': {'result': 9.61, 'units': 'mmol/l'},
#   'nitrates': {'result': 11.8, 'units': 'mmol/l'},
#   'sulphur': {'result': 1.96, 'units': 'mmol/l'},
#   'iron': {'result': 38.0, 'units': 'µmol/l'},
#   'manganese': {'result': 31.7, 'units': 'µmol/l'},
#   'zinc': {'result': 14.4, 'units': 'µmol/l'},
#   'boron': {'result': 34.3, 'units': 'µmol/l'},
#   'copper': {'result': 8.66, 'units': 'µmol/l'},
#   'molybdenum': {'result': 0.3, 'units': 'µmol/l'},
#   'sodium': {'result': 2.69, 'units': 'mmol/l'},
#   'chloride': {'result': 0.54, 'units': 'mmol/l'},
#   'silicon__': {'result': 690.0, 'units': 'µmol/l'},
#   'bicarbonate': {'result': 0.61, 'units': 'mmol/l'}},
#  {'sample_code': 'CM173SGF3299      ',
#   'analysis_id': [26823],
#   'ph': {'result': 7.41, 'units': 'None'},
#   'electrical_conductivity': {'result': 0.42, 'units': 'mS cm -1'},
#   'ammonium': {'result': 0.01, 'units': 'mmol/l'},
#   'calcium': {'result': 0.53, 'units': 'mmol/l'},
#   'magnesium': {'result': 0.041, 'units': 'mmol/l'},
#   'potassium': {'result': 0.29, 'units': 'mmol/l'},
#   'phosphorus': {'result': 0.00032, 'units': 'mmol/l'},
#   'nitrate_n': {'result': 0.62, 'units': 'mmol/l'},
#   'nitrates': {'result': 0.76, 'units': 'mmol/l'},
#   'sulphur': {'result': 0.41, 'units': 'mmol/l'},
#   'iron': {'result': 0.77, 'units': 'µmol/l'},
#   'manganese': {'result': 0.18, 'units': 'µmol/l'},
#   'zinc': {'result': 1.39, 'units': 'µmol/l'},
#   'copper': {'result': 0.16, 'units': 'µmol/l'},
#   'boron': {'result': 2.22, 'units': 'µmol/l'},
#   'molybdenum': {'result': 0.1, 'units': 'µmol/l'},
#   'sodium': {'result': 2.55, 'units': 'mmol/l'},
#   'chloride': {'result': 0.36, 'units': 'mmol/l'},
#   'bicarbonate': {'result': 2.0, 'units': 'mmol/l'},
#   'silicon__': {'result': 705.0, 'units': 'µmol/l'}},
#  {'sample_code': 'CF053SGF0133',
#   'analysis_id': [294],
#   'ph': {'result': 6.86, 'units': 'None'},
#   'electrical_conductivity': {'result': 1.43, 'units': 'mS/cm'},
#   'ammonium': {'result': 8.31, 'units': 'ppm'},
#   'calcium': {'result': 70.2, 'units': 'ppm'},
#   'magnesium': {'result': 22.0, 'units': 'ppm'},
#   'potassium': {'result': 185.0, 'units': 'ppm'},
#   'phosphorus': {'result': 19.4, 'units': 'ppm'},
#   'nitrate_n': {'result': 56.5, 'units': 'ppm'},
#   'nitrates': {'result': 250.0, 'units': 'ppm'},
#   'sulphur': {'result': 97.5, 'units': 'ppm'},
#   'iron': {'result': 0.012, 'units': 'ppm'},
#   'manganese': {'result': 0.01, 'units': 'ppm'},
#   'zinc': {'result': 0.03, 'units': 'ppm'},
#   'boron': {'result': 0.22, 'units': 'ppm'},
#   'molybdenum': {'result': 0.084, 'units': 'ppm'},
#   'copper': {'result': 0.029, 'units': 'ppm'},
#   'sodium': {'result': 88.0, 'units': 'ppm'},
#   'chloride': {'result': 53.1, 'units': 'ppm'},
#   'bicarbonate': {'result': 40.9, 'units': 'ppm'},
#   'silicon__': {'result': 18.1, 'units': 'ppm'}},
#  {'sample_code': 'CF053SGF0134',
#   'analysis_id': [294],
#   'ph': {'result': 7.01, 'units': 'None'},
#   'electrical_conductivity': {'result': 2.87, 'units': 'mS/cm'},
#   'ammonium': {'result': 9.05, 'units': 'ppm'},
#   'calcium': {'result': 237.0, 'units': 'ppm'},
#   'magnesium': {'result': 73.7, 'units': 'ppm'},
#   'potassium': {'result': 427.0, 'units': 'ppm'},
#   'phosphorus': {'result': 12.2, 'units': 'ppm'},
#   'nitrate_n': {'result': 93.6, 'units': 'ppm'},
#   'nitrates': {'result': 414.0, 'units': 'ppm'},
#   'sulphur': {'result': 405.0, 'units': 'ppm'},
#   'iron': {'result': 0.01, 'units': 'ppm'},
#   'manganese': {'result': 0.01, 'units': 'ppm'},
#   'zinc': {'result': 0.038, 'units': 'ppm'},
#   'boron': {'result': 0.28, 'units': 'ppm'},
#   'copper': {'result': 0.047, 'units': 'ppm'},
#   'molybdenum': {'result': 0.14, 'units': 'ppm'},
#   'sodium': {'result': 221.0, 'units': 'ppm'},
#   'chloride': {'result': 133.0, 'units': 'ppm'},
#   'bicarbonate': {'result': 57.3, 'units': 'ppm'},
#   'silicon__': {'result': 20.0, 'units': 'ppm'}},
#  {'sample_code': 'CE249SGF0073',
#   'analysis_id': [294],
#   'ph': {'result': 7.52, 'units': 'None'},
#   'electrical_conductivity': {'result': 4.63, 'units': 'mS/cm'},
#   'ammonium': {'result': 5.75, 'units': 'ppm'},
#   'calcium': {'result': 170.0, 'units': 'ppm'},
#   'magnesium': {'result': 42.8, 'units': 'ppm'},
#   'potassium': {'result': 58.5, 'units': 'ppm'},
#   'phosphorus': {'result': 0.32, 'units': 'ppm'},
#   'nitrate_n': {'result': 64.0, 'units': 'ppm'},
#   'nitrates': {'result': 283.0, 'units': 'ppm'},
#   'sulphur': {'result': 419.0, 'units': 'ppm'},
#   'iron': {'result': 0.01, 'units': 'ppm'},
#   'manganese': {'result': 0.01, 'units': 'ppm'},
#   'zinc': {'result': 0.01, 'units': 'ppm'},
#   'boron': {'result': 0.34, 'units': 'ppm'},
#   'copper': {'result': 0.035, 'units': 'ppm'},
#   'molybdenum': {'result': 0.012, 'units': 'ppm'},
#   'sodium': {'result': 781.0, 'units': 'ppm'},
#   'chloride': {'result': 465.0, 'units': 'ppm'},
#   'bicarbonate': {'result': 65.7, 'units': 'ppm'},
#   'silicon__': {'result': 17.3, 'units': 'ppm'}}]

# %%
reverse_analysis_dict['1:2 Soil Volume Extract']
# Out:
# 294

# %%
analysis_dict = pd.read_sql(f"""SELECT analysis_id, LTRIM(RTRIM(analysis_name)) as analysis_name FROM Analysis  ORDER BY analysis_name""",con=conn_lims).set_index("analysis_id").to_dict()['analysis_name']
# Out:
# C:\Users\tsuma.thomas\AppData\Local\Temp\ipykernel_11632\132348878.py:1: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   analysis_dict = pd.read_sql(f"""SELECT analysis_id, LTRIM(RTRIM(analysis_name)) as analysis_name FROM Analysis  ORDER BY analysis_name""",con=conn_lims).set_index("analysis_id").to_dict()['analysis_name']

# %%
pickle.dump(analysis_dict, open("analysis.dict","wb"))

# %%
analysis_dict = pickle.load(open("analysis.dict","rb"))

# %%
mahalanobis_thresholds = pickle.load(open("mahalanobis_thresholds.dict","rb"))

# %%
pd.DataFrame({'analysis_name':mahalanobis_thresholds.keys()}).to_csv("output/analyses_in_models.csv")

# %%
unit_decision = pd.read_csv("output/sgf_unit_per_chemical_decision.csv")

# %%
ppmmol_df = pd.read_csv("ppm-mmol.csv")
conversion_dict = ppmmol_df[['Element','Ppm to Mmol/L multiply value by;']].set_index("Element").to_dict()['Ppm to Mmol/L multiply value by;']
conversion_dict
# Out:
# {'Al': 0.0371,
#  'B': 0.0925,
#  'Ca': 0.025,
#  'Cl': 0.0282,
#  'CO3': 0.0167,
#  'Cu': 0.0157,
#  'Fe': 0.0179,
#  'HCO3': 0.0164,
#  'K': 0.0256,
#  'Mg': 0.0411,
#  'Mn': 0.0182,
#  'Mo': 0.0104,
#  'N': 0.0714,
#  'Na': 0.0435,
#  'NH4': 0.0554,
#  'NO2': 0.0217,
#  'NO3': 0.2259,
#  'OH': 0.0588,
#  'P': 0.0323,
#  'PO4': 0.0105,
#  'S': 0.0312,
#  'Si': 0.0356,
#  'SO4': 0.0104,
#  'Zn': 0.0153}

# %%
conversion_dict_2 = ppmmol_df.to_dict("records")
conversion_dict_2
# Out:
# [{'Element': 'Al',
#   'Molecular weight': 26.982,
#   'Ppm to Mmol/L multiply value by;': 0.0371,
#   'LIMS Molecular weight': 26.98,
#   'Conversion': '0.0371*1000',
#   'unit': 'µmol'},
#  {'Element': 'B',
#   'Molecular weight': 10.806,
#   'Ppm to Mmol/L multiply value by;': 0.0925,
#   'LIMS Molecular weight': 10.8,
#   'Conversion': '0.0925*1000',
#   'unit': 'µmol'},
#  {'Element': 'Ca',
#   'Molecular weight': 40.08,
#   'Ppm to Mmol/L multiply value by;': 0.025,
#   'LIMS Molecular weight': 40.1,
#   'Conversion': 'OK',
#   'unit': 'mmol'},
#  {'Element': 'Cl',
#   'Molecular weight': 35.453,
#   'Ppm to Mmol/L multiply value by;': 0.0282,
#   'LIMS Molecular weight': 35.5,
#   'Conversion': 'OK',
#   'unit': 'mmol'},
#  {'Element': 'CO3',
#   'Molecular weight': 60.008,
#   'Ppm to Mmol/L multiply value by;': 0.0167,
#   'LIMS Molecular weight': nan,
#   'Conversion': 'Not implemented in LIMS',
#   'unit': nan},
#  {'Element': 'Cu',
#   'Molecular weight': 63.546,
#   'Ppm to Mmol/L multiply value by;': 0.0157,
#   'LIMS Molecular weight': 63.5,
#   'Conversion': '0.0157*1000',
#   'unit': nan},
#  {'Element': 'Fe',
#   'Molecular weight': 55.845,
#   'Ppm to Mmol/L multiply value by;': 0.0179,
#   'LIMS Molecular weight': 55.8,
#   'Conversion': '0.0179*1000',
#   'unit': nan},
#  {'Element': 'HCO3',
#   'Molecular weight': 61.02,
#   'Ppm to Mmol/L multiply value by;': 0.0164,
#   'LIMS Molecular weight': 61.0,
#   'Conversion': 'OK',
#   'unit': nan},
#  {'Element': 'K',
#   'Molecular weight': 39.0983,
#   'Ppm to Mmol/L multiply value by;': 0.0256,
#   'LIMS Molecular weight': 39.1,
#   'Conversion': 'OK',
#   'unit': nan},
#  {'Element': 'Mg',
#   'Molecular weight': 24.305,
#   'Ppm to Mmol/L multiply value by;': 0.0411,
#   'LIMS Molecular weight': 24.3,
#   'Conversion': 'OK',
#   'unit': nan},
#  {'Element': 'Mn',
#   'Molecular weight': 54.938,
#   'Ppm to Mmol/L multiply value by;': 0.0182,
#   'LIMS Molecular weight': 54.9,
#   'Conversion': '0.01828*1000',
#   'unit': nan},
#  {'Element': 'Mo',
#   'Molecular weight': 95.95,
#   'Ppm to Mmol/L multiply value by;': 0.0104,
#   'LIMS Molecular weight': 95.9,
#   'Conversion': '0.0104*1000',
#   'unit': nan},
#  {'Element': 'N',
#   'Molecular weight': 14.00674,
#   'Ppm to Mmol/L multiply value by;': 0.0714,
#   'LIMS Molecular weight': 14.0,
#   'Conversion': nan,
#   'unit': nan},
#  {'Element': 'Na',
#   'Molecular weight': 22.989,
#   'Ppm to Mmol/L multiply value by;': 0.0435,
#   'LIMS Molecular weight': 23.0,
#   'Conversion': 'OK',
#   'unit': nan},
#  {'Element': 'NH4',
#   'Molecular weight': 18.00674,
#   'Ppm to Mmol/L multiply value by;': 0.0554,
#   'LIMS Molecular weight': 18.0,
#   'Conversion': 'OK',
#   'unit': nan},
#  {'Element': 'NO2',
#   'Molecular weight': 46.01,
#   'Ppm to Mmol/L multiply value by;': 0.0217,
#   'LIMS Molecular weight': 46.0,
#   'Conversion': nan,
#   'unit': nan},
#  {'Element': 'NO3',
#   'Molecular weight': 62.00674,
#   'Ppm to Mmol/L multiply value by;': 0.2259,
#   'LIMS Molecular weight': 62.0,
#   'Conversion': 'OK',
#   'unit': nan},
#  {'Element': 'OH',
#   'Molecular weight': 17.01,
#   'Ppm to Mmol/L multiply value by;': 0.0588,
#   'LIMS Molecular weight': 0.0,
#   'Conversion': 'Not implemented in LIMS',
#   'unit': nan},
#  {'Element': 'P',
#   'Molecular weight': 30.9737,
#   'Ppm to Mmol/L multiply value by;': 0.0323,
#   'LIMS Molecular weight': 31.0,
#   'Conversion': 'OK',
#   'unit': nan},
#  {'Element': 'PO4',
#   'Molecular weight': 94.97,
#   'Ppm to Mmol/L multiply value by;': 0.0105,
#   'LIMS Molecular weight': 0.0,
#   'Conversion': 'Not implemented in LIMS',
#   'unit': nan},
#  {'Element': 'S',
#   'Molecular weight': 32.066,
#   'Ppm to Mmol/L multiply value by;': 0.0312,
#   'LIMS Molecular weight': 32.1,
#   'Conversion': 'OK',
#   'unit': nan},
#  {'Element': 'Si',
#   'Molecular weight': 28.0855,
#   'Ppm to Mmol/L multiply value by;': 0.0356,
#   'LIMS Molecular weight': 28.1,
#   'Conversion': '0.0356*1000',
#   'unit': nan},
#  {'Element': 'SO4',
#   'Molecular weight': 96.06,
#   'Ppm to Mmol/L multiply value by;': 0.0104,
#   'LIMS Molecular weight': 32.1,
#   'Conversion': 'Uses S = 0.0312',
#   'unit': nan},
#  {'Element': 'Zn',
#   'Molecular weight': 65.38,
#   'Ppm to Mmol/L multiply value by;': 0.0153,
#   'LIMS Molecular weight': 65.4,
#   'Conversion': '0.0153*100',
#   'unit': nan}]

# %%
chemicals['chemical_symbol'] = [ str(i).strip() for i in chemicals['chemical_symbol']]

# %%
chemicals_dict = chemicals.set_index("chemical_name").to_dict()['chemical_symbol']
chemicals_dict
# Out:
# {'potassium': 'K',
#  'ph': 'pH',
#  'calcium': 'Ca',
#  'sodium': 'Na',
#  'magnesium': 'Mg',
#  'cec': 'C.E.C',
#  'sulphur': 'S',
#  'manganese': 'Mn',
#  'copper': 'Cu',
#  'boron': 'B',
#  'zinc': 'Zn',
#  'molybdenum': 'Mo',
#  'iron': 'Fe',
#  'phosphorus_olsen': 'P(O)',
#  'phosphorusbray1-sensor': 'P(S)',
#  'organic_matter': 'OM',
#  'phosphorus': 'P',
#  'chloride': 'Cl',
#  'carbonate': 'CO3',
#  'bicarbonate': 'HCO3',
#  'fluorine': 'F',
#  'nitrates': 'NO3',
#  'nitrate_n': 'NO3N',
#  'nitrite_n': 'NO2N',
#  'ammonium': 'NH4',
#  'sulphate': 'SO4',
#  'chromium': 'Cr',
#  'nickel': 'Ni',
#  'lead': 'Pb',
#  'hydrogen': 'H',
#  'phosphate': 'PO4',
#  'sand': '%Sand',
#  'silt': '%Silt',
#  'clay': '%Clay',
#  'stones': 'ST',
#  'cadmium': 'Cd',
#  'arsenic': 'As',
#  'lithium': 'Li',
#  'nobelium': 'No',
#  'ci': 'Ci',
#  'h2po4': 'h2po',
#  'iodine': 'I',
#  'cobalt': 'Co',
#  'se': 'se',
#  'nitrate_nitrogen': 'NON3',
#  'total_dissolved_solids': 'TDS',
#  'turbidity': 'TUB',
#  'chlorine': 'Cln',
#  'ammonia': 'NH3',
#  'exch_acidity_kcl': 'EA',
#  'electrical_conductivity': 'EC',
#  'calcium_carbonate': 'CaCO3',
#  'colour': 'Col',
#  'cyanide___': 'CN',
#  'selenium': 'Se',
#  'suspended_material': 'nan',
#  'taste_and_odour': 'nan',
#  'tds': 'nan',
#  '_heptachlor_and_heptachlor_epo': 'nan',
#  '1,2_dichlorobenzene_': 'nan',
#  '1,2-dichloroethene__': 'nan',
#  '1,2-dichloropropane': 'nan',
#  '1,4_dichlorobenzene_': 'nan',
#  '2,4,5-t__________': 'nan',
#  '2,4,6-trichlorophenol_': 'nan',
#  '2,4-d': 'nan',
#  '2,4-db______': 'nan',
#  '2,4-dichlorophenol_': 'nan',
#  '2-chlorophenol_': 'nan',
#  'alachlor': 'nan',
#  'aldicarb_____': 'nan',
#  'aldrin_dieldriu': 'nan',
#  'aluminium': 'Al',
#  'antimony__': 'Sb',
#  'atrezine': 'nan',
#  'bentazone': 'nan',
#  'benzene__': 'C6H12',
#  'beryllium__': 'Be',
#  'calcium_sulphate_caso4_': 'CaSO4',
#  'carbofuran': 'nan',
#  'chloramines___': 'nan',
#  'chlordane': 'nan',
#  'chlorine_dioxide_': 'nan',
#  'chlorate_________': 'Chlorate',
#  'chlorotoluron': 'nan',
#  'faecal_coliforms': 'FC',
#  'ddt': 'nan',
#  'dibromoacetonitrile__': 'nan',
#  'dichlororprop_____': 'nan',
#  'dicholoroacetonitrile_': 'nan',
#  'dissolved_oxygen_do_': 'nan',
#  'ethylbenzene_': 'nan',
#  'fenoprop_____': 'nan',
#  'hydrogen_sulfide_': 'nan',
#  'isoproturon': 'nan',
#  'lindane': 'nan',
#  'magnesium_sulfatemgso4_': 'MgSo4',
#  'mcpa': 'MCPA',
#  'mecoprop_____': 'nan',
#  'methoxychlor': 'nan',
#  'metolachlor': 'nan',
#  'molinate_': 'nan',
#  'monocholorobenzene_': 'nan',
#  'pathogenic_e_coli_': 'nan',
#  'pendimethalin____': 'nan',
#  'permethrin__': 'nan',
#  'propanil_________': 'nan',
#  'pyridate___________': 'nan',
#  'sar': 'SAR',
#  'silicon__': 'Si',
#  'simazine______________': 'nan',
#  'sodium_content_': 'nan',
#  'sodium_sulfate_naso4_': 'nan',
#  'styrene_': 'nan',
#  'temperature': 'Temp',
#  'tetrachloroethene__': 'nan',
#  'toluene_': 'Tl',
#  'total_disolved_salts_': 'nan',
#  'total_pcbs_': 'nan',
#  'trichlorobenzene_': 'nan',
#  'trichloroethene_______': 'nan',
#  'trifluralin_____________': 'nan',
#  'uranium__': 'U',
#  'xylene_': 'Xy',
#  '_heptachlor_and_heptachlor_epoxide': 'nan',
#  'phosphorus_as_p205': 'P2O5',
#  'aldrin_dieldrin': 'nan',
#  'atrazine___': 'nan',
#  'dissolved_oxygen': 'DO',
#  'saprofagic': 'Sap',
#  'xiphinema': 'Xip',
#  'carrot': 'nan',
#  'alkyl_mercury': 'nan',
#  'dissolved_manganese': 'nan',
#  'free_ammonia': 'nan',
#  'organic_phosphorus': 'OP',
#  'pcbs': 'nan',
#  'pesitcide_residues': 'nan',
#  'sulphides': 'S2',
#  'total_chromium': 'nan',
#  'total_mercury': 'nan',
#  'meloidogyne': 'Mel',
#  'pratylenchus': 'Pra',
#  'helicotylenchus': 'Hel',
#  'tylenchus': 'Tyl',
#  'total_suspended_solids': 'TSS',
#  'most_probable_number': 'MPN',
#  'tbc_at_37_degrees': 'TBC(37)',
#  'faecal_e_coli': 'FCECL',
#  'barium': 'Ba',
#  'total_phenols': 'Tdp',
#  'total_hardness': 'TH',
#  'fluoride': 'Fl',
#  'scutellonema': 'Scu',
#  'dry_matter': 'DM',
#  'total_nitrogen': 'N',
#  'bod': 'BOD',
#  'cod': 'COD',
#  'potassium_oxide': 'K2O',
#  'oil_&_grease': 'OG',
#  'silicates': 'Sil',
#  'carbon': 'C',
#  'cn_ratio': 'C:N',
#  'salmonella_spp': 'Salmonella',
#  'lime': 'Lime',
#  'trichodorus': 'Tcd',
#  'ditylenchus': 'Dts',
#  'aphelenchus': 'Aps',
#  'strontium': 'Sr',
#  'paratylenchus': 'Par',
#  'silica': 'SiO2',
#  'heterodera': 'Het',
#  'longidorus': 'Lon',
#  'potassium_as_k2o': 'K2O',
#  'magnesium_as_mgo': 'MgO',
#  'organic_carbon': 'C',
#  'gypsum': 'Gyp',
#  'silver': 'Ag',
#  'hardness': 'CaCO3',
#  'e_coli': 'Ecoli',
#  'permanganate_value': 'PValue',
#  'vibrio_cholerae': 'VC',
#  'soluble_p': 'S-P',
#  'total_phosphorus': 'T-P',
#  'total_n': 'T-N',
#  'listeria_monocytogenes': 'Listeria',
#  'pseudomonas_aeruginosa': 'Ps',
#  'phosphorus_bray1': 'P1',
#  'phosphorus_bray2': 'P2',
#  'ergs': 'ERGS',
#  'total_solids': 'TS',
#  'enterococcus_faecalis': 'E.faecalis',
#  'calcium_co3_equivalent': 'CCE',
#  'particle_size_<_03_mm': 'PSRE',
#  'pythium_': 'PY',
#  'fusarium_oxysporum': 'FUS',
#  'rhizoctonia_solani': 'RHIZ',
#  'gc-ms_screening': 'GC-MS',
#  'phytophthora_infestans': 'PHYT',
#  'aspergillus': 'ASPG',
#  'rhizobium': 'RHIZB',
#  'oil_': 'Oil',
#  'fibre': 'Fibre',
#  'total_ash': 'Ash',
#  'metabolisable_energy': 'Mel',
#  '_d_value': 'DValue',
#  'crude_protein': 'C.P',
#  'digestible_crude_protein': 'DCP',
#  'rumen_digestible_protein': 'RDP',
#  'shigella': 'SH',
#  'radopholus': 'Rad',
#  'tylenchorhynchus': 'Tyle',
#  'rotylenchus': 'Rot',
#  'ec_salts': 'EC(S)',
#  'aphelenchoides': 'Aph',
#  'lc_-_ms_screening': 'LC-MS',
#  'tylenchulus': 'Ty',
#  'water': 'H20',
#  'hemicyclophora': 'Hem',
#  'tvc_@22': 'TVC@22',
#  'staphylococcus_aureus': 'Staphy',
#  'tbc_at_22_degrees': 'TBC(22)',
#  'criconema': 'Cri',
#  'total_bacterial_count': 'TBC',
#  'free_residual_chlorine': 'Free(Cl2)',
#  'phosphorus_m3': 'P(M3)',
#  'bulk_density': 'BD',
#  'ph_kcl': 'pH(KCl)',
#  'free_lime': 'CaCO3',
#  '%_gypsum': '%Gyp',
#  '%_very_course_sand': '%  V.C San',
#  'course_sand': '% C.Sand',
#  'medium_sand': '% M.Sand',
#  'very_fine_sand': '%V.F Sand',
#  'fine_sand': '% Fine San',
#  'hirschimeniella': 'Hi',
#  'longidorous': 'Lo',
#  'extract': 'Extract',
#  'anguina': 'An',
#  'hoplolaimus': 'Hop',
#  'total_residual_chlorine': 'TRC',
#  'al': 'Al',
#  'ralstonia': 'Ral',
#  'xanthomonas': 'Xan',
#  'erwinia': 'Erw',
#  'mercury': 'Hg',
#  'trichoderma': 'Tch',
#  'tin': 'Sn',
#  '%_fc_pf_20': 'MC',
#  'agrobacterium': 'Agrob',
#  'glyphosate': 'Glyp',
#  'phosphorus_sorption_index_psi': 'PSI',
#  'exchangeable_aluminium': 'Exch.Al',
#  '%_pwp_pf_42': 'MC4.2',
#  'magnesium_hardness': 'MH',
#  'total_alkalinity': 'TA',
#  'reactive_silica': 'RS',
#  'colloidal_silica': 'CSiO',
#  'calcium_hardness': 'CH',
#  'fungi': 'Fungi',
#  'calcium_%': 'Ca%',
#  'magnesium_%': 'Mg%',
#  'potassium_%': 'K%',
#  'sodium_%_esp': 'Na%',
#  'hydrogen_%': 'H%',
#  'other_bases_%': 'OB%',
#  'ca:mg_ratio': 'Ca:Mg',
#  'mc_60cm_fc': 'MC 60cm',
#  'mc_100cm_fc': 'MC 100cm',
#  'mc_300cm_fc': 'MC 300cm',
#  'mc_1000cm_wp': 'MC 1000cm',
#  'mc_1500cm_wp': 'MC 1500cm',
#  'mc_4000cm_wp': 'MC 4000cm',
#  'soil_moisture_': 'SM',
#  'hexavalent_chromium': 'CrVI',
#  'total_petro_hydrocarbons': 'TPH',
#  'fieldcapacity': 'FieldCapacity',
#  'wiltingpt': 'WiltingPt',
#  'field_saturation': 'Field Saturation',
#  'saturation_pt': 'Saturation Pt',
#  'cec_nh4oac': 'C.E.C (NH4OAc)',
#  'calcium_oxide': 'CaO',
#  'magnesium_carbonate': 'MgCO3',
#  'eff_calcium_co3_eq': 'ECCE',
#  'particle_size_03_-_2_mm': 'PSRE2',
#  'btex': 'BTEX',
#  'tph_&_phenols': 'TPH & Phenols',
#  'ethyl_benzene': 'C8H16',
#  'charge_balance_error': 'Charge Bal',
#  'acid_saturation': 'Acid Saturation',
#  'co3,oh,hco3': 'T-Alkalinity',
#  'yeast': 'Yst',
#  'mould': 'Mld',
#  'protein': 'Protein',
#  'moisture': 'Moisture',
#  'fat': 'Fat',
#  'neutral_detergent_fibre': 'NDF',
#  'acid_detergent_fibre': 'ADF',
#  'starch_': 'Starch',
#  'sugars': 'Sugar',
#  'digestibility_ncgd': 'NCGD',
#  'sodium_chloride': 'NaCl',
#  'water_insoluble_matter': 'WIM',
#  '**nitrogen': '**N',
#  'aflatoxin_total_': 'Aflatoxin(Total)',
#  'bad_nematodes': 'PPN',
#  'good_nematodes': 'GN',
#  'reactive_carbon': 'ROC%',
#  'sulphur_as_so3': 'SO3',
#  'ammoniacal_n': 'NH4N',
#  'total_coliforms': 'TC',
#  '_soil_life_test': 'Soil Life Test',
#  'estimated_soil_texture': 'EST',
#  'soil_respiration_co2-c': 'CO2-C',
#  'dorylaimus': 'Dory',
#  'predators': 'Pred',
#  'bromide': 'Br',
#  'manganes_sulphate': 'Mn,S',
#  'phosphoric_acid': 'H3PO4',
#  'energy': 'E',
#  'total_plate_count': 'TPC',
#  'gold': 'Au',
#  'ureic-n': 'Co(NH2)2',
#  'alternaria_solani': 'E.B',
#  'xathomonas': 'Xat',
#  'particle_size_<1mm': 'PS1mm',
#  'particle_size_<2mm': 'PS2mm',
#  'particle_size_>28mm': 'PS2.8mm',
#  'particle_size_>4mm': 'PS4mm',
#  'biuret': 'C2H5N3O2',
#  'criconemella': 'Cri',
#  'bm': 'Biomass',
#  'sulphuric_acid': 'H2SO4',
#  'verticillium_spp': 'Verticillium',
#  'colletotrichum_coccodes': 'Anthracnose',
#  'septoria_lycopersici': 'Septoria',
#  'water_soluble_phosphorous_': 'P(W)',
#  'water_soluble_phosphorus_as_p2o5': 'P2O5(W)',
#  'sodium_carbonate': 'Na2CO3',
#  'pseudomonas_syringae': 'BLS',
#  'agrobacterium_tumefaciens': 'CG',
#  'agrobacterium_rhizogenes': 'RG',
#  'marssonina_rosae': 'BS',
#  'podosphaera_pannosa': 'PM',
#  'rose_mosaic_virus_rmv': 'RMV',
#  'rose_streak_virus_': 'RSV',
#  'rose_rosette_virus': 'RRV.',
#  'strawberry_latent_ringspot_virus_': 'SLRV.',
#  'pernospora_sparsa': 'Dw',
#  'phragmidium_mucranatum': 'Rst.',
#  'spaceloma_rosarum': 'Antr.',
#  'botrytis_cineria': 'Gm.',
#  'verticillium_dahliae': 'VW',
#  'leptosphaeria_coniothyrium': 'Sc.',
#  'cryptosporella_umbrina': 'Stem C.',
#  'corynebacterium_michiganesis': 'Bacterial Can.',
#  'pseudomonas_syringae_pvtomato': 'Speck',
#  'xanthomonas_campensiris': 'Bact.S',
#  'sclerotium_rolfsii': 'SB',
#  'stemphyllium_solani': 'GLS',
#  'tomato_yellow_leaf_curl_virus_': 'TYLCV',
#  'tomato_spotted_wilt_virus_': 'TSWV',
#  'tomato_yellow_ring_virus': 'TYRv',
#  'leaf_roll_virus': 'LRv',
#  'tomato_mosaic_virus_': 'ToMV',
#  'tobacco_mosaic_virus_': 'TMV',
#  'pepino_mosaic_virus_': 'PepMV',
#  'cucumber_mosaic_virus': 'CMv.',
#  'ralstonia_solanacearum': 'Rs',
#  'pectobacterium_carotovorum': 'BSR',
#  'dickeya_solani': 'DS',
#  'pseudomonas_fluorescans': 'PE',
#  'puccinia_pitteriana': 'Common Rst',
#  'aecidium_cantensis': 'DRst.',
#  'phoma_exigua': 'G',
#  'phythium_spp_potato': 'Lk.',
#  'phoma_andigena': 'PLS',
#  'phytophthora_spp': 'Phyt.spp',
#  'clavibacter_michiganesis': 'Ringspt.',
#  'streptomyces_scabiei': 'CS',
#  'colletotrichum_coccodes_potato': 'Bd.',
#  'gibberella_zeae': 'ER',
#  'exerohilum_turcicum': 'NLB',
#  'bipolaris_maydis': 'SLB',
#  'boric_acid': 'H3BO3',
#  'chlorophyll': 'Chlorophyll',
#  'paramagnetism': 'PCM',
#  'morgan-p': 'P(M)',
#  'morgan-k': 'K(M)',
#  'morgan-ca': 'Ca(M)',
#  'morgan-s': 'S(M)',
#  'morgan-mg': 'Mg(M)',
#  'morgan-nh4': 'NH4(M)',
#  'morgan-no3': 'NO3(M)',
#  'specific_gravity': 'SG',
#  'nh4_m': 'Morgan NH4',
#  'no3-m': 'Morgan NO3',
#  'combined_chlorine': 'CC',
#  'citrus_tristeza_virus': 'CTV',
#  'yeast_&_mould': 'Yst&Mld',
#  'particle_size_1-2mm': 'PS1mm-2mm',
#  'mites': 'Mites',
#  'leaf_miner': 'Leaf Miner',
#  'white_flies': 'White flies',
#  'thrips': 'Thrips',
#  'spider_mites': 'Spider Mites',
#  'dissolved_silica': 'SIO2(D)',
#  'downy_mildew': 'DownyM',
#  'nitric_acid': 'HNO3',
#  'calcium_hypochlorite': 'Ca(OCl)2',
#  'handling_fee': 'Handling Fee',
#  'kephis_permit,courier_charges,sample_preparation': 'HandlingFee',
#  'rosellinia_spp': 'Rspp',
#  'spongospora_subterranea': 'Sponsu',
#  'alternaria_alternata': 'bsss',
#  'cercospora_concors_solani': 'Cllb',
#  'sclerotinium_bataticola': 'Ccr',
#  'fusarium_spp': 'Fusar.spp',
#  'rhizoctonia_canker': 'Rhzca',
#  'helminththosporium_solani': 'Ssss',
#  'polyscytalum_pustulans': 'Sssn',
#  'thecaphora_solani': 'Thsm',
#  'ulocladium_atrum': 'Ulb',
#  'synchytrium_endobioticum': 'War',
#  'sclerotinia_sclerotiorum': 'Wwm',
#  'potato_virus_y_pvy': 'PVY',
#  'potato_leaf_roll_virus_plrv': 'Plrv',
#  'potato_virus_s_pvs': 'pvs',
#  'potato_virus_x_pvx': 'pvx',
#  'potato_mop_top_virus_pmtv': 'pmtv',
#  'tobacco_rattle_virus_trv': 'trv',
#  'potato_spindle_tuber_viroid_pstv': 'pstv',
#  'alfafa_mosaic_virus_amv': 'amv',
#  'potato_cyst_nematodes': 'pcnm',
#  'cercospora_maydis': 'GLSss',
#  'puccinia_sorghi': 'Crrr',
#  'puccinia_polysora': 'Srr',
#  'ustilago_maydis': 'Cmrs',
#  'spacelothea_reilliana': 'Hss',
#  'maize_lethal_necoric_disease_mlnd': 'MLND',
#  'maize_streak_virus_msv': 'Msvv',
#  'xanthomonas_translucens': 'Blss',
#  'basal_glume_rotbacterial_glume_rot': 'Pseus',
#  'alternaria_triticina': 'Albt',
#  'tilletia_contraversa': 'Tico',
#  'cochliobolus_sativus': 'Cosa',
#  'cochliobolus_spicifer': 'Cocsp',
#  'fusarium_head_blight': 'Gize',
#  'monographella_nivalis': 'Psm',
#  'phaeosphaeria_nodorum': 'Pnn',
#  'pyrenophora_tritici-repentis': 'Pytrs',
#  'sclerophthora_macrospora': 'Sclm',
#  'tilletia_tritici': 'Cbss',
#  'urocystis_agropyri': 'Ura',
#  'ustilago_tritici': 'Ustr',
#  'barley_stripe_mosaic_virus_bsmv': 'bsmv',
#  'wheat_streak_mosaic_virus_wsmv': 'wsmv',
#  'xanthomonas_oryzae_pv_oryzae': 'Xaoo',
#  'xanthomonas_oryzae_pv_oryzicola': 'xaooi',
#  'pyricularia_oryzae': 'pyo',
#  'fusairum_moniliforme': 'Fusmo',
#  'bipolaris_oryzae': 'Bipor',
#  'sarocladium_oryzae': 'Saro',
#  'xanthomonas_axonopodis': 'Xanta',
#  'pseudomonas_syringae_pv_phaseolicola': 'Psspp',
#  'pseudomonas_fluorescens': 'Psefl',
#  'curtobacterium_flaccumfasciens': 'Curfl',
#  'colletotrichum_lindemuthianum': 'Coll',
#  'phaeosariopsis_griseola': 'Phag',
#  'fusarium_solani': 'Fuss',
#  'fusarium_yellows': 'FusY',
#  'web_blight': 'Web',
#  'alternaria_spp': 'Alt.spp',
#  'ascochyta': 'Asco',
#  'macrophomina_phaseolina': 'Macp',
#  'cercospora_canescens': 'Cercc',
#  'bean_common_mosaic_virus_bcmv': 'bcmvv',
#  'peanut_mottle_virus_pemov': 'Pemov',
#  'bean_southern_mosaic_virus_bsmv': 'bssmv',
#  'xanthomonas_axonpodis_pv_glycines': 'Xaxpg',
#  'xanthomonas_savastonioi_pv_glycinea': 'Xasg',
#  'pseudomonas_syringae_pv_glycinea': 'Psspg',
#  'phakospora_pachyrhizi': 'Phap',
#  'red_leaf_blotch': 'Relf',
#  'frog_eye_leaf_spot': 'Fels',
#  'peronospora_manchurica': 'Perm',
#  'diaporthe_phaseolorum_': 'Diap',
#  'soybean_mosaic_polyvirus_smv': 'Smvv',
#  'bean_yellow_mosaic_virus_bymv': 'Bymv',
#  'ascochyta_pisi__pinodella': 'Aspp',
#  'erysiphe_polygoni': 'Erp',
#  'peronospora_pisi': 'Pepp',
#  'fusarium_oxysporum_f_sp_pisi': 'Fofsp',
#  'pea_enation_mosaic_virus_pemv': 'Pemv',
#  'xanthomonas_campestris': 'Xac',
#  'erwinia_carotovora': 'Erwc',
#  'leptosphaeria_maculans_phoma_lingam': 'Lmpl',
#  'alternaria_brassicae': 'Albrassc',
#  'plasmodiaphora_brassicae': 'Plbrassc',
#  'cercosphora_brassicola': 'Cebrassc',
#  'damping_off': 'Fuspp',
#  'turnip_mosaic_virus_tumv': 'Tumv',
#  'cottony_rot': 'Cor',
#  'pseudomonas_allicolai': 'Psall',
#  'pseudmonas_cepacia': 'Psce',
#  'alternaria_porri': 'Alpo',
#  'personospora_destructor': 'Pedes',
#  'sclerotium_cepivorum': 'Sclce',
#  'puccinia_porri': 'Pucpo',
#  'fusarium_oxysporum_f_sp_cepae': 'fuofCep',
#  'banana_xanthomonas_wilt': 'Bxw',
#  'panama_disease': 'Foxcu',
#  'mycosphaerella_figensis': 'Myfi',
#  'trachyspaera_fructogena': 'Trfr',
#  'anthracnose': 'Anthr',
#  'bunchy_top_disease': 'Btd',
#  'pseudomonas_syringae_pv_lachrymans': 'Pspl',
#  'pythium_spp__rhizoctonia_spp__fusarium_spp__phytopthera_spp': 'Dao',
#  'pseudoperonspora_cubensis': 'Psecu',
#  'fusarium_oxysporum_f_sp_niveum': 'Fuon',
#  'sphaerotheca_fuliginea__erysiphe_cichoracearum': 'SpfE',
#  'pythium__phytophthora': 'PyPh',
#  'curly_top_virus': 'Cutv',
#  'watermelon_mosaic_virus': 'Wamv',
#  'lettuce_infectious_yellows': 'Liy',
#  'cucumber_aphidborne_virus': 'Cav',
#  'xanthomonas_campestris_pv_vesicatoria': 'Xacpv',
#  'leveillula_taurica': 'Leta',
#  'colletotrichum_capsici': 'Colca',
#  'cercospora_capsici': 'Cerca',
#  'fusarium_oxysporum_f_sp_capsici': 'Fofcapsi',
#  'phytophthora_capsici': 'Phcapsi',
#  'chillie_veinal_mottle_virus': 'Cvms',
#  'pepper_veinal_virus': 'Pvv',
#  'tobacco_etch': 'Te',
#  'chilli_leaf_curl_virus': 'Clcv',
#  'xanthomonas_campestris_pv_vasculorum': 'Xcpv',
#  'xanthomonas_albilineans': 'Xaal',
#  'glomerella_tucumanesis': 'Glt',
#  'ceratocystis_paradoxo': 'Cepa',
#  'ustilago_scitaminea': 'Uss',
#  'clavibacter_xylisspxyli': 'Clxx',
#  'puccinia_melanocephalia': 'Pumel',
#  'sugarcane_mosaic_polyvirus_scmv': 'Scmvv',
#  'colletotrichum_gloeosporioides': 'Coglo',
#  'cercosporidium_henningsii': 'Cehen',
#  'cercospora_vicosae': 'Cevic',
#  'stricttococcus_vayssierrei': 'Stvay',
#  'cassava_mosaic_virus_cmv': 'Cmmv',
#  'cassava_brown_streak_virus_cbsv': 'Cbsvv',
#  'african_cassava_mosaic_virus_acmv': 'Acmvv',
#  'psedudomonas_syringae': 'Pssy',
#  'pyrenophora_graminea': 'Pygr',
#  'pyrenophora_teres': 'Pyrte',
#  'rhynchosporium_secalis': 'Rhyse',
#  'ustilago_hordei': 'Ushor',
#  'claviceps_purpurea': 'Clpu',
#  'cephalosporum_gramineum': 'Cegr',
#  'septoria_passerinii': 'Sepas',
#  'ustilago_nuda': 'Usnu',
#  'barley_mosaic_virus_bmv': 'Bmmv',
#  'burkholderia_andropogonis': 'Buhan',
#  'xanthomonas_vasicola': 'Xanva',
#  'claviceps_sorghi': 'Clavso',
#  'periconia_circinata': 'Perci',
#  'peronosclerospora_sorghi': 'Peroso',
#  'colletotrichum_graminicola': 'Collegra',
#  'sporisorium_sorghi': 'Sporso',
#  'cercospora_sorghi': 'Cercso',
#  'exserohilum_turcicum': 'Exstu',
#  'ascochyta_sorghi': 'Ascoso',
#  'cochliobolus_lunatus': 'Colu',
#  'pseudomonas_avellanae': 'Pseav',
#  'colletotrichum_theae_-_sinesis': 'Collethesi',
#  'armillaria_mellea': 'Amme',
#  'pseudomonas_syringae_pv_garcae': 'Psspvga',
#  'colletotrichum_kahawe_coffeanum': 'Colka',
#  'hemileia_vastatrix': 'Heva',
#  'fusarium_xylaroides_gibberella_xylaroides': 'Fuxy',
#  'fusarium_stillbioides_gibberella_stillbioides': 'Fusstil',
#  'cercospora_coffeicola': 'Cercof',
#  'plum_virus_pv': 'Plvs',
#  'available_chlorine': 'Cl2',
#  'discocriconema': 'Dcri',
#  'calcium_sap': 'Ca(sap)',
#  'magnesium_sap': 'Mg(sap)',
#  'potassium_sap': 'K(sap)',
#  'phosphorus_sap': 'P(sap)',
#  'sulphur_sap': 'S(sap)',
#  'sulphate_sap': 'SO4(sap)',
#  'globodera_pcn_cysts': 'Globodera',
#  'neofusicocum_parvum': 'Neofusicoccum',
#  'guignardia_mangiferae': 'Guignardia',
#  'cladosporium_tenuissimum': 'Cladosporium',
#  'total_aerobic_count': 'TAC',
#  'clostridium': 'Clostridia',
#  'globodera_pcn_juveniles': 'Globodera(PCN-Juveniles)',
#  'aphelenchoidesfragariae': 'Aph(F)',
#  'aphelenchoidesbesseyi': 'Aph(B)',
#  'ditylenchusdipsaci': 'Dty(D)',
#  'papaya_mosaic_virus': 'PapMV',
#  'colletotrichum_spp': 'Coll sp',
#  'total_sulphites': 'Total Sulphites',
#  'patulin': 'Patulin',
#  'sodium_hydroxide': 'NaOH',
#  'fertiliser_ph': 'pH',
#  'particle_size_1mm-4mm': 'PSRE3',
#  'legionella_spp': 'leg',
#  'sugarcane_mosaic_virus': 'SCMV',
#  'maize_chlorotic_mottle_virus': 'MCMV',
#  'free_moisture': 'Free Moisture',
#  'l_pneumophila_sg_1': 'LSg1',
#  'l_pneumophila_sg_2-14': 'LSg2-14',
#  'moisture@105c_': 'Moisture-105deg',
#  'microscopic_examination': 'ME',
#  'moisture_nir': 'Moisture-NIR',
#  'clostridium_perfringens': 'Clostridium',
#  'quaternary_ammonium_compounds_ddacbac': 'QAC',
#  'perchlorate': 'Perchlorate',
#  'tvc_at_30_degrees': 'TVC(30)',
#  'escherichia_coli': 'E.coli',
#  'virus_package_tomato': 'MVT',
#  'soil_texture_class': 'STC',
#  'fats,_oil_&_grease': 'FOG',
#  'total_chlorine': 'Total(Cl2)',
#  'munsell_soil_colour': 'Colour',
#  'ochratoxin_a': 'OT',
#  'total_carbon': 'T-C',
#  'sodium_oxide': 'Na2O',
#  'fatty_acids': 'FA',
#  'salmonella_spp_food': 'Salmonella(food)',
#  'staphylococcus_aureus_food': 'Staphy(food)',
#  'listeria_monocytogenes_food': 'Listeria (food)',
#  'psilenchus': 'Psil',
#  'fosetyl-aluminium_': 'fosetyl-Al',
#  'phosphonic_acid': 'H3PO3',
#  'sulphite_reducing_anaerobes': 'SRA',
#  'tvc_@37': 'TVC@37',
#  'particle_size0053-015mm': 'PS-6',
#  'particle_size_015-0212mm': 'PS-5',
#  'particle_size_<0053mm': 'PS0.053mm',
#  'nir_scanning': 'Scan',
#  'milling': 'Milling',
#  'water_soluble_k': 'K(W)',
#  'steviol_glycoside': 'SGs',
#  'particle_size_0212-_03_mm': 'PS-4',
#  'particle_size_1mm_-_03_mm': 'PS 1mm-0.3mm',
#  'particle_size_05-1mm': 'PS-1',
#  'particle_size_03-05mm': 'PS3',
#  'particle_size_2mm-4mm': 'PS2mm-4mm',
#  'p_alkalinity': 'PA',
#  'particle_size_>018mm': 'PS>0.18mm',
#  'total__bacteria_count_@22': 'TBC @22',
#  'tryptophan': 'C11H12N2O2',
#  'amino_acids': 'AC',
#  'organic_nitrogen': 'O-N',
#  'water_stable_aggregate_': 'Ag >0.25mm',
#  'sulfentrazone': 'C11H10Cl2F2N4O3S',
#  'rhizoctonia_spp': 'Rhizo.spp',
#  'sample_digestion': 'SD',
#  'dithiocarbamates_': 'CH2NS2',
#  'ryznar_index': 'RSI',
#  'enterobacteriaceae': 'Enterobacter',
#  'paraquat+diquat_': 'P+D',
#  'antibiotics': 'AB',
#  'quinolonen': 'C9H7NO',
#  'tetracyclinen': 'C22H24N2O8',
#  'amphenicolen': 'C11H12Cl2N2O5',
#  'nitrofuran': 'C4H3NO3',
#  'sulfonamide': 'CH5NO2S',
#  'water_soluble_ash_as_%_of_ta': 'WSA',
#  'alkalinity_of_water_soluble_ash': 'AWSA',
#  'water_extract': 'WE',
#  'catechins': 'C15H14O6',
#  'total_polyphenols': 'TPolyphenols',
#  'edta_copper': 'EDTA_Cu',
#  'edta_zinc': 'EDTA_Zn',
#  'edta_iron': 'EDTA_Fe',
#  'edta_manganese': 'EDTA_Mn',
#  'anaerobic_plate_count_': 'APC',
#  'potyvirus': 'Potyvirus',
#  'glufosinate': 'Glufosinate',
#  'ampa': 'AMPA',
#  'glucose': 'C6H12O6',
#  'sucrose': 'C12H22O11',
#  'pythium_aphanidermatum': 'PY-APHA',
#  'pythium_ultimum': 'PY-ULTI',
#  'fusarium_oxysporum_f_sp_radicis-lycopersici': 'FORL',
#  'verticillium_albo-atrum': 'Vert.albo',
#  'clavibacter_michiganensis_subsp_michiganensis': 'Cmm',
#  'nitrite': 'NO2',
#  'residual__free_chlorine': 'Cl(residual)',
#  'weight1000_seeds': 'Wt',
#  'shape': 'Shape',
#  'firmness': 'Firm',
#  'hygroscopy': 'Hyg',
#  'water_soluble_k2o': 'K20(W)',
#  'dissolved_organic_carbon': 'DOC',
#  'acid_insoluble_ash': 'AIA',
#  'iron_filings': 'FeFil',
#  'seed_germination_test': 'SeGer',
#  'phosphorus_dissolved_citric_acid': 'P-cs',
#  'particle_size__>03_mm': 'PS>0.3mm',
#  'particle_size_>2_mm': 'PS>2mm',
#  'purity_check_seeds_and_grains': 'Pur',
#  'admixture_seeds_and_grains': 'AdMix',
#  'free_fatty_acids': 'FFA',
#  'sodium_hypochlorite': 'NaOCl',
#  'seed_layer': 'SL',
#  'peroxide_value_o2': 'PV',
#  'insect_damaged_kernel': 'IDK',
#  'kernel_dust': 'KD',
#  'immature_kernels': 'IK',
#  'living_pests': 'LP',
#  'foreign_objects': 'FO',
#  'defective_kernels_%_mm': 'DK',
#  'foreign_matter_%_mm': 'FM',
#  'listeria_spp': 'Listeria_spp',
#  'insoluble_matter': 'IM',
#  'moisture_@145c_salt': 'MC140',
#  'particle_size_<0212mm': 'PS0.212mm',
#  'acid_insoluble_matter': 'AIM',
#  'alkalinity_as_na2co3': 'NaCO3',
#  'residue_on_evaporation': 'RE',
#  'absorbance_at_254nm': 'abs',
#  'aflatoxin_b1': 'AFB1',
#  'odour': 'Odour',
#  'taste': 'Taste',
#  'moisture_@103c_fats_&_oils': 'MC103FO',
#  'moisture_@103c_oil_seeds': 'MC103OS',
#  'moisture_@130c_maize': 'MC130MM',
#  'moisture_@130c_pulses': 'MC130P',
#  'moisture_@130c_cereal_products': 'MC130CP',
#  'dry_matter_@103c_animal_feed': 'DM103AF',
#  'fat_acidity': 'F(acidity)',
#  'anthraquinone': 'Anth',
#  'ffa_as_oleic_acid': 'C18H34O2',
#  'ffa_as_palmitic_acid': 'C16H32O2',
#  'ffa_as_linoleic_acid': 'C18H32O2',
#  'diplocarpon_rosae': 'Dipl',
#  'abaca_mosaic_virusamv': 'AbaMV',
#  'abaca_bract_mosaic_virusabmv': 'ABMV',
#  'abaca_bunchy_top_virusabtv': 'ABTV',
#  'apple_chlorotic_leafspot_virus_aclsv': 'ACLSV',
#  'african_cereal_steak_virus__acsv': 'ACSV',
#  'albugo_tragopogonis': 'Albu.trago',
#  'alternaria_brassicicola': 'Alt. brass',
#  'alternaria_citri': 'Alt. citri',
#  'alternaria_cucumerina': 'Alt.cuc',
#  'alternaria_mali': 'Alt.mali',
#  'alternaria_passiflorae': 'Alt.pass',
#  'alternaria_saponariae': 'Alt.sapon',
#  'alternaria_tenuissima': 'Alt.tenui',
#  'alternaria_tomatophila': 'Alt.tomato',
#  'apple_mosaic_virus_apmv': 'ApMV',
#  'armillaria_spp': 'Armi.spp',
#  'armillariella_mellea': 'Armill.mel',
#  'arabis_mosaic_virus\xa0armv': 'ArMV',
#  'ascochyta_aquilegiae': 'Ascoc.aquil',
#  'ascochyta_pinodella': 'Ascoc.pino',
#  'ascochyta_pisi': 'Ascoc.pisi',
#  'apple_stem_grooving_virus_asgv': 'ASGV',
#  'aspergillus_flavus,_a_parasiticus_': 'Asper.flav',
#  'aspergillus_niger': 'Asper.nig',
#  'aspergillus_spp': 'Asper.spp',
#  'apple_stem_pitting_virus_aspv': 'ASPV',
#  'asteridiella_perseae': 'Aste.perse',
#  'avocado_sunblotch_viroidasv': 'ASV',
#  'barlery_mild_mosaic_virus__bammv': 'BaMMV',
#  'banana_bract_mosaic_virus_bbrmv': 'BBrMV',
#  'banana_bunchy_top_virus_bbtv': 'BBTV',
#  'bean_common_mosaic__necrosis_virus_bcmnv': 'BCMNV',
#  'beety_curl_top_virus_bctv': 'BCTV',
#  'bean_golden_mosaic_virus_bgmv': 'BGMV',
#  'bipolaris': 'Bipo',
#  'bipolaris_hawaiiensis': 'Bipo.hawa',
#  'biscogniauxia_marginata': 'Bisc.margn',
#  'bean_leaf_roll_virus_blrv': 'BLRV',
#  'banana_mosaic_virus_bmv': 'BMV',
#  'beet_mild_yellowing_virusbmyv': 'BMYV',
#  'botrytis': 'Botry',
#  'botrytis_allii': 'Botry.allii',
#  'botrytis_cinerea': 'Botry.cine',
#  'botrytis_fabae': 'Botry.fab',
#  'botrytis_squamosa': 'Botry.squa',
#  'bortydiplodia_spp': 'Boty-diplo',
#  'botryosphaeria_disrupta': 'Botyosph.disr',
#  'botryosphaeria_ribis': 'Botyosph.ribi',
#  'botryosphaeria': 'Botyosph.spp',
#  'botryosphaeria_stevensii': 'Botyosph.stev',
#  'bean_pod_mottle_virus_bpmv': 'BPMV',
#  'banana_streak_virus_bsv': 'BSV',
#  'butlerelfia_eustacei': 'Butl.eust',
#  'banana_virus_x': 'BVX',
#  'barley_yellow_dwarf_virus_bydv': 'BYDV',
#  'barley_yellow_streak_mosaic_virus_bysmv': 'BYSMV',
#  'beet_yellow_virusbyv': 'BYV',
#  'carnation_mottle_virus_carmv': 'CarMV',
#  'chrysanthemum_chlorotic_mottle_viroid_ccmvd': 'CCMVd',
#  'cephalosporium_sacchari': 'Ceph.sacch',
#  'ceratocystis_fimbriata': 'Cera.fimbri',
#  'ceratocystis_paradoxa': 'Cera.parad',
#  'cercosphora_beticola': 'Cerco. bet',
#  'cercosphora_brassicicola': 'Cerco. brass',
#  'cercospora_chrysanthemi': 'Cerco. chrys',
#  'cercospora_spp': 'Cerco. spp',
#  'cercospora_citrullina': 'Cerco.citr',
#  'cercospora_concors': 'Cerco.conc',
#  'cercospora_delphinii': 'Cerco.delp',
#  'cercospora_fragariae': 'Cerco.frug',
#  'cercospora_fusimaculans': 'Cerco.fusi',
#  'cercospora_hydrangeae': 'Cerco.hydr',
#  'cercospora_kikuchii': 'Cerco.kiku',
#  'cercospora_nicotianae': 'Cerco.nico',
#  'cercospora_penniseti': 'Cerco.penni',
#  'cercospora_pisa_-sativae': 'Cerco.pisa',
#  'cercospora_rosicola': 'Cerco.rosi',
#  'cercospora_sojina': 'Cerco.soji',
#  'cercospora_vexans': 'Cerco.vexa',
#  'carnation_etched_ring_virus_cerv': 'CERV',
#  'cucumber_green_mottle_mosaic_virus_cgmmv': 'CGMMV',
#  'cassava_green_mottle_virus_cgmv_': 'CGMV',
#  'chalara_paradoxa': 'Chal.parad',
#  'chilli_leaf_curl_virus_chilcv': 'ChiLCV',
#  'chilli_veinal_mottle_virus': 'ChiVMV',
#  'chrysanthemum_mosaic_virus_chmv': 'ChMV',
#  'choanephora_cucurbitarum': 'Choa.cucur',
#  'cassava_ivorian_bacilliform_virus_cibv': 'CIBV',
#  'cladosporium': 'Clado',
#  'cladosporium_cladosporioides': 'Clado.clad',
#  'cladosporium_cucumerinum': 'Clado.cucu',
#  'cladosporium_fulvum': 'Clado.fulv',
#  'cladosporum_spp': 'Clado.spp',
#  'clavipeps_purpurea': 'Clavi.purp',
#  'clitocybe_tabescens': 'Clito.tabe',
#  'citrus_leaf_rugose_virus_clrv': 'CLRV',
#  'carnation_latent_virus_clv': 'CLV',
#  'cucumber_mosaic__virus_cmv': 'CMV',
#  'carnation_necrotic_fleck_virus_cnfv': 'CNFV',
#  'colletotrichum_falcatum': 'Col. falca',
#  'colletotrichum_phomoides': 'Col. phomo',
#  'coleosporium_helianthi': 'Cole.helia',
#  'colletotrichum_legenarium': 'Collet lege',
#  'colletotrichum_dematium': 'Collet. Dema',
#  'glomerella_graminicola': 'Collet. gram',
#  'colletotrichum_actatum': 'Collet.act',
#  'colletotrichum_ananas': 'Collet.anan',
#  'colletotrichum_cajani': 'Collet.cajan',
#  'colletotrichum_cereale_manns': 'Collet.cere',
#  'colletotrichum_circinans': 'Collet.circ',
#  'colletotrichum_destructivum': 'Collet.dest',
#  'colletotrichum_fragariae': 'Collet.frug',
#  'glomerella_tucumanensiscolletotrichum_fulcatum': 'Collet.fulc',
#  'colletotrichum_gloeosporiodes': 'Collet.gloe',
#  'colletotrichum_kahawae': 'Collet.kaha',
#  'colletotrichum_musae': 'Collet.musa',
#  'colletotrichum_truncatum': 'Collet.trunc',
#  'coniothyrium_spp': 'Conio.spp',
#  'corynespora_cassiicola': 'Cor. cassi',
#  'corticium_koleroga': 'Cort.koler',
#  'corticium_salmonicolor': 'Cort.salmo',
#  'corticium_stevensii': 'Cort.steve',
#  'cowpea_mosaic_virus_cmv': 'CPMV',
#  'citrus_psorosis_virus_cpsv': 'CPsV',
#  'cherry_rasp_leaf_virus_crlv': 'CRLV',
#  'carnation_ringspot_virus_crsv': 'CRSV',
#  'cassava_american_latent_virus_csalv_': 'CsAlV',
#  'cassava_common_mosaic_viruscscmv': 'CsCMV',
#  'cassava__frogskin_associated_virus_csfsav': 'CsFSaV',
#  'chrysanthemum_stunt_viroid_csvd': 'CSVd',
#  'cassava_vein_mosai_virus_csvmv': 'CsVMV',
#  'cereal_tillering_disease_virus_ctdv': 'CTDV',
#  'curvularia_eragrostidis': 'Curv.erag',
#  'curvularia_lunata': 'Curv.luna',
#  'curvularia_tuberculata': 'Curv.tuber',
#  'carnation_vein_mottle_virus_cvmv': 'CVMV',
#  'citrus_variegation_virus_cvv': 'CVV',
#  'cylindrocladium_crotalariae': 'Cyli.crota',
#  'cylindrocarpon_musae': 'Cyli.musa',
#  'cylindrocarpon_tenue': 'Cyli.tenue',
#  'dahliae_spp': 'Dahl.spp',
#  'dematophora_necatrix': 'Dema.neca',
#  'diaporthe_longicola': 'Dia. longi',
#  'diaporthe_spp': 'Dia.spp',
#  'didymella_bryoniae': 'Didy.bryo',
#  'diplodina_delphinii': 'Dipl.delph',
#  'diplocarpon_earlianum': 'Dipl.earli',
#  'diplodia__maydis': 'Dipl.mayd',
#  'dothiorella_sp': 'Dothio.spp',
#  'dreschslera_gigantea': 'Dresh.giga',
#  'drechslera_teres_': 'Dresh.teres',
#  'entyloma_winteri': 'Enty.winte',
#  'erysiphe_cichoracearum': 'Erysip .cicho',
#  'erysiphe_cruciferarum': 'Erysip. crucif',
#  'erysiphe_graminis_fsp_hordei': 'Erysip.gramin',
#  'erysiphe_pisi': 'Erysip.pisi',
#  'erysiphe_spp': 'Erysip.spp.',
#  'exobasidium_reticulatum': 'Exob.reti',
#  'fleck_lsv_+_cmv_': 'FLECK',
#  'fusarium_decemcellulare': 'Fusar.decem',
#  'fusarium_equiseti': 'Fusar.equis',
#  'fusarium_graminearum': 'Fusar.grami',
#  'fusarium__moniliforme': 'Fusar.monil',
#  'fusarium_nivalis': 'Fusar.niva',
#  'fusarium_oxysporium_fsppassiflorae': 'Fusar.oxys',
#  'fusarium_pallidoroseum': 'Fusar.palli',
#  'fusarium_sacchari': 'Fusar.sacch',
#  'fusarium_subglutinans': 'Fusar.subglu',
#  'fusarium_udum': 'Fusar.udum',
#  'gaeumannomyces_gramini_varavenae': 'Gaeu.aven',
#  'gaeumannomyces_gramini_vartritici': 'Gaeu.trit',
#  'ganoderma_applanatum': 'Gano.appla',
#  'ganoderma_philippii': 'Gano.phil',
#  'ganoderma_zonatum': 'Gano.zonat',
#  'garlic_common_latent_virusgclv': 'GCLV',
#  'gleosporium_musarum': 'Gle. musar',
#  'gleosporium_spp': 'Gle. Spp',
#  'graft_transmissible_agentgta': 'GTA',
#  'guignardia_sp': 'Guig.sp',
#  'gymnosporangium_libocedri': 'Gym. liboc',
#  'gymnosporangium_clavipes': 'Gymn.clavi',
#  'gymnosporangium_globosum': 'Gymn.glob',
#  'gymnosporangium_juniperi-virginianae': 'Gymn.virg',
#  'gymnosporangium_yamadae': 'Gymn.yama',
#  'hydrangea_chlorotic_mottle_virus_hdcmv': 'HdCMV',
#  'hydrangea_latent_virus_hdlv': 'HdLV',
#  'hydrangea_mosaic_virus_hdmv': 'HdMV',
#  'hydrangea_ringspot_virus_hdrsv': 'HdRSV',
#  'helicobasidium_compactum': 'Heli.comp',
#  'helminthosporium_carbonum': 'Helmint.carbo',
#  'helminthosporium_nodulosum': 'Helmint.nodu',
#  'helminthosporium_papulosum': 'Helmint.papu',
#  'helminthosporium_pedicallatum': 'Helmint.pedi',
#  'helminthosporium_spp': 'Helmint.spp',
#  'hemileia_coffeicola': 'Hemi.coffe',
#  'hendersonia_creberrima': 'Hend.crebe',
#  'hexagonia_hydnoides': 'Hexa.hydro',
#  'hippeastrum_mosaic_virus_hmv': 'HMV',
#  'hyaloperonospora_parasitica': 'Hyal.paras',
#  'indian_cassava_mosaic_virus_icmv': 'ICMV',
#  'impatiens_necrotic_spot_virus_insv': 'INSV',
#  'iris_yellow_spotvirusiysv': 'IYSV',
#  'johnsongrass_mosaic_virus_jgmv': 'JGMV',
#  'lasiodiplodia_theobromae': 'Lasi.theo',
#  'leucostoma_cinctum': 'LEUC',
#  'leveillula_taurica_and_oidium': 'Leve.Oidi',
#  'leveilla_tourica': 'Leve.touri',
#  'linochora_graminis': 'Lino.grami',
#  'lettuce_infectious_yellows_virus_liyv': 'LIYV',
#  'lily_mottle_virus\xa0lmv': 'LMV',
#  'lettuce_necrotic_yellows_viruslnyv': 'LNYV',
#  'lily_symptomless_virus_lsv': 'LSV',
#  'lily_virus_x\xa0lvx,': 'LVX',
#  'leek_yellow_stripe_virus_lysp': 'LYSP',
#  'macrophoma_mangiferae': 'Macr.mangi',
#  'macrophoma_theicola': 'Macr.thei',
#  'maize_chlorotic_dwarf_virusmcdv': 'MCDV',
#  'meliola_mangiferae': 'Meli.mangi',
#  'microsphaeropsis_tanaceti': 'Mic. tanac',
#  'microsphaera_friesii': 'Micr.fries',
#  'maize_rough_dwarf_virus_mrdv': 'MRDV',
#  'maize_streak_virus_msv_-sugarcane_strain': 'MSV',
#  'mucor_circinelloides': 'Muco.circi',
#  'mucor_mucedo': 'Muco.muce',
#  'mycena_citricolor': 'Myc. citri',
#  'mycosphaerella_brassicicola': 'Myco.brass',
#  'mycosphaerella_caricae': 'Myco.cari',
#  'mycosphaerella_eumusae': 'Myco.eumu',
#  'mycosphaerella_fragariae': 'Myco.fragar',
#  'mycosphaerella_ligulicola': 'Myco.ligul',
#  'mycosphaerella_musae': 'Myco.musa',
#  'mycosphaerella_musicola': 'Myco.musi',
#  'mycosphaerella_nicotianae': 'Myco.nicot',
#  'mung_bean_yellow_mosaic_virusmymv': 'MYMV',
#  'neocosmospora_vasinfecta': 'Neoc.vasi',
#  'neofabraea_perennans': 'Neof.peren',
#  'neopestalotiopsis_spp': 'Neop.spp',
#  'nigrospora_sphericu': 'Nigr.spher',
#  'northern_cereal_mosaic_virus_ncmv': 'Nor. (NCMV',
#  'oidiopsis_sicula': 'Oid. sicul',
#  'oidiopsis_taurica': 'Oid. tauri',
#  'oidium_spp': 'Oid.spp',
#  'oidium_manihotis': 'Oidi.manih',
#  'olpidium_brassicae': 'Olpi.bras',
#  'onion_yellow_dwarf_virus_oydv': 'Oni. (OYDV',
#  'oxyporus_latemarginatus': 'Oxyp.latem',
#  'panicum_mosaic_virus_pmv': 'Pan. (PMV)',
#  'papaya_apical_necrosis_virus_panv': 'PANV',
#  'passalora_fulva': 'Pas. fulva',
#  'patellaria_theae': 'Pate.theae',
#  'papaya_droopy_necrosis_viruspdnv': 'PDNV',
#  'pea_early_browning_virus_pebv': 'PEBV',
#  'peltaster_fruticola_': 'Pelst.frut',
#  'penicillium_expansum': 'Pen. expan',
#  'penicillium_funiculosum': 'Pen. funic',
#  'penicillium_spp': 'Penni.spp',
#  'pepper_mottle_virus_pepmov': 'PepMoV',
#  'peronospora_manshurica': 'Per. mansh',
#  'peronospora_sparsa': 'Per. spars',
#  'peronospora_tabacina': 'Per. tabac',
#  ...}

# %%
chemicals_dict_2 = chemicals.set_index("chemical_name").to_dict()['chemical_symbol']

# %%
req_body = test
_ = pd.DataFrame(req_body)
unit_decision = pd.read_csv("output/sgf_unit_per_chemical_decision.csv")
unit_decision.analysis_name = [ i.replace(":","") for i in unit_decision.analysis_name ]
analysis_dict = pickle.load(open("analysis.dict","rb"))
mahalanobis_thresholds = pickle.load(open("mahalanobis_thresholds.dict","rb"))

result = {}
_df = _.explode('analysis_id', ignore_index=True)
cursor = conn_lims.cursor()
import math
for index,row in _df.iterrows():
    sample_code = row['sample_code']
    if sample_code not in result.keys():
        result[sample_code] = []
    if math.isnan(row['analysis_id']):
        result[sample_code].append({"sample_code": sample_code,"status":"warning", "message": f"Analysis not in specified", "details": f"Analysis id not provided", "analysis": None  })   
        continue
    row['analysis_name'] = analysis_dict[row['analysis_id']]
    analysis = row['analysis_name'].replace(":","")
    analysis_id = row['analysis_id']
    if analysis not in mahalanobis_thresholds.keys():
        result[sample_code].append({"sample_code": sample_code,"status":"warning", "message": f"Analysis not in models", "details": f"Analysis: {analysis} is not in the list of defined models", "analysis": row['analysis_name'] })   
        continue  
    row = row.dropna()
    scaler = pickle.load(open(f"models/scalers/{analysis}.pkl","rb"))
    pca = pickle.load(open(f"models/pca/{analysis}.pkl","rb"))
    imputer = pickle.load(open(f"models/imputers/{analysis}.pkl","rb"))
    analysis_df = pd.read_csv(f"output/analysis/{analysis}.csv",index_col=0)
    mahalanobis_distance_df = pd.read_csv(f"output/mahalanobis_distance/{analysis}.csv",index_col=0).drop("mahalanobis_distance",axis=1)

    

    try :
        tmp_df = pd.DataFrame(row).T[analysis_df.columns]
    except Exception as e:
        result[sample_code].append({"sample_code": sample_code,"status":"warning", "message": f"Missing parameters for analysis: {analysis}", "details": f"Missing parameters: {','.join([ i for i in analysis_df.columns if i not in row.dropna().index])} for analysis: {analysis}", "analysis": row['analysis_name']})
        continue
    failed_units_comparison = {}    
    for col in tmp_df.columns:
        expected_units = unit_decision.loc[(unit_decision['analysis_name'] == analysis) & (unit_decision['chemical_name'] == col)]
        expected_units = unit_decision.loc[(unit_decision['analysis_name'] == analysis) & (unit_decision['chemical_name'] == col)]
        # if row['sample_code'] == 'CN013SGF0150':
        #     print(row[col]['units'])
        val = row[col]['result']
        symbol = chemicals_dict[col.strip()].strip()

        import math
        if type(row[col]) != dict and math.isnan(row[col]):
            failed_units_comparison[col] = {}
            failed_units_comparison[col]['expected_units'] = expected_units['unit_name'].tolist()[0]
            failed_units_comparison[col]['units_provided'] = None
        elif symbol in [ i for i in conversion_dict.keys() ] and row[col]['units'] == "ppm" and expected_units['unit_name'].values[0] == "mmol/l":
            val = row[col]['result']
            sql = f"""
                SELECT [dbo].[Calculate_Conversion] ({val}, '{symbol}') 
            """
            converted = cursor.execute(sql).fetchone()[0]
            row[col]['units'] = "mmol/l"
            row[col]['result'] = converted
        elif symbol in [ i for i in conversion_dict.keys() ] and row[col]['units'] == "mmol/l" and expected_units['unit_name'].values[0] == "ppm":
            print("mmol")
            val = row[col]['result']
            
            factor = conversion_dict[symbol]
            converted_val = val / factor
            row[col]['units'] = "ppm"
            row[col]['result'] = converted_val
        elif symbol in [ i for i in conversion_dict.keys() ] and row[col]['units'] == "µmol/l" and expected_units['unit_name'].values[0] == "ppm":
            print("µmol/l")
            val = row[col]['result']
            
            factor = conversion_dict[symbol]
            converted_val = (val / factor) / 1000
            row[col]['units'] = "ppm"
            row[col]['result'] = converted_val
        elif row[col]['units'] !=   expected_units['unit_name'].values[0] :
            failed_units_comparison[col] = {}
            failed_units_comparison[col]['expected_units'] = expected_units['unit_name'].tolist()[0]
            failed_units_comparison[col]['units_provided'] = row[col]['units']
        else:
            continue    
    if len(failed_units_comparison.keys()) > 0:
        result[sample_code].append({"sample_code": sample_code,"status":"warning", "message": f"Wrong units provided", "details": f"Expected units are {str(failed_units_comparison)} for analysis: {analysis}" , "analysis": row['analysis_name']})
        continue
    for col in analysis_df.columns:
        if type(row[col]) == dict:
            row[col] = row[col]['result']
    
    out_of_bounds_chems = [ ]
    for col in tmp_df.columns:
        if col == "sample_code":
            continue
        if col == "ec_salts":
            if row[col] > 105 or row[col] < 95:
                out_of_bounds_chems.append("ec_salts out of bounds. Allowed bounds are 95 - 105")
        if col == "Charge Balance":
            if row[col] < -1:
                out_of_bounds_chems.append("Charge Balance out of bounds. Allowed lower boundary is -10. ")       
        elif col.lower() == "total suspended solids" and row['analysis_name'].lower() == "total suspended solids":
            if row[col] > 1:
                out_of_bounds_chems.append("total suspended solids out of bounds. If analysis is total suspended solids is <1 then total suspended solids check should be <1  . ")         
    if len(out_of_bounds_chems) > 0:
        result[sample_code].append({"sample_code": sample_code,"status":"warning", "message": f"Out of bounds", "details": f"{'.'.join(out_of_bounds_chems)}", "analysis": row['analysis_name'] })
        continue    

    tmp_df = pd.DataFrame(row).T[analysis_df.columns]
    tmp_df = imputer.transform(tmp_df)
    df_scaled = scaler.transform(tmp_df)
    df_pca = pd.DataFrame(pca.transform(df_scaled))
    
    df_pca.columns = [ i for i in df_pca.columns]
    mahalanobis_distance_df.columns = [ i for i in df_pca.columns]
    df_pca = pd.concat([df_pca, mahalanobis_distance_df])
    mu = np.mean(df_pca, axis=0)
    sigma = np.cov(df_pca.T)

    mahalanobis_distance = distance.mahalanobis(df_pca.iloc[0], mu, np.linalg.inv(sigma))

    expected_md = mahalanobis_thresholds[analysis]

    if mahalanobis_distance > expected_md:
        result[sample_code].append({"sample_code": sample_code,"status":"fail", "message": "Mahalanobis distance exceeds threshold", "details":f"Mahalanobis distance of {round(mahalanobis_distance,2)} exceeds threshold of {round(expected_md,2)} for analysis: {analysis}", "analysis": row['analysis_name'] })
    else:
        result[sample_code].append({"sample_code": sample_code,"status":"pass","message": "Mahalanobis distance within threshold", "details":f"Mahalanobis distance of {round(mahalanobis_distance,2)} is within threshold of {round(expected_md,2)} for analysis: {analysis}", "analysis": row['analysis_name'] })
# Out:
# 6.71
# NO3N
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[93], line 50
#      48     print(val)
#      49     print(symbol)
# ---> 50     print(conversion_dict[symbol.strip()])
#      51 import math
#      52 if type(row[col]) != dict and math.isnan(row[col]):
#
# KeyError: 'NO3N'

# %%
final_df = pd.DataFrame()
for i in result.keys():
    out_df = (pd.DataFrame(result[i]))
    final_df = pd.concat([final_df, out_df])

# %%
final_df.to_csv("test_results.csv")

# %%
final_df
# Out:
#            sample_code   status                                 message  \
# 0         CS032SGF0390     pass   Mahalanobis distance within threshold
# 0         CS032SGF0391     pass   Mahalanobis distance within threshold
# 0         CB047SGF0228     pass   Mahalanobis distance within threshold
# 0         CB047SGF0226     pass   Mahalanobis distance within threshold
# 0         CN013SGF0150  warning                    Wrong units provided
# ..                 ...      ...                                     ...
# 0   CM173SGF3298           pass   Mahalanobis distance within threshold
# 0   CM173SGF3299        warning                    Wrong units provided
# 0         CF053SGF0133     pass   Mahalanobis distance within threshold
# 0         CF053SGF0134     fail  Mahalanobis distance exceeds threshold
# 0         CE249SGF0073     fail  Mahalanobis distance exceeds threshold
#
#                                               details  \
# 0   Mahalanobis distance of 2.61 is within thresho...
# 0   Mahalanobis distance of 2.1 is within threshol...
# 0   Mahalanobis distance of 2.3 is within threshol...
# 0   Mahalanobis distance of 2.38 is within thresho...
# 0   Expected units are {'potassium': {'expected_un...
# ..                                                ...
# 0   Mahalanobis distance of 2.81 is within thresho...
# 0   Expected units are {'ph': {'expected_units': '...
# 0   Mahalanobis distance of 3.51 is within thresho...
# 0   Mahalanobis distance of 8.15 exceeds threshold...
# 0   Mahalanobis distance of 24.85 exceeds threshol...
#
#                                            analysis
# 0                           1:2 Soil Volume Extract
# 0                           1:2 Soil Volume Extract
# 0                           1:2 Soil Volume Extract
# 0                           1:2 Soil Volume Extract
# 0                           1:2 Soil Volume Extract
# ..                                              ...
# 0                               Drip Water Analysis
# 0   Raw irrigation water analysis (for fertigation)
# 0                           1:2 Soil Volume Extract
# 0                           1:2 Soil Volume Extract
# 0                           1:2 Soil Volume Extract
#
# [647 rows x 5 columns]
